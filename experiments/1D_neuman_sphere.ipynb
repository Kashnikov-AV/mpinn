# %%
import jax
import jax.numpy as jnp
import flax.nnx as nnx
import optax
import matplotlib.pyplot as plt
import pandas as pd
import os
from dataclasses import dataclass
from functools import partial

# %%
from geom import Interval
from pinn_core import PINN, FCNet
from pde import sphere_1d
from bc import dirichlet_bc, neuman_bc
from analytic import sphere_1d_neuman_exact

# %%
plt.rcParams.update({
    'font.size': 14,
    'axes.titlesize': 14,
    'axes.labelsize': 14,
    'xtick.labelsize': 14,
    'ytick.labelsize': 14,
    'legend.fontsize': 14,
    'figure.titlesize': 16,
})

# %%
@dataclass(frozen=True)
class PhysicsParams:
    L: float = 1.0
    x_left: float = 0.3
    x_right: float = 0.6
    T_left: float = 300.0
    q_right: float = -100.0
    _lambda: float = 1.0

    @property
    def grad_right(self):
        return -self.q_right / self._lambda

# %%
def get_activation(name):
    mapping = {
        'tanh': nnx.tanh,
        'Swish': nnx.silu,
        'sin': jnp.sin,
        'GELU': nnx.gelu,
        'ReLU': nnx.relu,
        'Sigmoid': nnx.sigmoid,
    }
    return mapping.get(name, nnx.relu)

def get_optimizer(name, lr):
    mapping = {'adam': optax.adam(lr)}
    return mapping.get(name, optax.adam(lr))

# %%
def train_model(
    hidden_features, num_layers, activation_name, lr,
    num_points, opt_name, epochs, weights, save_img=False, show_plot=False
):
    phys = PhysicsParams()
    
    geom = Interval(phys.x_left, phys.x_right)
    x_collocation = geom.generate_collocation(n_interior=num_points, method='random')
    total_points = x_collocation.shape[0]

    act_fn = get_activation(activation_name)
    net = FCNet(din=1, dmid=hidden_features, dout=1, num_layers=num_layers, activation=act_fn, rngs=nnx.Rngs(0))
    
    optimizer = get_optimizer(opt_name, lr=lr)
    pinn = PINN(net, opt=optimizer, weights=weights)

    bc_fns = [
        partial(dirichlet_bc, x=phys.x_left, T=phys.T_left),
        partial(neuman_bc, x=phys.x_right, g=phys.grad_right)
    ]

    history, training_time = pinn.fit(
        x_collocation=x_collocation,
        pde_fn=sphere_1d,
        bc_fns=bc_fns,
        phys=phys,
        epochs=epochs
    )

    x_test = jnp.linspace(phys.x_left, phys.x_right, 100).reshape(-1, 1)
    metrics, T_pred, T_exact = pinn.evaluate(
        x_test, sphere_1d_neuman_exact, phys, bc_names=['dirichlet', 'neuman']
    )

    print(f'Эпохи: {epochs}, Время: {training_time:.4f}c, MSE: {metrics['mse']}')

    if save_img:
        pinn.save_plot(x_test, T_pred, T_exact, phys, save_path=f'images/pinn/1D_sphere_Neuman_{epochs}.png')

    if show_plot:
        pinn.show_plot(x_test, T_pred, T_exact, phys)

    result = {
        'bc_left': metrics['bc_left'],
        'bc_right': metrics['bc_right'],
        'training_time': f'{training_time:.4f}',
        'epoches': epochs,
        'lr': lr,
        'activation_func': activation_name,
        'layers': num_layers,
        'neurons': hidden_features,
        'optimizer': opt_name,
        'collocation_points': total_points,
        'mape': metrics['mape'],
        'mae': metrics['mae'],
        'mse': metrics['mse'],
        'rmse': metrics['rmse'],
        'max_error': metrics['max_error'],
        'weights': f'{weights}',
    }

    return result, history

# %%
def find_optimal_epochs(
    target_mape, max_epochs, step,
    hidden_features, num_layers,
    activation_name, lr,
    num_points, opt_name,
    weights
):
    for epochs in range(step, max_epochs + 1, step):
        metrics, history = train_model(
            hidden_features, num_layers, activation_name, lr,
            num_points, opt_name, epochs, weights, save_img=False
        )
        if float(metrics['mape']) < target_mape:
            return epochs
    return max_epochs

# %%
def try_experiments(eph, lr, csv_path='csv_results/1D_sphere_neuman_results.csv'):
    num_hidden = [32, 64, 128]
    num_layers = [1, 2, 3]
    activation = ['tanh', 'Swish', 'sin', 'GELU', 'ReLU', 'Sigmoid']
    num_col = [10, 20, 50, 100]
    optimizer = ['adam']
    epochs = [eph, eph*2, eph*3]
    weights = [1, 5, 5]
    
    results = []
    exp = 0

    for h in num_hidden:
        for l in num_layers:
            for a in activation:
                for col in num_col:
                    for opt in optimizer:
                        for epoch in epochs:
                            exp += 1
                            print(f'Experiment {exp}/{len(num_hidden)*len(num_layers)*len(activation)*len(num_col)}')
                            res, history = train_model(h, l, a, lr, col, opt, epoch, weights)
                            results.append(res)

    df_results = pd.DataFrame(results)
    os.makedirs(os.path.dirname(csv_path), exist_ok=True)
    df_results.to_csv(csv_path, mode='a', header=not os.path.exists(csv_path), index=False)
    print(f'Experiments finished. Results saved to {csv_path}')
    return df_results

# %%
# Оптимальные эпохи
learning_rate = 0.01
weights=[1, 1, 1]

optimal_epochs = find_optimal_epochs(
    target_mape=0.001, max_epochs=3000, step=50,
    hidden_features=64, num_layers=2,
    activation_name='GELU', lr=learning_rate,
    num_points=100, opt_name='adam',
    weights=weights
)
optimal_epochs
# Out:
# Эпохи: 50, Время: 1.1450c, MSE: 2.0084e+04
# Эпохи: 100, Время: 0.9671c, MSE: 1.9584e+02
# Эпохи: 150, Время: 1.1246c, MSE: 2.0690e+01
# Эпохи: 200, Время: 1.1139c, MSE: 5.6925e+00
# Эпохи: 250, Время: 1.1002c, MSE: 1.0526e+00
# Эпохи: 300, Время: 1.2669c, MSE: 6.7906e-01
# Эпохи: 350, Время: 1.2433c, MSE: 1.9384e+00
# Эпохи: 400, Время: 1.1962c, MSE: 1.2897e-01
# 400

# %%
metrics, history = train_model(
    hidden_features=64, num_layers=2, 
    activation_name='GELU', lr=learning_rate, 
    num_points=100, opt_name='adam', 
    epochs=optimal_epochs, show_plot=True,save_img=True,
    weights=weights
)
metrics
# Out:
# Эпохи: 400, Время: 1.2748c, MSE: 1.2897e-01
# {'bc_left': 'dirichlet',
#  'bc_right': 'neuman',
#  'training_time': '1.2748',
#  'epoches': 400,
#  'lr': 0.01,
#  'activation_func': 'GELU',
#  'layers': 2,
#  'neurons': 64,
#  'optimizer': 'adam',
#  'collocation_points': 102,
#  'mape': '9.2706e-04',
#  'mae': '3.1980e-01',
#  'mse': '1.2897e-01',
#  'rmse': '3.5913e-01',
#  'max_error': '5.4053e-01',
#  'weights': '[1, 1, 1]'}

# %%
history.keys()
# Out:
# dict_keys(['steps', 'total_loss', 'pde', 'bc_0', 'bc_1'])

# %%
plt.figure(figsize=(12, 7))
steps = history['steps']

plt.semilogy(steps, history['pde'], 'b', label='PDE Потери', linewidth=2) # PDE
plt.semilogy(steps, history['bc_0'], 'r--', label='ГУ слева', linewidth=2, alpha=0.7) # Boundary Conditions
plt.semilogy(steps, history['bc_1'], 'r--', label='ГУ справа', linewidth=2, alpha=0.7)
plt.semilogy(steps, history['total_loss'], 'g--', label='Общая ошибка', linewidth=2, alpha=0.7)

plt.title('История Обучения')
plt.xlabel('Эпохи')
plt.ylabel('Потери')
plt.legend(loc='upper right')
plt.grid(True, alpha=0.3, which="both")
plt.tight_layout()
plt.savefig('images/history_sphere_neuman', dpi=72, bbox_inches='tight')
plt.show()

# %%
df_results = try_experiments(optimal_epochs, lr=learning_rate)
df_results.head()
# Out:
# Experiment 1/216
# Эпохи: 400, Время: 0.4108c, MSE: 4.1639e+04
# Experiment 2/216
# Эпохи: 800, Время: 0.5821c, MSE: 1.4017e+04
# Experiment 3/216
# Эпохи: 1200, Время: 0.6048c, MSE: 6.8355e+03
# Experiment 4/216
# Эпохи: 400, Время: 0.4588c, MSE: 4.1751e+04
# Experiment 5/216
# Эпохи: 800, Время: 0.6848c, MSE: 1.4090e+04
# Experiment 6/216
# Эпохи: 1200, Время: 0.6817c, MSE: 6.4991e+03
# Experiment 7/216
# Эпохи: 400, Время: 0.6518c, MSE: 4.1805e+04
# Experiment 8/216
# Эпохи: 800, Время: 0.6112c, MSE: 1.4125e+04
# Experiment 9/216
# Эпохи: 1200, Время: 0.6475c, MSE: 6.2372e+03
# Experiment 10/216
# Эпохи: 400, Время: 0.6008c, MSE: 4.1810e+04
# Experiment 11/216
# Эпохи: 800, Время: 0.6394c, MSE: 1.4129e+04
# Experiment 12/216
# Эпохи: 1200, Время: 0.6825c, MSE: 6.2844e+03
# Experiment 13/216
# Эпохи: 400, Время: 0.5307c, MSE: 8.0331e+02
# Experiment 14/216
# Эпохи: 800, Время: 0.5740c, MSE: 3.5835e+01
# Experiment 15/216
# Эпохи: 1200, Время: 0.6100c, MSE: 1.0631e+01
# Experiment 16/216
# Эпохи: 400, Время: 0.4340c, MSE: 6.6614e+02
# Experiment 17/216
# Эпохи: 800, Время: 0.6297c, MSE: 3.6400e+01
# Experiment 18/216
# Эпохи: 1200, Время: 0.6583c, MSE: 6.5241e+00
# Experiment 19/216
# Эпохи: 400, Время: 0.4806c, MSE: 7.1143e+02
# Experiment 20/216
# Эпохи: 800, Время: 0.4526c, MSE: 3.1701e+01
# Experiment 21/216
# Эпохи: 1200, Время: 0.6490c, MSE: 5.5457e+00
# Experiment 22/216
# Эпохи: 400, Время: 0.5947c, MSE: 7.1733e+02
# Experiment 23/216
# Эпохи: 800, Время: 0.6012c, MSE: 2.7806e+01
# Experiment 24/216
# Эпохи: 1200, Время: 0.7025c, MSE: 4.8247e+00
# Experiment 25/216
# Эпохи: 400, Время: 0.4533c, MSE: 4.1801e+04
# Experiment 26/216
# Эпохи: 800, Время: 0.5211c, MSE: 1.4446e+04
# Experiment 27/216
# Эпохи: 1200, Время: 0.4671c, MSE: 5.0254e+03
# Experiment 28/216
# Эпохи: 400, Время: 0.5255c, MSE: 4.1993e+04
# Experiment 29/216
# Эпохи: 800, Время: 0.4857c, MSE: 1.4609e+04
# Experiment 30/216
# Эпохи: 1200, Время: 0.5418c, MSE: 5.0371e+03
# Experiment 31/216
# Эпохи: 400, Время: 0.4287c, MSE: 4.2087e+04
# Experiment 32/216
# Эпохи: 800, Время: 0.4386c, MSE: 1.4700e+04
# Experiment 33/216
# Эпохи: 1200, Время: 0.5883c, MSE: 5.0384e+03
# Experiment 34/216
# Эпохи: 400, Время: 0.4070c, MSE: 4.2095e+04
# Experiment 35/216
# Эпохи: 800, Время: 0.4956c, MSE: 1.4708e+04
# Experiment 36/216
# Эпохи: 1200, Время: 0.6653c, MSE: 5.0385e+03
# Experiment 37/216
# Эпохи: 400, Время: 0.8974c, MSE: 1.1521e+03
# Experiment 38/216
# Эпохи: 800, Время: 0.6595c, MSE: 2.6236e+01
# Experiment 39/216
# Эпохи: 1200, Время: 0.9184c, MSE: 8.9305e+00
# Experiment 40/216
# Эпохи: 400, Время: 0.6385c, MSE: 9.6917e+02
# Experiment 41/216
# Эпохи: 800, Время: 0.9439c, MSE: 2.3907e+01
# Experiment 42/216
# Эпохи: 1200, Время: 0.7880c, MSE: 1.5212e+00
# Experiment 43/216
# Эпохи: 400, Время: 1.1604c, MSE: 9.8910e+02
# Experiment 44/216
# Эпохи: 800, Время: 1.1328c, MSE: 2.3742e+01
# Experiment 45/216
# Эпохи: 1200, Время: 1.4096c, MSE: 6.9982e-01
# Experiment 46/216
# Эпохи: 400, Время: 0.9376c, MSE: 9.9484e+02
# Experiment 47/216
# Эпохи: 800, Время: 1.0692c, MSE: 2.1191e+01
# Experiment 48/216
# Эпохи: 1200, Время: 1.2727c, MSE: 7.2638e-01
# Experiment 49/216
# Эпохи: 400, Время: 0.3136c, MSE: 2.3715e+03
# Experiment 50/216
# Эпохи: 800, Время: 0.3828c, MSE: 1.4225e+03
# Experiment 51/216
# Эпохи: 1200, Время: 0.6390c, MSE: 1.4225e+03
# Experiment 52/216
# Эпохи: 400, Время: 0.4163c, MSE: 2.3779e+03
# Experiment 53/216
# Эпохи: 800, Время: 0.3337c, MSE: 1.4041e+03
# Experiment 54/216
# Эпохи: 1200, Время: 0.4255c, MSE: 1.4041e+03
# Experiment 55/216
# Эпохи: 400, Время: 0.4173c, MSE: 2.3819e+03
# Experiment 56/216
# Эпохи: 800, Время: 0.5273c, MSE: 1.3929e+03
# Experiment 57/216
# Эпохи: 1200, Время: 0.3809c, MSE: 1.3929e+03
# Experiment 58/216
# Эпохи: 400, Время: 0.3554c, MSE: 2.3823e+03
# Experiment 59/216
# Эпохи: 800, Время: 0.5014c, MSE: 1.3918e+03
# Experiment 60/216
# Эпохи: 1200, Время: 0.5549c, MSE: 1.3918e+03
# Experiment 61/216
# Эпохи: 400, Время: 0.3733c, MSE: 4.1253e+04
# Experiment 62/216
# Эпохи: 800, Время: 0.6149c, MSE: 1.3314e+04
# Experiment 63/216
# Эпохи: 1200, Время: 0.8436c, MSE: 4.6477e+03
# Experiment 64/216
# Эпохи: 400, Время: 0.4943c, MSE: 4.1264e+04
# Experiment 65/216
# Эпохи: 800, Время: 0.7196c, MSE: 1.3341e+04
# Experiment 66/216
# Эпохи: 1200, Время: 1.0118c, MSE: 4.6723e+03
# Experiment 67/216
# Эпохи: 400, Время: 0.7080c, MSE: 4.1269e+04
# Experiment 68/216
# Эпохи: 800, Время: 0.6567c, MSE: 1.3357e+04
# Experiment 69/216
# Эпохи: 1200, Время: 1.0544c, MSE: 4.6907e+03
# Experiment 70/216
# Эпохи: 400, Время: 0.8472c, MSE: 4.1270e+04
# Experiment 71/216
# Эпохи: 800, Время: 0.5391c, MSE: 1.3358e+04
# Experiment 72/216
# Эпохи: 1200, Время: 0.7382c, MSE: 4.6921e+03
# Experiment 73/216
# Эпохи: 400, Время: 0.9565c, MSE: 4.5501e+04
# Experiment 74/216
# Эпохи: 800, Время: 0.8536c, MSE: 1.6393e+04
# Experiment 75/216
# Эпохи: 1200, Время: 1.1888c, MSE: 5.8041e+03
# Experiment 76/216
# Эпохи: 400, Время: 0.9116c, MSE: 4.5504e+04
# Experiment 77/216
# Эпохи: 800, Время: 1.1544c, MSE: 1.6395e+04
# Experiment 78/216
# Эпохи: 1200, Время: 1.3193c, MSE: 5.8048e+03
# Experiment 79/216
# Эпохи: 400, Время: 1.1581c, MSE: 4.5505e+04
# Experiment 80/216
# Эпохи: 800, Время: 1.3475c, MSE: 1.6396e+04
# Experiment 81/216
# Эпохи: 1200, Время: 1.1806c, MSE: 5.8051e+03
# Experiment 82/216
# Эпохи: 400, Время: 1.2847c, MSE: 4.5505e+04
# Experiment 83/216
# Эпохи: 800, Время: 1.1055c, MSE: 1.6396e+04
# Experiment 84/216
# Эпохи: 1200, Время: 1.5991c, MSE: 5.8051e+03
# Experiment 85/216
# Эпохи: 400, Время: 0.9094c, MSE: 9.4408e+00
# Experiment 86/216
# Эпохи: 800, Время: 1.2248c, MSE: 7.7898e+00
# Experiment 87/216
# Эпохи: 1200, Время: 1.1703c, MSE: 7.2621e+00
# Experiment 88/216
# Эпохи: 400, Время: 0.7469c, MSE: 7.7007e-02
# Experiment 89/216
# Эпохи: 800, Время: 1.0290c, MSE: 2.2458e-02
# Experiment 90/216
# Эпохи: 1200, Время: 1.1509c, MSE: 9.7413e-03
# Experiment 91/216
# Эпохи: 400, Время: 0.7317c, MSE: 5.3616e-02
# Experiment 92/216
# Эпохи: 800, Время: 1.1243c, MSE: 1.5297e-02
# Experiment 93/216
# Эпохи: 1200, Время: 1.1163c, MSE: 1.5438e-01
# Experiment 94/216
# Эпохи: 400, Время: 0.7661c, MSE: 7.2288e-03
# Experiment 95/216
# Эпохи: 800, Время: 0.8457c, MSE: 5.0113e-02
# Experiment 96/216
# Эпохи: 1200, Время: 1.0320c, MSE: 2.6151e-01
# Experiment 97/216
# Эпохи: 400, Время: 0.7660c, MSE: 4.5760e+04
# Experiment 98/216
# Эпохи: 800, Время: 0.7378c, MSE: 1.7160e+04
# Experiment 99/216
# Эпохи: 1200, Время: 0.9252c, MSE: 5.7196e+03
# Experiment 100/216
# Эпохи: 400, Время: 0.7121c, MSE: 4.5419e+04
# Experiment 101/216
# Эпохи: 800, Время: 0.8731c, MSE: 1.7126e+04
# Experiment 102/216
# Эпохи: 1200, Время: 1.0902c, MSE: 5.4933e+03
# Experiment 103/216
# Эпохи: 400, Время: 0.6433c, MSE: 4.5401e+04
# Experiment 104/216
# Эпохи: 800, Время: 0.9956c, MSE: 1.6956e+04
# Experiment 105/216
# Эпохи: 1200, Время: 1.0322c, MSE: 5.4766e+03
# Experiment 106/216
# Эпохи: 400, Время: 0.8626c, MSE: 4.5392e+04
# Experiment 107/216
# Эпохи: 800, Время: 1.0685c, MSE: 1.6903e+04
# Experiment 108/216
# Эпохи: 1200, Время: 1.5034c, MSE: 5.6057e+03
# Experiment 109/216
# Эпохи: 400, Время: 1.6303c, MSE: 2.2617e+00
# Experiment 110/216
# Эпохи: 800, Время: 1.7320c, MSE: 1.4892e+00
# Experiment 111/216
# Эпохи: 1200, Время: 1.6907c, MSE: 1.0478e+00
# Experiment 112/216
# Эпохи: 400, Время: 1.8886c, MSE: 1.5039e-02
# Experiment 113/216
# Эпохи: 800, Время: 2.0355c, MSE: 5.6464e-03
# Experiment 114/216
# Эпохи: 1200, Время: 1.4598c, MSE: 4.1234e-03
# Experiment 115/216
# Эпохи: 400, Время: 1.2565c, MSE: 2.6200e-03
# Experiment 116/216
# Эпохи: 800, Время: 1.7243c, MSE: 1.0162e-04
# Experiment 117/216
# Эпохи: 1200, Время: 1.8027c, MSE: 5.7060e-05
# Experiment 118/216
# Эпохи: 400, Время: 1.4441c, MSE: 3.4391e-03
# Experiment 119/216
# Эпохи: 800, Время: 1.3953c, MSE: 1.8145e-02
# Experiment 120/216
# Эпохи: 1200, Время: 1.8524c, MSE: 9.6040e-05
# Experiment 121/216
# Эпохи: 400, Время: 0.5700c, MSE: 1.3960e+03
# Experiment 122/216
# Эпохи: 800, Время: 0.6739c, MSE: 1.3960e+03
# Experiment 123/216
# Эпохи: 1200, Время: 0.9884c, MSE: 1.3960e+03
# Experiment 124/216
# Эпохи: 400, Время: 0.7350c, MSE: 1.4041e+03
# Experiment 125/216
# Эпохи: 800, Время: 0.8975c, MSE: 1.4041e+03
# Experiment 126/216
# Эпохи: 1200, Время: 0.8558c, MSE: 1.4041e+03
# Experiment 127/216
# Эпохи: 400, Время: 0.7528c, MSE: 1.3929e+03
# Experiment 128/216
# Эпохи: 800, Время: 0.8611c, MSE: 1.3929e+03
# Experiment 129/216
# Эпохи: 1200, Время: 1.0234c, MSE: 1.3929e+03
# Experiment 130/216
# Эпохи: 400, Время: 0.7431c, MSE: 1.3918e+03
# Experiment 131/216
# Эпохи: 800, Время: 0.8100c, MSE: 1.3918e+03
# Experiment 132/216
# Эпохи: 1200, Время: 0.9011c, MSE: 1.3918e+03
# Experiment 133/216
# Эпохи: 400, Время: 0.9455c, MSE: 4.8367e+04
# Experiment 134/216
# Эпохи: 800, Время: 0.8897c, MSE: 1.6903e+04
# Experiment 135/216
# Эпохи: 1200, Время: 1.0116c, MSE: 5.6631e+03
# Experiment 136/216
# Эпохи: 400, Время: 0.7650c, MSE: 4.8367e+04
# Experiment 137/216
# Эпохи: 800, Время: 1.0643c, MSE: 1.6903e+04
# Experiment 138/216
# Эпохи: 1200, Время: 1.0619c, MSE: 5.6631e+03
# Experiment 139/216
# Эпохи: 400, Время: 0.6521c, MSE: 4.8367e+04
# Experiment 140/216
# Эпохи: 800, Время: 0.8455c, MSE: 1.6903e+04
# Experiment 141/216
# Эпохи: 1200, Время: 0.9424c, MSE: 5.6630e+03
# Experiment 142/216
# Эпохи: 400, Время: 0.8154c, MSE: 4.8367e+04
# Experiment 143/216
# Эпохи: 800, Время: 0.8388c, MSE: 1.6903e+04
# Experiment 144/216
# Эпохи: 1200, Время: 0.9327c, MSE: 5.6630e+03
# Experiment 145/216
# Эпохи: 400, Время: 0.9141c, MSE: 4.5518e+04
# Experiment 146/216
# Эпохи: 800, Время: 1.1212c, MSE: 1.6435e+04
# Experiment 147/216
# Эпохи: 1200, Время: 1.1626c, MSE: 5.8253e+03
# Experiment 148/216
# Эпохи: 400, Время: 1.2559c, MSE: 4.5518e+04
# Experiment 149/216
# Эпохи: 800, Время: 1.4133c, MSE: 1.6435e+04
# Experiment 150/216
# Эпохи: 1200, Время: 1.7702c, MSE: 5.8253e+03
# Experiment 151/216
# Эпохи: 400, Время: 1.3222c, MSE: 4.5518e+04
# Experiment 152/216
# Эпохи: 800, Время: 1.4718c, MSE: 1.6435e+04
# Experiment 153/216
# Эпохи: 1200, Время: 1.6539c, MSE: 5.8253e+03
# Experiment 154/216
# Эпохи: 400, Время: 1.7036c, MSE: 4.5518e+04
# Experiment 155/216
# Эпохи: 800, Время: 1.8210c, MSE: 1.6435e+04
# Experiment 156/216
# Эпохи: 1200, Время: 2.1673c, MSE: 5.8254e+03
# Experiment 157/216
# Эпохи: 400, Время: 1.7192c, MSE: 5.1246e-01
# Experiment 158/216
# Эпохи: 800, Время: 1.6943c, MSE: 9.5182e-02
# Experiment 159/216
# Эпохи: 1200, Время: 1.7883c, MSE: 1.5176e-03
# Experiment 160/216
# Эпохи: 400, Время: 1.4261c, MSE: 5.8137e-02
# Experiment 161/216
# Эпохи: 800, Время: 1.6620c, MSE: 4.4169e-02
# Experiment 162/216
# Эпохи: 1200, Время: 1.5505c, MSE: 3.5624e-02
# Experiment 163/216
# Эпохи: 400, Время: 1.1525c, MSE: 2.4913e+00
# Experiment 164/216
# Эпохи: 800, Время: 1.1275c, MSE: 1.3704e-04
# Experiment 165/216
# Эпохи: 1200, Время: 1.1603c, MSE: 2.8856e-01
# Experiment 166/216
# Эпохи: 400, Время: 1.0645c, MSE: 3.4768e-03
# Experiment 167/216
# Эпохи: 800, Время: 1.1768c, MSE: 1.6155e-04
# Experiment 168/216
# Эпохи: 1200, Время: 1.4190c, MSE: 2.8714e-02
# Experiment 169/216
# Эпохи: 400, Время: 0.9476c, MSE: 4.6171e+04
# Experiment 170/216
# Эпохи: 800, Время: 1.0028c, MSE: 1.7780e+04
# Experiment 171/216
# Эпохи: 1200, Время: 1.1666c, MSE: 6.1095e+03
# Experiment 172/216
# Эпохи: 400, Время: 0.9739c, MSE: 4.5865e+04
# Experiment 173/216
# Эпохи: 800, Время: 1.1894c, MSE: 1.7483e+04
# Experiment 174/216
# Эпохи: 1200, Время: 1.5082c, MSE: 5.5235e+03
# Experiment 175/216
# Эпохи: 400, Время: 0.8742c, MSE: 4.5761e+04
# Experiment 176/216
# Эпохи: 800, Время: 1.2023c, MSE: 1.8278e+04
# Experiment 177/216
# Эпохи: 1200, Время: 1.4829c, MSE: 5.7960e+03
# Experiment 178/216
# Эпохи: 400, Время: 1.1422c, MSE: 4.5915e+04
# Experiment 179/216
# Эпохи: 800, Время: 1.6962c, MSE: 1.7506e+04
# Experiment 180/216
# Эпохи: 1200, Время: 2.0428c, MSE: 5.6238e+03
# Experiment 181/216
# Эпохи: 400, Время: 1.3569c, MSE: 9.6661e-02
# Experiment 182/216
# Эпохи: 800, Время: 1.6668c, MSE: 2.7371e-02
# Experiment 183/216
# Эпохи: 1200, Время: 1.4996c, MSE: 4.9357e-01
# Experiment 184/216
# Эпохи: 400, Время: 1.4698c, MSE: 1.2342e-01
# Experiment 185/216
# Эпохи: 800, Время: 1.5619c, MSE: 1.1087e-04
# Experiment 186/216
# Эпохи: 1200, Время: 1.7235c, MSE: 4.2812e-04
# Experiment 187/216
# Эпохи: 400, Время: 1.4291c, MSE: 1.6237e-02
# Experiment 188/216
# Эпохи: 800, Время: 1.5725c, MSE: 6.8583e-05
# Experiment 189/216
# Эпохи: 1200, Время: 1.9170c, MSE: 5.0801e-03
# Experiment 190/216
# Эпохи: 400, Время: 1.6294c, MSE: 2.1442e-03
# Experiment 191/216
# Эпохи: 800, Время: 1.7872c, MSE: 3.3871e-04
# Experiment 192/216
# Эпохи: 1200, Время: 2.2224c, MSE: 1.1436e-04
# Experiment 193/216
# Эпохи: 400, Время: 0.5621c, MSE: 1.4224e+03
# Experiment 194/216
# Эпохи: 800, Время: 0.7477c, MSE: 1.4224e+03
# Experiment 195/216
# Эпохи: 1200, Время: 0.8731c, MSE: 1.4224e+03
# Experiment 196/216
# Эпохи: 400, Время: 0.6445c, MSE: 1.4041e+03
# Experiment 197/216
# Эпохи: 800, Время: 0.8727c, MSE: 1.4041e+03
# Experiment 198/216
# Эпохи: 1200, Время: 0.9593c, MSE: 1.4041e+03
# Experiment 199/216
# Эпохи: 400, Время: 0.7465c, MSE: 1.3929e+03
# Experiment 200/216
# Эпохи: 800, Время: 0.8586c, MSE: 1.3929e+03
# Experiment 201/216
# Эпохи: 1200, Время: 0.8888c, MSE: 1.3929e+03
# Experiment 202/216
# Эпохи: 400, Время: 0.6275c, MSE: 1.3918e+03
# Experiment 203/216
# Эпохи: 800, Время: 1.0343c, MSE: 1.3918e+03
# Experiment 204/216
# Эпохи: 1200, Время: 0.9382c, MSE: 1.3918e+03
# Experiment 205/216
# Эпохи: 400, Время: 1.0329c, MSE: 5.1566e+04
# Experiment 206/216
# Эпохи: 800, Время: 1.0088c, MSE: 1.9178e+04
# Experiment 207/216
# Эпохи: 1200, Время: 1.2014c, MSE: 7.0842e+03
# Experiment 208/216
# Эпохи: 400, Время: 1.0937c, MSE: 5.1566e+04
# Experiment 209/216
# Эпохи: 800, Время: 0.9536c, MSE: 1.9178e+04
# Experiment 210/216
# Эпохи: 1200, Время: 1.0922c, MSE: 7.0842e+03
# Experiment 211/216
# Эпохи: 400, Время: 0.9193c, MSE: 5.1566e+04
# Experiment 212/216
# Эпохи: 800, Время: 0.8619c, MSE: 1.9178e+04
# Experiment 213/216
# Эпохи: 1200, Время: 0.9959c, MSE: 7.0842e+03
# Experiment 214/216
# Эпохи: 400, Время: 0.9346c, MSE: 5.1566e+04
# Experiment 215/216
# Эпохи: 800, Время: 1.1021c, MSE: 1.9178e+04
# Experiment 216/216
# Эпохи: 1200, Время: 1.1448c, MSE: 7.0842e+03
# Experiment 217/216
# Эпохи: 400, Время: 0.4218c, MSE: 1.2598e+04
# Experiment 218/216
# Эпохи: 800, Время: 0.4926c, MSE: 1.9901e+03
# Experiment 219/216
# Эпохи: 1200, Время: 0.5153c, MSE: 4.8777e+01
# Experiment 220/216
# Эпохи: 400, Время: 0.4342c, MSE: 1.2771e+04
# Experiment 221/216
# Эпохи: 800, Время: 0.5700c, MSE: 1.8789e+03
# Experiment 222/216
# Эпохи: 1200, Время: 0.5084c, MSE: 4.2356e+01
# Experiment 223/216
# Эпохи: 400, Время: 0.4509c, MSE: 1.2863e+04
# Experiment 224/216
# Эпохи: 800, Время: 0.5882c, MSE: 1.9911e+03
# Experiment 225/216
# Эпохи: 1200, Время: 0.6064c, MSE: 3.9102e+01
# Experiment 226/216
# Эпохи: 400, Время: 0.4139c, MSE: 1.2873e+04
# Experiment 227/216
# Эпохи: 800, Время: 0.5023c, MSE: 1.9918e+03
# Experiment 228/216
# Эпохи: 1200, Время: 0.6362c, MSE: 3.9229e+01
# Experiment 229/216
# Эпохи: 400, Время: 0.5068c, MSE: 6.0719e+02
# Experiment 230/216
# Эпохи: 800, Время: 0.5934c, MSE: 1.5653e+01
# Experiment 231/216
# Эпохи: 1200, Время: 0.5623c, MSE: 2.3965e+00
# Experiment 232/216
# Эпохи: 400, Время: 0.5380c, MSE: 4.8749e+02
# Experiment 233/216
# Эпохи: 800, Время: 0.5410c, MSE: 1.2552e+01
# Experiment 234/216
# Эпохи: 1200, Время: 0.5891c, MSE: 1.4873e+00
# Experiment 235/216
# Эпохи: 400, Время: 0.5540c, MSE: 5.1472e+02
# Experiment 236/216
# Эпохи: 800, Время: 0.4646c, MSE: 1.0337e+01
# Experiment 237/216
# Эпохи: 1200, Время: 0.6015c, MSE: 1.1692e+00
# Experiment 238/216
# Эпохи: 400, Время: 0.5813c, MSE: 5.1291e+02
# Experiment 239/216
# Эпохи: 800, Время: 0.7580c, MSE: 9.1813e+00
# Experiment 240/216
# Эпохи: 1200, Время: 0.5353c, MSE: 8.7946e-01
# Experiment 241/216
# Эпохи: 400, Время: 0.5522c, MSE: 1.2820e+04
# Experiment 242/216
# Эпохи: 800, Время: 0.5749c, MSE: 2.2847e+03
# Experiment 243/216
# Эпохи: 1200, Время: 0.5504c, MSE: 1.5805e+03
# Experiment 244/216
# Эпохи: 400, Время: 0.5177c, MSE: 1.3110e+04
# Experiment 245/216
# Эпохи: 800, Время: 0.3808c, MSE: 2.2378e+03
# Experiment 246/216
# Эпохи: 1200, Время: 0.5344c, MSE: 1.5010e+03
# Experiment 247/216
# Эпохи: 400, Время: 0.3464c, MSE: 1.3262e+04
# Experiment 248/216
# Эпохи: 800, Время: 0.5356c, MSE: 2.1960e+03
# Experiment 249/216
# Эпохи: 1200, Время: 0.5971c, MSE: 1.4221e+03
# Experiment 250/216
# Эпохи: 400, Время: 0.4045c, MSE: 1.3275e+04
# Experiment 251/216
# Эпохи: 800, Время: 0.5469c, MSE: 2.1918e+03
# Experiment 252/216
# Эпохи: 1200, Время: 0.7438c, MSE: 1.4136e+03
# Experiment 253/216
# Эпохи: 400, Время: 0.6130c, MSE: 6.0131e+02
# Experiment 254/216
# Эпохи: 800, Время: 0.5761c, MSE: 1.2335e+01
# Experiment 255/216
# Эпохи: 1200, Время: 0.8692c, MSE: 7.2119e+00
# Experiment 256/216
# Эпохи: 400, Время: 0.5828c, MSE: 4.9936e+02
# Experiment 257/216
# Эпохи: 800, Время: 0.6327c, MSE: 7.7431e+00
# Experiment 258/216
# Эпохи: 1200, Время: 0.7798c, MSE: 1.5542e+00
# Experiment 259/216
# Эпохи: 400, Время: 1.0392c, MSE: 5.1370e+02
# Experiment 260/216
# Эпохи: 800, Время: 0.6376c, MSE: 7.8055e+00
# Experiment 261/216
# Эпохи: 1200, Время: 0.8576c, MSE: 6.9599e-01
# Experiment 262/216
# Эпохи: 400, Время: 0.5920c, MSE: 4.9433e+02
# Experiment 263/216
# Эпохи: 800, Время: 0.6689c, MSE: 6.4706e+00
# Experiment 264/216
# Эпохи: 1200, Время: 1.0185c, MSE: 7.1449e-01
# Experiment 265/216
# Эпохи: 400, Время: 0.3241c, MSE: 1.4217e+03
# Experiment 266/216
# Эпохи: 800, Время: 0.5255c, MSE: 1.4224e+03
# Experiment 267/216
# Эпохи: 1200, Время: 0.4428c, MSE: 1.4224e+03
# Experiment 268/216
# Эпохи: 400, Время: 0.4398c, MSE: 1.4033e+03
# Experiment 269/216
# Эпохи: 800, Время: 0.3363c, MSE: 1.4041e+03
# Experiment 270/216
# Эпохи: 1200, Время: 0.5435c, MSE: 1.4041e+03
# Experiment 271/216
# Эпохи: 400, Время: 0.3152c, MSE: 1.3922e+03
# Experiment 272/216
# Эпохи: 800, Время: 0.3633c, MSE: 1.3929e+03
# Experiment 273/216
# Эпохи: 1200, Время: 0.3953c, MSE: 1.3929e+03
# Experiment 274/216
# Эпохи: 400, Время: 0.3188c, MSE: 1.3910e+03
# Experiment 275/216
# Эпохи: 800, Время: 0.4675c, MSE: 1.3918e+03
# Experiment 276/216
# Эпохи: 1200, Время: 0.3978c, MSE: 1.3918e+03
# Experiment 277/216
# Эпохи: 400, Время: 0.3647c, MSE: 1.2830e+04
# Experiment 278/216
# Эпохи: 800, Время: 0.6938c, MSE: 2.0782e+03
# Experiment 279/216
# Эпохи: 1200, Время: 0.4655c, MSE: 1.3052e+03
# Experiment 280/216
# Эпохи: 400, Время: 0.3796c, MSE: 1.2850e+04
# Experiment 281/216
# Эпохи: 800, Время: 0.4336c, MSE: 2.0351e+03
# Experiment 282/216
# Эпохи: 1200, Время: 0.5679c, MSE: 1.0190e+03
# Experiment 283/216
# Эпохи: 400, Время: 0.3717c, MSE: 1.2864e+04
# Experiment 284/216
# Эпохи: 800, Время: 0.4138c, MSE: 2.0058e+03
# Experiment 285/216
# Эпохи: 1200, Время: 0.4546c, MSE: 9.3312e+02
# Experiment 286/216
# Эпохи: 400, Время: 0.5203c, MSE: 1.2865e+04
# Experiment 287/216
# Эпохи: 800, Время: 0.4236c, MSE: 2.0005e+03
# Experiment 288/216
# Эпохи: 1200, Время: 0.4646c, MSE: 8.9988e+02
# Experiment 289/216
# Эпохи: 400, Время: 0.7695c, MSE: 1.6546e+04
# Experiment 290/216
# Эпохи: 800, Время: 0.8299c, MSE: 2.8723e+03
# Experiment 291/216
# Эпохи: 1200, Время: 0.8259c, MSE: 1.7077e+03
# Experiment 292/216
# Эпохи: 400, Время: 0.9788c, MSE: 1.6549e+04
# Experiment 293/216
# Эпохи: 800, Время: 0.7718c, MSE: 2.8727e+03
# Experiment 294/216
# Эпохи: 1200, Время: 0.9242c, MSE: 1.7077e+03
# Experiment 295/216
# Эпохи: 400, Время: 0.6311c, MSE: 1.6550e+04
# Experiment 296/216
# Эпохи: 800, Время: 0.9013c, MSE: 2.8729e+03
# Experiment 297/216
# Эпохи: 1200, Время: 1.0208c, MSE: 1.7077e+03
# Experiment 298/216
# Эпохи: 400, Время: 0.7518c, MSE: 1.6550e+04
# Experiment 299/216
# Эпохи: 800, Время: 1.0583c, MSE: 2.8730e+03
# Experiment 300/216
# Эпохи: 1200, Время: 1.1160c, MSE: 1.7077e+03
# Experiment 301/216
# Эпохи: 400, Время: 0.8108c, MSE: 6.7200e+00
# Experiment 302/216
# Эпохи: 800, Время: 0.8981c, MSE: 6.9617e+00
# Experiment 303/216
# Эпохи: 1200, Время: 1.0250c, MSE: 2.9017e+00
# Experiment 304/216
# Эпохи: 400, Время: 0.7019c, MSE: 2.6997e-02
# Experiment 305/216
# Эпохи: 800, Время: 1.0706c, MSE: 1.2471e-01
# Experiment 306/216
# Эпохи: 1200, Время: 0.8773c, MSE: 1.3648e-03
# Experiment 307/216
# Эпохи: 400, Время: 1.0716c, MSE: 1.1043e-02
# Experiment 308/216
# Эпохи: 800, Время: 0.9791c, MSE: 1.1139e-02
# Experiment 309/216
# Эпохи: 1200, Время: 1.1387c, MSE: 5.8586e-04
# Experiment 310/216
# Эпохи: 400, Время: 1.0344c, MSE: 3.0497e-02
# Experiment 311/216
# Эпохи: 800, Время: 1.0372c, MSE: 1.2848e-02
# Experiment 312/216
# Эпохи: 1200, Время: 1.5340c, MSE: 1.1551e-02
# Experiment 313/216
# Эпохи: 400, Время: 0.7913c, MSE: 1.6751e+04
# Experiment 314/216
# Эпохи: 800, Время: 1.2664c, MSE: 1.9873e+03
# Experiment 315/216
# Эпохи: 1200, Время: 1.3124c, MSE: 2.3563e+02
# Experiment 316/216
# Эпохи: 400, Время: 0.9900c, MSE: 1.6794e+04
# Experiment 317/216
# Эпохи: 800, Время: 1.3290c, MSE: 1.7169e+03
# Experiment 318/216
# Эпохи: 1200, Время: 1.4559c, MSE: 7.2224e+01
# Experiment 319/216
# Эпохи: 400, Время: 0.9163c, MSE: 1.7476e+04
# Experiment 320/216
# Эпохи: 800, Время: 1.2216c, MSE: 1.8788e+03
# Experiment 321/216
# Эпохи: 1200, Время: 1.4992c, MSE: 6.9284e+01
# Experiment 322/216
# Эпохи: 400, Время: 1.0441c, MSE: 1.6547e+04
# Experiment 323/216
# Эпохи: 800, Время: 1.6675c, MSE: 1.6470e+03
# Experiment 324/216
# Эпохи: 1200, Время: 2.0982c, MSE: 6.7879e+01
# Experiment 325/216
# Эпохи: 400, Время: 1.0702c, MSE: 9.0299e+00
# Experiment 326/216
# Эпохи: 800, Время: 1.0364c, MSE: 3.5514e+00
# Experiment 327/216
# Эпохи: 1200, Время: 1.0967c, MSE: 2.6553e+00
# Experiment 328/216
# Эпохи: 400, Время: 1.1706c, MSE: 3.0641e-02
# Experiment 329/216
# Эпохи: 800, Время: 1.2244c, MSE: 1.4644e-01
# Experiment 330/216
# Эпохи: 1200, Время: 1.3721c, MSE: 1.7294e-02
# Experiment 331/216
# Эпохи: 400, Время: 0.9929c, MSE: 1.0494e-02
# Experiment 332/216
# Эпохи: 800, Время: 1.4151c, MSE: 5.6866e-04
# Experiment 333/216
# Эпохи: 1200, Время: 1.4021c, MSE: 1.4600e-04
# Experiment 334/216
# Эпохи: 400, Время: 1.4991c, MSE: 1.5829e-02
# Experiment 335/216
# Эпохи: 800, Время: 1.6598c, MSE: 9.3624e-02
# Experiment 336/216
# Эпохи: 1200, Время: 1.7567c, MSE: 1.3772e-01
# Experiment 337/216
# Эпохи: 400, Время: 0.4088c, MSE: 1.4224e+03
# Experiment 338/216
# Эпохи: 800, Время: 0.6351c, MSE: 1.4224e+03
# Experiment 339/216
# Эпохи: 1200, Время: 0.6574c, MSE: 1.4224e+03
# Experiment 340/216
# Эпохи: 400, Время: 0.4330c, MSE: 1.4041e+03
# Experiment 341/216
# Эпохи: 800, Время: 0.4885c, MSE: 1.4041e+03
# Experiment 342/216
# Эпохи: 1200, Время: 0.6589c, MSE: 1.4041e+03
# Experiment 343/216
# Эпохи: 400, Время: 0.3933c, MSE: 1.3929e+03
# Experiment 344/216
# Эпохи: 800, Время: 0.5481c, MSE: 1.3929e+03
# Experiment 345/216
# Эпохи: 1200, Время: 0.5178c, MSE: 1.3929e+03
# Experiment 346/216
# Эпохи: 400, Время: 0.3880c, MSE: 1.3918e+03
# Experiment 347/216
# Эпохи: 800, Время: 0.6711c, MSE: 1.3918e+03
# Experiment 348/216
# Эпохи: 1200, Время: 0.5148c, MSE: 1.3918e+03
# Experiment 349/216
# Эпохи: 400, Время: 0.5497c, MSE: 2.2149e+04
# Experiment 350/216
# Эпохи: 800, Время: 0.7253c, MSE: 4.6896e+03
# Experiment 351/216
# Эпохи: 1200, Время: 0.6864c, MSE: 1.0615e+03
# Experiment 352/216
# Эпохи: 400, Время: 0.6368c, MSE: 2.2149e+04
# Experiment 353/216
# Эпохи: 800, Время: 0.6943c, MSE: 4.9348e+03
# Experiment 354/216
# Эпохи: 1200, Время: 0.8150c, MSE: 2.7156e+02
# Experiment 355/216
# Эпохи: 400, Время: 0.5734c, MSE: 2.2149e+04
# Experiment 356/216
# Эпохи: 800, Время: 0.6575c, MSE: 4.5558e+03
# Experiment 357/216
# Эпохи: 1200, Время: 0.9013c, MSE: 2.0297e+02
# Experiment 358/216
# Эпохи: 400, Время: 0.7192c, MSE: 2.2149e+04
# Experiment 359/216
# Эпохи: 800, Время: 0.9614c, MSE: 4.7027e+03
# Experiment 360/216
# Эпохи: 1200, Время: 1.4396c, MSE: 2.1947e+02
# Experiment 361/216
# Эпохи: 400, Время: 0.7947c, MSE: 1.6551e+04
# Experiment 362/216
# Эпохи: 800, Время: 1.0367c, MSE: 2.8768e+03
# Experiment 363/216
# Эпохи: 1200, Время: 1.1457c, MSE: 4.3826e+03
# Experiment 364/216
# Эпохи: 400, Время: 0.9171c, MSE: 1.6551e+04
# Experiment 365/216
# Эпохи: 800, Время: 1.2267c, MSE: 2.8768e+03
# Experiment 366/216
# Эпохи: 1200, Время: 1.4043c, MSE: 3.9238e+03
# Experiment 367/216
# Эпохи: 400, Время: 0.8641c, MSE: 1.6551e+04
# Experiment 368/216
# Эпохи: 800, Время: 1.1122c, MSE: 2.8768e+03
# Experiment 369/216
# Эпохи: 1200, Время: 1.4965c, MSE: 8.6829e+03
# Experiment 370/216
# Эпохи: 400, Время: 1.0785c, MSE: 1.6551e+04
# Experiment 371/216
# Эпохи: 800, Время: 1.4817c, MSE: 2.8768e+03
# Experiment 372/216
# Эпохи: 1200, Время: 2.0107c, MSE: 5.2305e+03
# Experiment 373/216
# Эпохи: 400, Время: 1.1998c, MSE: 3.1116e-01
# Experiment 374/216
# Эпохи: 800, Время: 1.3750c, MSE: 2.1682e+00
# Experiment 375/216
# Эпохи: 1200, Время: 1.4003c, MSE: 3.2395e-01
# Experiment 376/216
# Эпохи: 400, Время: 0.9562c, MSE: 4.9369e-01
# Experiment 377/216
# Эпохи: 800, Время: 1.3684c, MSE: 3.7745e-02
# Experiment 378/216
# Эпохи: 1200, Время: 1.5847c, MSE: 3.5753e-02
# Experiment 379/216
# Эпохи: 400, Время: 1.2195c, MSE: 9.3427e-02
# Experiment 380/216
# Эпохи: 800, Время: 1.3753c, MSE: 5.6893e-02
# Experiment 381/216
# Эпохи: 1200, Время: 1.8282c, MSE: 1.0577e-03
# Experiment 382/216
# Эпохи: 400, Время: 1.7459c, MSE: 5.3241e-03
# Experiment 383/216
# Эпохи: 800, Время: 2.6631c, MSE: 4.2469e-01
# Experiment 384/216
# Эпохи: 1200, Время: 2.5450c, MSE: 8.0237e-02
# Experiment 385/216
# Эпохи: 400, Время: 1.1415c, MSE: 2.0913e+04
# Experiment 386/216
# Эпохи: 800, Время: 1.3549c, MSE: 3.4091e+03
# Experiment 387/216
# Эпохи: 1200, Время: 1.5084c, MSE: 3.1354e+02
# Experiment 388/216
# Эпохи: 400, Время: 1.0843c, MSE: 1.7618e+04
# Experiment 389/216
# Эпохи: 800, Время: 1.5266c, MSE: 1.7286e+03
# Experiment 390/216
# Эпохи: 1200, Время: 1.8143c, MSE: 7.9668e+01
# Experiment 391/216
# Эпохи: 400, Время: 1.3168c, MSE: 2.2796e+04
# Experiment 392/216
# Эпохи: 800, Время: 1.6618c, MSE: 4.7576e+03
# Experiment 393/216
# Эпохи: 1200, Время: 2.3679c, MSE: 5.6725e+02
# Experiment 394/216
# Эпохи: 400, Время: 1.7868c, MSE: 1.7864e+04
# Experiment 395/216
# Эпохи: 800, Время: 2.6513c, MSE: 2.6263e+03
# Experiment 396/216
# Эпохи: 1200, Время: 3.7341c, MSE: 1.5776e+02
# Experiment 397/216
# Эпохи: 400, Время: 1.5506c, MSE: 3.3744e+00
# Experiment 398/216
# Эпохи: 800, Время: 1.6776c, MSE: 4.1868e-02
# Experiment 399/216
# Эпохи: 1200, Время: 1.7120c, MSE: 3.0408e-01
# Experiment 400/216
# Эпохи: 400, Время: 1.5538c, MSE: 3.5639e-03
# Experiment 401/216
# Эпохи: 800, Время: 1.8880c, MSE: 1.2372e+00
# Experiment 402/216
# Эпохи: 1200, Время: 2.0685c, MSE: 1.5345e-01
# Experiment 403/216
# Эпохи: 400, Время: 1.5683c, MSE: 4.1201e-02
# Experiment 404/216
# Эпохи: 800, Время: 1.7942c, MSE: 2.2232e-03
# Experiment 405/216
# Эпохи: 1200, Время: 2.0637c, MSE: 2.7192e-02
# Experiment 406/216
# Эпохи: 400, Время: 1.8718c, MSE: 1.5413e-02
# Experiment 407/216
# Эпохи: 800, Время: 2.4079c, MSE: 4.0153e-01
# Experiment 408/216
# Эпохи: 1200, Время: 2.9345c, MSE: 5.5632e-02
# Experiment 409/216
# Эпохи: 400, Время: 0.6630c, MSE: 1.4325e+03
# Experiment 410/216
# Эпохи: 800, Время: 0.5709c, MSE: 1.3417e+03
# Experiment 411/216
# Эпохи: 1200, Время: 0.6858c, MSE: 1.3953e+03
# Experiment 412/216
# Эпохи: 400, Время: 0.5819c, MSE: 1.4041e+03
# Experiment 413/216
# Эпохи: 800, Время: 0.6604c, MSE: 1.4186e+03
# Experiment 414/216
# Эпохи: 1200, Время: 0.7023c, MSE: 1.4041e+03
# Experiment 415/216
# Эпохи: 400, Время: 0.5578c, MSE: 1.3929e+03
# Experiment 416/216
# Эпохи: 800, Время: 0.6514c, MSE: 1.6436e+03
# Experiment 417/216
# Эпохи: 1200, Время: 0.7148c, MSE: 1.3496e+03
# Experiment 418/216
# Эпохи: 400, Время: 0.6562c, MSE: 1.3918e+03
# Experiment 419/216
# Эпохи: 800, Время: 0.6786c, MSE: 1.3918e+03
# Experiment 420/216
# Эпохи: 1200, Время: 0.7837c, MSE: 1.3941e+03
# Experiment 421/216
# Эпохи: 400, Время: 0.8833c, MSE: 2.9649e+04
# Experiment 422/216
# Эпохи: 800, Время: 0.9469c, MSE: 6.0526e+03
# Experiment 423/216
# Эпохи: 1200, Время: 1.0864c, MSE: 2.0345e+03
# Experiment 424/216
# Эпохи: 400, Время: 0.7604c, MSE: 2.9649e+04
# Experiment 425/216
# Эпохи: 800, Время: 0.9442c, MSE: 6.0526e+03
# Experiment 426/216
# Эпохи: 1200, Время: 1.0859c, MSE: 2.0345e+03
# Experiment 427/216
# Эпохи: 400, Время: 0.8242c, MSE: 2.9649e+04
# Experiment 428/216
# Эпохи: 800, Время: 0.9644c, MSE: 6.0526e+03
# Experiment 429/216
# Эпохи: 1200, Время: 1.1630c, MSE: 2.0345e+03
# Experiment 430/216
# Эпохи: 400, Время: 1.0485c, MSE: 2.9649e+04
# Experiment 431/216
# Эпохи: 800, Время: 1.2337c, MSE: 6.0526e+03
# Experiment 432/216
# Эпохи: 1200, Время: 1.5882c, MSE: 2.0345e+03
# Experiment 433/216
# Эпохи: 400, Время: 0.4359c, MSE: 1.5452e+03
# Experiment 434/216
# Эпохи: 800, Время: 0.4719c, MSE: 1.7342e+01
# Experiment 435/216
# Эпохи: 1200, Время: 0.5168c, MSE: 4.2662e-01
# Experiment 436/216
# Эпохи: 400, Время: 0.4616c, MSE: 1.5605e+03
# Experiment 437/216
# Эпохи: 800, Время: 0.4952c, MSE: 8.1540e+00
# Experiment 438/216
# Эпохи: 1200, Время: 0.4837c, MSE: 6.5917e-03
# Experiment 439/216
# Эпохи: 400, Время: 0.4760c, MSE: 1.5490e+03
# Experiment 440/216
# Эпохи: 800, Время: 0.4576c, MSE: 7.7559e+00
# Experiment 441/216
# Эпохи: 1200, Время: 0.4974c, MSE: 4.8401e-02
# Experiment 442/216
# Эпохи: 400, Время: 0.4944c, MSE: 1.5452e+03
# Experiment 443/216
# Эпохи: 800, Время: 0.5491c, MSE: 7.4265e+00
# Experiment 444/216
# Эпохи: 1200, Время: 0.8172c, MSE: 2.2712e-02
# Experiment 445/216
# Эпохи: 400, Время: 0.6293c, MSE: 5.4351e+02
# Experiment 446/216
# Эпохи: 800, Время: 0.5714c, MSE: 8.5303e+00
# Experiment 447/216
# Эпохи: 1200, Время: 0.8836c, MSE: 1.0967e+00
# Experiment 448/216
# Эпохи: 400, Время: 0.5065c, MSE: 4.1625e+02
# Experiment 449/216
# Эпохи: 800, Время: 0.5823c, MSE: 5.5575e+00
# Experiment 450/216
# Эпохи: 1200, Время: 0.6827c, MSE: 5.3136e-01
# Experiment 451/216
# Эпохи: 400, Время: 0.5710c, MSE: 4.4271e+02
# Experiment 452/216
# Эпохи: 800, Время: 0.7403c, MSE: 4.6313e+00
# Experiment 453/216
# Эпохи: 1200, Время: 0.6734c, MSE: 3.4750e-01
# Experiment 454/216
# Эпохи: 400, Время: 0.5992c, MSE: 4.3774e+02
# Experiment 455/216
# Эпохи: 800, Время: 0.7748c, MSE: 4.3026e+00
# Experiment 456/216
# Эпохи: 1200, Время: 0.8155c, MSE: 2.6608e-01
# Experiment 457/216
# Эпохи: 400, Время: 0.5722c, MSE: 1.9073e+03
# Experiment 458/216
# Эпохи: 800, Время: 0.7989c, MSE: 1.4829e+03
# Experiment 459/216
# Эпохи: 1200, Время: 0.5768c, MSE: 1.4532e+03
# Experiment 460/216
# Эпохи: 400, Время: 0.3793c, MSE: 1.8640e+03
# Experiment 461/216
# Эпохи: 800, Время: 0.4259c, MSE: 1.4238e+03
# Experiment 462/216
# Эпохи: 1200, Время: 0.5372c, MSE: 1.4053e+03
# Experiment 463/216
# Эпохи: 400, Время: 0.5312c, MSE: 1.8235e+03
# Experiment 464/216
# Эпохи: 800, Время: 0.5503c, MSE: 1.3569e+03
# Experiment 465/216
# Эпохи: 1200, Время: 0.6764c, MSE: 1.3487e+03
# Experiment 466/216
# Эпохи: 400, Время: 0.4869c, MSE: 1.8216e+03
# Experiment 467/216
# Эпохи: 800, Время: 0.6479c, MSE: 1.3496e+03
# Experiment 468/216
# Эпохи: 1200, Время: 1.1201c, MSE: 1.3429e+03
# Experiment 469/216
# Эпохи: 400, Время: 0.6071c, MSE: 2.5148e+02
# Experiment 470/216
# Эпохи: 800, Время: 0.6138c, MSE: 4.2515e+00
# Experiment 471/216
# Эпохи: 1200, Время: 0.7012c, MSE: 2.7831e+00
# Experiment 472/216
# Эпохи: 400, Время: 0.6161c, MSE: 1.9276e+02
# Experiment 473/216
# Эпохи: 800, Время: 0.8288c, MSE: 2.3813e+00
# Experiment 474/216
# Эпохи: 1200, Время: 0.7764c, MSE: 9.1786e-01
# Experiment 475/216
# Эпохи: 400, Время: 0.6231c, MSE: 1.8990e+02
# Experiment 476/216
# Эпохи: 800, Время: 0.9186c, MSE: 1.9943e+00
# Experiment 477/216
# Эпохи: 1200, Время: 0.9153c, MSE: 5.2662e-01
# Experiment 478/216
# Эпохи: 400, Время: 0.7384c, MSE: 1.6741e+02
# Experiment 479/216
# Эпохи: 800, Время: 0.7418c, MSE: 1.5883e+00
# Experiment 480/216
# Эпохи: 1200, Время: 1.0506c, MSE: 4.3166e-01
# Experiment 481/216
# Эпохи: 400, Время: 0.4292c, MSE: 1.4224e+03
# Experiment 482/216
# Эпохи: 800, Время: 0.4577c, MSE: 1.4224e+03
# Experiment 483/216
# Эпохи: 1200, Время: 0.5907c, MSE: 1.4224e+03
# Experiment 484/216
# Эпохи: 400, Время: 0.4180c, MSE: 1.4040e+03
# Experiment 485/216
# Эпохи: 800, Время: 0.4001c, MSE: 1.4041e+03
# Experiment 486/216
# Эпохи: 1200, Время: 0.4316c, MSE: 1.4041e+03
# Experiment 487/216
# Эпохи: 400, Время: 0.2925c, MSE: 1.3929e+03
# Experiment 488/216
# Эпохи: 800, Время: 0.3394c, MSE: 1.3929e+03
# Experiment 489/216
# Эпохи: 1200, Время: 0.7362c, MSE: 1.3929e+03
# Experiment 490/216
# Эпохи: 400, Время: 0.4765c, MSE: 1.3917e+03
# Experiment 491/216
# Эпохи: 800, Время: 0.4976c, MSE: 1.3918e+03
# Experiment 492/216
# Эпохи: 1200, Время: 0.4791c, MSE: 1.3918e+03
# Experiment 493/216
# Эпохи: 400, Время: 0.9314c, MSE: 1.8289e+03
# Experiment 494/216
# Эпохи: 800, Время: 0.7481c, MSE: 1.2659e+03
# Experiment 495/216
# Эпохи: 1200, Время: 0.7293c, MSE: 4.0253e+02
# Experiment 496/216
# Эпохи: 400, Время: 0.6424c, MSE: 1.7886e+03
# Experiment 497/216
# Эпохи: 800, Время: 0.6092c, MSE: 1.1114e+03
# Experiment 498/216
# Эпохи: 1200, Время: 0.5606c, MSE: 1.9595e+02
# Experiment 499/216
# Эпохи: 400, Время: 0.3942c, MSE: 1.7678e+03
# Experiment 500/216
# Эпохи: 800, Время: 0.7148c, MSE: 1.0230e+03
# Experiment 501/216
# Эпохи: 1200, Время: 0.8178c, MSE: 1.6264e+02
# Experiment 502/216
# Эпохи: 400, Время: 0.5448c, MSE: 1.7652e+03
# Experiment 503/216
# Эпохи: 800, Время: 0.7116c, MSE: 1.0041e+03
# Experiment 504/216
# Эпохи: 1200, Время: 0.6834c, MSE: 1.4386e+02
# Experiment 505/216
# Эпохи: 400, Время: 1.0738c, MSE: 2.8095e+03
# Experiment 506/216
# Эпохи: 800, Время: 0.9217c, MSE: 1.6412e+03
# Experiment 507/216
# Эпохи: 1200, Время: 1.1351c, MSE: 1.6390e+03
# Experiment 508/216
# Эпохи: 400, Время: 0.8702c, MSE: 2.8102e+03
# Experiment 509/216
# Эпохи: 800, Время: 1.0924c, MSE: 1.6412e+03
# Experiment 510/216
# Эпохи: 1200, Время: 1.1900c, MSE: 1.6390e+03
# Experiment 511/216
# Эпохи: 400, Время: 0.9636c, MSE: 2.8105e+03
# Experiment 512/216
# Эпохи: 800, Время: 1.2084c, MSE: 1.6412e+03
# Experiment 513/216
# Эпохи: 1200, Время: 1.3826c, MSE: 1.6390e+03
# Experiment 514/216
# Эпохи: 400, Время: 1.1468c, MSE: 2.8105e+03
# Experiment 515/216
# Эпохи: 800, Время: 1.7490c, MSE: 1.6412e+03
# Experiment 516/216
# Эпохи: 1200, Время: 2.4307c, MSE: 1.6390e+03
# Experiment 517/216
# Эпохи: 400, Время: 0.8905c, MSE: 6.5394e+00
# Experiment 518/216
# Эпохи: 800, Время: 1.2189c, MSE: 3.0790e+00
# Experiment 519/216
# Эпохи: 1200, Время: 1.3034c, MSE: 3.6021e+00
# Experiment 520/216
# Эпохи: 400, Время: 0.9112c, MSE: 3.6483e-02
# Experiment 521/216
# Эпохи: 800, Время: 1.1441c, MSE: 4.3456e-02
# Experiment 522/216
# Эпохи: 1200, Время: 1.8749c, MSE: 2.4137e-01
# Experiment 523/216
# Эпохи: 400, Время: 1.0850c, MSE: 1.7401e-03
# Experiment 524/216
# Эпохи: 800, Время: 1.5162c, MSE: 2.2722e-01
# Experiment 525/216
# Эпохи: 1200, Время: 1.7763c, MSE: 2.8103e-04
# Experiment 526/216
# Эпохи: 400, Время: 1.4508c, MSE: 6.7877e-02
# Experiment 527/216
# Эпохи: 800, Время: 2.2789c, MSE: 1.4000e-01
# Experiment 528/216
# Эпохи: 1200, Время: 3.8030c, MSE: 2.0030e-02
# Experiment 529/216
# Эпохи: 400, Время: 0.9750c, MSE: 1.8596e+03
# Experiment 530/216
# Эпохи: 800, Время: 1.3817c, MSE: 1.0278e+02
# Experiment 531/216
# Эпохи: 1200, Время: 1.7203c, MSE: 2.9666e+00
# Experiment 532/216
# Эпохи: 400, Время: 0.9866c, MSE: 1.9582e+03
# Experiment 533/216
# Эпохи: 800, Время: 1.6422c, MSE: 1.3438e+01
# Experiment 534/216
# Эпохи: 1200, Время: 2.1081c, MSE: 5.1668e-02
# Experiment 535/216
# Эпохи: 400, Время: 1.2429c, MSE: 1.8246e+03
# Experiment 536/216
# Эпохи: 800, Время: 1.9700c, MSE: 1.8555e+01
# Experiment 537/216
# Эпохи: 1200, Время: 2.7358c, MSE: 1.8207e-03
# Experiment 538/216
# Эпохи: 400, Время: 1.7970c, MSE: 1.8730e+03
# Experiment 539/216
# Эпохи: 800, Время: 2.9794c, MSE: 8.4260e+01
# Experiment 540/216
# Эпохи: 1200, Время: 4.3434c, MSE: 7.1132e-04
# Experiment 541/216
# Эпохи: 400, Время: 1.1567c, MSE: 3.2335e+01
# Experiment 542/216
# Эпохи: 800, Время: 1.3690c, MSE: 3.2797e+00
# Experiment 543/216
# Эпохи: 1200, Время: 1.4879c, MSE: 9.4057e+00
# Experiment 544/216
# Эпохи: 400, Время: 1.1987c, MSE: 9.4779e-02
# Experiment 545/216
# Эпохи: 800, Время: 1.5271c, MSE: 1.8638e-01
# Experiment 546/216
# Эпохи: 1200, Время: 1.7797c, MSE: 2.1316e+01
# Experiment 547/216
# Эпохи: 400, Время: 1.3001c, MSE: 2.1181e-02
# Experiment 548/216
# Эпохи: 800, Время: 1.6662c, MSE: 5.5287e-03
# Experiment 549/216
# Эпохи: 1200, Время: 1.9728c, MSE: 1.1123e-03
# Experiment 550/216
# Эпохи: 400, Время: 1.6750c, MSE: 1.5553e-01
# Experiment 551/216
# Эпохи: 800, Время: 2.4662c, MSE: 6.1525e-01
# Experiment 552/216
# Эпохи: 1200, Время: 3.1779c, MSE: 1.2829e-03
# Experiment 553/216
# Эпохи: 400, Время: 0.5246c, MSE: 1.4224e+03
# Experiment 554/216
# Эпохи: 800, Время: 0.5898c, MSE: 1.4224e+03
# Experiment 555/216
# Эпохи: 1200, Время: 0.5690c, MSE: 1.4224e+03
# Experiment 556/216
# Эпохи: 400, Время: 0.6140c, MSE: 1.4041e+03
# Experiment 557/216
# Эпохи: 800, Время: 0.5740c, MSE: 1.4041e+03
# Experiment 558/216
# Эпохи: 1200, Время: 0.7126c, MSE: 1.4041e+03
# Experiment 559/216
# Эпохи: 400, Время: 0.5096c, MSE: 1.3929e+03
# Experiment 560/216
# Эпохи: 800, Время: 0.6621c, MSE: 1.3929e+03
# Experiment 561/216
# Эпохи: 1200, Время: 0.6215c, MSE: 1.3929e+03
# Experiment 562/216
# Эпохи: 400, Время: 0.6789c, MSE: 1.3918e+03
# Experiment 563/216
# Эпохи: 800, Время: 0.7009c, MSE: 1.3918e+03
# Experiment 564/216
# Эпохи: 1200, Время: 0.8391c, MSE: 1.3918e+03
# Experiment 565/216
# Эпохи: 400, Время: 0.8260c, MSE: 5.9644e+03
# Experiment 566/216
# Эпохи: 800, Время: 0.9815c, MSE: 1.0461e+03
# Experiment 567/216
# Эпохи: 1200, Время: 1.1240c, MSE: 8.8890e+02
# Experiment 568/216
# Эпохи: 400, Время: 0.9046c, MSE: 5.9500e+03
# Experiment 569/216
# Эпохи: 800, Время: 0.9843c, MSE: 2.9019e+02
# Experiment 570/216
# Эпохи: 1200, Время: 1.2910c, MSE: 8.2399e-01
# Experiment 571/216
# Эпохи: 400, Время: 0.9428c, MSE: 5.9668e+03
# Experiment 572/216
# Эпохи: 800, Время: 1.2506c, MSE: 1.6460e+02
# Experiment 573/216
# Эпохи: 1200, Время: 1.5419c, MSE: 5.1891e-01
# Experiment 574/216
# Эпохи: 400, Время: 1.3932c, MSE: 5.9656e+03
# Experiment 575/216
# Эпохи: 800, Время: 1.9055c, MSE: 2.5326e+02
# Experiment 576/216
# Эпохи: 1200, Время: 2.4602c, MSE: 2.6314e-01
# Experiment 577/216
# Эпохи: 400, Время: 1.3470c, MSE: 2.8249e+03
# Experiment 578/216
# Эпохи: 800, Время: 1.5026c, MSE: 1.6413e+03
# Experiment 579/216
# Эпохи: 1200, Время: 1.7978c, MSE: 1.6391e+03
# Experiment 580/216
# Эпохи: 400, Время: 1.3179c, MSE: 2.8250e+03
# Experiment 581/216
# Эпохи: 800, Время: 1.7944c, MSE: 1.6413e+03
# Experiment 582/216
# Эпохи: 1200, Время: 2.2420c, MSE: 1.6391e+03
# Experiment 583/216
# Эпохи: 400, Время: 1.3333c, MSE: 2.8250e+03
# Experiment 584/216
# Эпохи: 800, Время: 1.7971c, MSE: 1.6413e+03
# Experiment 585/216
# Эпохи: 1200, Время: 2.5349c, MSE: 1.6391e+03
# Experiment 586/216
# Эпохи: 400, Время: 2.3634c, MSE: 2.8250e+03
# Experiment 587/216
# Эпохи: 800, Время: 3.5318c, MSE: 1.6413e+03
# Experiment 588/216
# Эпохи: 1200, Время: 5.0561c, MSE: 1.6391e+03
# Experiment 589/216
# Эпохи: 400, Время: 1.2330c, MSE: 3.0543e+00
# Experiment 590/216
# Эпохи: 800, Время: 1.5407c, MSE: 2.2394e-01
# Experiment 591/216
# Эпохи: 1200, Время: 1.8501c, MSE: 1.0891e+01
# Experiment 592/216
# Эпохи: 400, Время: 1.4530c, MSE: 1.3188e+01
# Experiment 593/216
# Эпохи: 800, Время: 1.8264c, MSE: 2.7204e+01
# Experiment 594/216
# Эпохи: 1200, Время: 2.4339c, MSE: 2.0241e-03
# Experiment 595/216
# Эпохи: 400, Время: 1.8205c, MSE: 7.0423e-01
# Experiment 596/216
# Эпохи: 800, Время: 2.7656c, MSE: 6.1763e-01
# Experiment 597/216
# Эпохи: 1200, Время: 3.5060c, MSE: 5.2561e-01
# Experiment 598/216
# Эпохи: 400, Время: 2.4390c, MSE: 6.0461e-01
# Experiment 599/216
# Эпохи: 800, Время: 3.8507c, MSE: 3.5731e-01
# Experiment 600/216
# Эпохи: 1200, Время: 5.3826c, MSE: 7.4821e-01
# Experiment 601/216
# Эпохи: 400, Время: 1.2483c, MSE: 9.5455e+04
# Experiment 602/216
# Эпохи: 800, Время: 1.9471c, MSE: 1.5023e+04
# Experiment 603/216
# Эпохи: 1200, Время: 2.8433c, MSE: 1.0971e+04
# Experiment 604/216
# Эпохи: 400, Время: 1.5477c, MSE: 1.4746e+04
# Experiment 605/216
# Эпохи: 800, Время: 2.6495c, MSE: 2.4300e+04
# Experiment 606/216
# Эпохи: 1200, Время: 3.3513c, MSE: 1.3668e+04
# Experiment 607/216
# Эпохи: 400, Время: 1.9078c, MSE: 1.3520e+04
# Experiment 608/216
# Эпохи: 800, Время: 3.4313c, MSE: 3.4624e+03
# Experiment 609/216
# Эпохи: 1200, Время: 4.5669c, MSE: 3.8722e+02
# Experiment 610/216
# Эпохи: 400, Время: 3.1576c, MSE: 2.2400e+03
# Experiment 611/216
# Эпохи: 800, Время: 5.5697c, MSE: 9.4457e+03
# Experiment 612/216
# Эпохи: 1200, Время: 7.8129c, MSE: 5.3542e+03
# Experiment 613/216
# Эпохи: 400, Время: 1.7218c, MSE: 7.2977e-01
# Experiment 614/216
# Эпохи: 800, Время: 2.0091c, MSE: 1.3508e-02
# Experiment 615/216
# Эпохи: 1200, Время: 2.4157c, MSE: 1.9107e-01
# Experiment 616/216
# Эпохи: 400, Время: 1.7936c, MSE: 1.1139e-03
# Experiment 617/216
# Эпохи: 800, Время: 2.4533c, MSE: 9.9711e+00
# Experiment 618/216
# Эпохи: 1200, Время: 2.9965c, MSE: 3.0220e-03
# Experiment 619/216
# Эпохи: 400, Время: 2.1865c, MSE: 3.0141e-03
# Experiment 620/216
# Эпохи: 800, Время: 2.7730c, MSE: 6.9265e-04
# Experiment 621/216
# Эпохи: 1200, Время: 3.7096c, MSE: 7.0489e-01
# Experiment 622/216
# Эпохи: 400, Время: 2.5601c, MSE: 6.5184e-03
# Experiment 623/216
# Эпохи: 800, Время: 3.8606c, MSE: 2.2305e-03
# Experiment 624/216
# Эпохи: 1200, Время: 5.2563c, MSE: 3.2030e-04
# Experiment 625/216
# Эпохи: 400, Время: 0.6774c, MSE: 1.3992e+03
# Experiment 626/216
# Эпохи: 800, Время: 0.6599c, MSE: 1.4225e+03
# Experiment 627/216
# Эпохи: 1200, Время: 0.7305c, MSE: 1.4224e+03
# Experiment 628/216
# Эпохи: 400, Время: 0.5700c, MSE: 1.4045e+03
# Experiment 629/216
# Эпохи: 800, Время: 0.7697c, MSE: 1.4041e+03
# Experiment 630/216
# Эпохи: 1200, Время: 0.7627c, MSE: 1.4040e+03
# Experiment 631/216
# Эпохи: 400, Время: 0.5595c, MSE: 1.3929e+03
# Experiment 632/216
# Эпохи: 800, Время: 0.7146c, MSE: 1.3929e+03
# Experiment 633/216
# Эпохи: 1200, Время: 0.8516c, MSE: 1.3924e+03
# Experiment 634/216
# Эпохи: 400, Время: 0.6670c, MSE: 1.3918e+03
# Experiment 635/216
# Эпохи: 800, Время: 0.9689c, MSE: 1.3918e+03
# Experiment 636/216
# Эпохи: 1200, Время: 1.1471c, MSE: 1.4993e+03
# Experiment 637/216
# Эпохи: 400, Время: 0.9168c, MSE: 8.2339e+03
# Experiment 638/216
# Эпохи: 800, Время: 1.3368c, MSE: 1.7895e+03
# Experiment 639/216
# Эпохи: 1200, Время: 1.5479c, MSE: 1.6401e+03
# Experiment 640/216
# Эпохи: 400, Время: 1.1344c, MSE: 8.2339e+03
# Experiment 641/216
# Эпохи: 800, Время: 1.4629c, MSE: 1.7895e+03
# Experiment 642/216
# Эпохи: 1200, Время: 2.0418c, MSE: 1.6401e+03
# Experiment 643/216
# Эпохи: 400, Время: 1.2855c, MSE: 8.2339e+03
# Experiment 644/216
# Эпохи: 800, Время: 1.9250c, MSE: 1.7895e+03
# Experiment 645/216
# Эпохи: 1200, Время: 2.6637c, MSE: 1.6401e+03
# Experiment 646/216
# Эпохи: 400, Время: 2.1267c, MSE: 8.2339e+03
# Experiment 647/216
# Эпохи: 800, Время: 3.5340c, MSE: 1.7895e+03
# Experiment 648/216
# Эпохи: 1200, Время: 5.5262c, MSE: 1.6401e+03
# Experiments finished. Results saved to csv_results/1D_sphere_neuman_results.csv
#      bc_left bc_right training_time  epoches    lr activation_func  layers  \
# 0  dirichlet   neuman        0.4108      400  0.01            tanh       1
# 1  dirichlet   neuman        0.5821      800  0.01            tanh       1
# 2  dirichlet   neuman        0.6048     1200  0.01            tanh       1
# 3  dirichlet   neuman        0.4588      400  0.01            tanh       1
# 4  dirichlet   neuman        0.6848      800  0.01            tanh       1
#
#    neurons optimizer  collocation_points        mape         mae         mse  \
# 0       32      adam                  12  6.0291e-01  2.0337e+02  4.1639e+04
# 1       32      adam                  12  3.4642e-01  1.1722e+02  1.4017e+04
# 2       32      adam                  12  2.4261e-01  8.2024e+01  6.8355e+03
# 3       32      adam                  22  6.0372e-01  2.0364e+02  4.1751e+04
# 4       32      adam                  22  3.4735e-01  1.1753e+02  1.4090e+04
#
#          rmse   max_error    weights
# 0  2.0406e+02  2.2632e+02  [1, 5, 5]
# 1  1.1839e+02  1.4003e+02  [1, 5, 5]
# 2  8.2677e+01  9.6177e+01  [1, 5, 5]
# 3  2.0433e+02  2.2659e+02  [1, 5, 5]
# 4  1.1870e+02  1.4033e+02  [1, 5, 5]
