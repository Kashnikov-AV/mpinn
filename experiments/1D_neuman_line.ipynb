# %%
import jax
import jax.numpy as jnp
import flax.nnx as nnx
import optax
import matplotlib.pyplot as plt
import pandas as pd
import os
from dataclasses import dataclass
from functools import partial

# %%
from geom import Interval
from pinn_core import PINN, FCNet
from pde import line_1d
from bc import dirichlet_bc, neuman_bc
from analytic import line_1d_neuman_exact

# %%
plt.rcParams.update({
    'font.size': 14,
    'axes.titlesize': 14,
    'axes.labelsize': 14,
    'xtick.labelsize': 14,
    'ytick.labelsize': 14,
    'legend.fontsize': 14,
    'figure.titlesize': 16,
})

# %%
@dataclass(frozen=True)
class PhysicsParams:
    x_left: float = 0.0
    x_right: float = 1.0
    T_left: float = 300.0
    q_right: float = -100.0
    _lambda: float = 1.0

    @property
    def grad_right(self):
        return -self.q_right / self._lambda

# %%
def get_activation(name):
    mapping = {
        'tanh': nnx.tanh,
        'Swish': nnx.silu,
        'sin': jnp.sin,
        'GELU': nnx.gelu,
        'ReLU': nnx.relu,
        'Sigmoid': nnx.sigmoid,
    }
    return mapping.get(name, nnx.relu)

def get_optimizer(name, lr):
    mapping = {'adam': optax.adam(lr)}
    return mapping.get(name, optax.adam(lr))

# %%
def train_model(
    hidden_features, num_layers, activation_name, lr,
    num_points, opt_name, epochs, weights, save_img=False, show_plot=False
):
    phys = PhysicsParams()
    
    geom = Interval(phys.x_left, phys.x_right)
    x_collocation = geom.generate_collocation(n_interior=num_points, method='random')
    total_points = x_collocation.shape[0]

    act_fn = get_activation(activation_name)
    net = FCNet(din=1, dmid=hidden_features, dout=1, num_layers=num_layers, activation=act_fn, rngs=nnx.Rngs(0))
    
    optimizer = get_optimizer(opt_name, lr=lr)
    pinn = PINN(net, opt=optimizer, weights=weights)

    bc_fns = [
        partial(dirichlet_bc, x=phys.x_left, T=phys.T_left),
        partial(neuman_bc, x=phys.x_right, g=phys.grad_right)
    ]

    history, training_time = pinn.fit(
        x_collocation=x_collocation,
        pde_fn=line_1d,
        bc_fns=bc_fns,
        phys=phys,
        epochs=epochs
    )

    x_test = jnp.linspace(phys.x_left, phys.x_right, 100).reshape(-1, 1)
    metrics, T_pred, T_exact = pinn.evaluate(
        x_test, line_1d_neuman_exact, phys, bc_names=['dirichlet', 'neuman']
    )

    print(f'Эпохи: {epochs}, Время: {training_time:.4f}c, MSE: {metrics['mse']}')

    if save_img:
        pinn.save_plot(x_test, T_pred, T_exact, phys, save_path=f'images/pinn/1D_line_Neuman_{epochs}.png')

    if show_plot:
        pinn.show_plot(x_test, T_pred, T_exact, phys)

    result = {
        'bc_left': metrics['bc_left'],
        'bc_right': metrics['bc_right'],
        'training_time': f'{training_time:.4f}',
        'epoches': epochs,
        'lr': lr,
        'activation_func': activation_name,
        'layers': num_layers,
        'neurons': hidden_features,
        'optimizer': opt_name,
        'collocation_points': total_points,
        'mape': metrics['mape'],
        'mae': metrics['mae'],
        'mse': metrics['mse'],
        'rmse': metrics['rmse'],
        'max_error': metrics['max_error'],
        'weights': f'{weights}',
    }

    return result, history

# %%
def find_optimal_epochs(
    target_mape, max_epochs, step,
    hidden_features, num_layers,
    activation_name, lr,
    num_points, opt_name,
    weights
):
    for epochs in range(step, max_epochs + 1, step):
        metrics, history = train_model(
            hidden_features, num_layers, activation_name, lr,
            num_points, opt_name, epochs, weights, save_img=False
        )
        if float(metrics['mape']) < target_mape:
            return epochs
    return max_epochs

# %%
def try_experiments(eph, lr, csv_path='csv_results/1D_line_neuman_results.csv'):
    num_hidden = [32, 64, 128]
    num_layers = [1, 2, 3]
    activation = ['tanh', 'Swish', 'sin', 'GELU', 'ReLU', 'Sigmoid']
    num_interior = [10, 20, 50, 100]
    optimizer = ['adam']
    epochs = [eph]
    weights = [1.0, 1.0, 1.0]
    
    results = []
    exp = 0

    for h in num_hidden:
        for l in num_layers:
            for a in activation:
                for col in num_interior:
                    for opt in optimizer:
                        for epoch in epochs:
                            exp += 1
                            print(f'Experiment {exp}/{len(num_hidden)*len(num_layers)*len(activation)*len(num_interior)}')
                            res, history = train_model(h, l, a, lr, col, opt, epoch, weights)
                            results.append(res)

    df_results = pd.DataFrame(results)
    os.makedirs(os.path.dirname(csv_path), exist_ok=True)
    df_results.to_csv(csv_path, mode='a', header=not os.path.exists(csv_path), index=False)
    print(f'Experiments finished. Results saved to {csv_path}')
    return df_results

# %%
# Оптимальные эпохи
learning_rate = 0.01
weights=[1, 1, 1]

optimal_epochs = find_optimal_epochs(
    target_mape=0.001, max_epochs=3000, step=50,
    hidden_features=64, num_layers=2,
    activation_name='GELU', lr=learning_rate,
    num_points=100, opt_name='adam',
    weights=weights
)
optimal_epochs
# Out:
# Эпохи: 50, Время: 1.8314c, MSE: 1.0462e+04
# Эпохи: 100, Время: 1.8402c, MSE: 1.7080e+01
# Эпохи: 150, Время: 1.9200c, MSE: 4.7060e-02
# 150

# %%
metrics, history = train_model(
    hidden_features=64, num_layers=2, 
    activation_name='GELU', lr=learning_rate, 
    num_points=100, opt_name='adam', 
    epochs=optimal_epochs, show_plot=True, save_img=True,
    weights=weights
)
metrics
# Out:
# Эпохи: 150, Время: 1.8038c, MSE: 4.7060e-02
# {'bc_left': 'dirichlet',
#  'bc_right': 'neuman',
#  'training_time': '1.8038',
#  'epoches': 150,
#  'lr': 0.01,
#  'activation_func': 'GELU',
#  'layers': 2,
#  'neurons': 64,
#  'optimizer': 'adam',
#  'collocation_points': 102,
#  'mape': '5.9184e-04',
#  'mae': '1.9831e-01',
#  'mse': '4.7060e-02',
#  'rmse': '2.1693e-01',
#  'max_error': '3.6850e-01',
#  'weights': '[1, 1, 1]'}

# %%
history.keys()
# Out:
# dict_keys(['steps', 'total_loss', 'pde', 'bc_0', 'bc_1'])

# %%
plt.figure(figsize=(12, 7))
steps = history['steps']

plt.semilogy(steps, history['pde'], 'b', label='PDE Потери', linewidth=2) # PDE
plt.semilogy(steps, history['bc_0'], 'r--', label='ГУ слева', linewidth=2, alpha=0.7) # Boundary Conditions
plt.semilogy(steps, history['bc_1'], 'r--', label='ГУ справа', linewidth=2, alpha=0.7)
plt.semilogy(steps, history['total_loss'], 'g--', label='Общая ошибка', linewidth=2, alpha=0.7)

plt.title('История Обучения')
plt.xlabel('Эпохи')
plt.ylabel('Потери')
plt.legend(loc='upper right')
plt.grid(True, alpha=0.3, which="both")
plt.tight_layout()
plt.savefig('images/history_line_neuman', dpi=72, bbox_inches='tight')
plt.show()

# %%
df_results = try_experiments(optimal_epochs, lr=learning_rate)
df_results.head()
# Out:
# Experiment 1/216
# Эпохи: 150, Время: 0.8642c, MSE: 8.7873e+04
# Experiment 2/216
# Эпохи: 150, Время: 0.9486c, MSE: 8.7620e+04
# Experiment 3/216
# Эпохи: 150, Время: 1.0545c, MSE: 8.7877e+04
# Experiment 4/216
# Эпохи: 150, Время: 1.1039c, MSE: 8.7865e+04
# Experiment 5/216
# Эпохи: 150, Время: 0.8867c, MSE: 5.0587e+04
# Experiment 6/216
# Эпохи: 150, Время: 0.8709c, MSE: 5.0223e+04
# Experiment 7/216
# Эпохи: 150, Время: 0.8132c, MSE: 5.0192e+04
# Experiment 8/216
# Эпохи: 150, Время: 0.9060c, MSE: 5.0230e+04
# Experiment 9/216
# Эпохи: 150, Время: 0.7377c, MSE: 8.9014e+04
# Experiment 10/216
# Эпохи: 150, Время: 0.6801c, MSE: 8.8668e+04
# Experiment 11/216
# Эпохи: 150, Время: 0.6359c, MSE: 8.8490e+04
# Experiment 12/216
# Эпохи: 150, Время: 0.6151c, MSE: 8.8561e+04
# Experiment 13/216
# Эпохи: 150, Время: 1.0485c, MSE: 5.2325e+04
# Experiment 14/216
# Эпохи: 150, Время: 1.0423c, MSE: 5.0874e+04
# Experiment 15/216
# Эпохи: 150, Время: 1.0809c, MSE: 5.0685e+04
# Experiment 16/216
# Эпохи: 150, Время: 1.0953c, MSE: 5.0809e+04
# Experiment 17/216
# Эпохи: 150, Время: 0.5340c, MSE: 9.6555e+04
# Experiment 18/216
# Эпохи: 150, Время: 0.4819c, MSE: 9.6555e+04
# Experiment 19/216
# Эпохи: 150, Время: 0.4770c, MSE: 9.6555e+04
# Experiment 20/216
# Эпохи: 150, Время: 0.5008c, MSE: 9.6555e+04
# Experiment 21/216
# Эпохи: 150, Время: 0.6940c, MSE: 9.3046e+04
# Experiment 22/216
# Эпохи: 150, Время: 0.7520c, MSE: 9.3018e+04
# Experiment 23/216
# Эпохи: 150, Время: 0.8275c, MSE: 9.3007e+04
# Experiment 24/216
# Эпохи: 150, Время: 0.8187c, MSE: 9.3008e+04
# Experiment 25/216
# Эпохи: 150, Время: 1.2079c, MSE: 9.8422e+04
# Experiment 26/216
# Эпохи: 150, Время: 1.4971c, MSE: 9.3626e+04
# Experiment 27/216
# Эпохи: 150, Время: 1.6990c, MSE: 9.0626e+04
# Experiment 28/216
# Эпохи: 150, Время: 1.6369c, MSE: 9.0473e+04
# Experiment 29/216
# Эпохи: 150, Время: 1.3734c, MSE: 1.2237e-01
# Experiment 30/216
# Эпохи: 150, Время: 1.3756c, MSE: 2.7176e-01
# Experiment 31/216
# Эпохи: 150, Время: 1.2830c, MSE: 2.2050e-01
# Experiment 32/216
# Эпохи: 150, Время: 1.2979c, MSE: 2.0470e-01
# Experiment 33/216
# Эпохи: 150, Время: 1.0832c, MSE: 9.2902e+04
# Experiment 34/216
# Эпохи: 150, Время: 1.1567c, MSE: 9.0144e+04
# Experiment 35/216
# Эпохи: 150, Время: 1.0800c, MSE: 8.9910e+04
# Experiment 36/216
# Эпохи: 150, Время: 1.1090c, MSE: 8.9943e+04
# Experiment 37/216
# Эпохи: 150, Время: 1.8646c, MSE: 4.4059e+01
# Experiment 38/216
# Эпохи: 150, Время: 2.0242c, MSE: 5.4020e-01
# Experiment 39/216
# Эпохи: 150, Время: 1.9661c, MSE: 4.8002e-01
# Experiment 40/216
# Эпохи: 150, Время: 1.9661c, MSE: 3.4395e-01
# Experiment 41/216
# Эпохи: 150, Время: 0.6967c, MSE: 8.9069e+04
# Experiment 42/216
# Эпохи: 150, Время: 0.6754c, MSE: 8.9069e+04
# Experiment 43/216
# Эпохи: 150, Время: 0.7578c, MSE: 8.9069e+04
# Experiment 44/216
# Эпохи: 150, Время: 0.8483c, MSE: 8.9069e+04
# Experiment 45/216
# Эпохи: 150, Время: 1.1556c, MSE: 9.4530e+04
# Experiment 46/216
# Эпохи: 150, Время: 1.1794c, MSE: 9.4530e+04
# Experiment 47/216
# Эпохи: 150, Время: 1.2021c, MSE: 9.4530e+04
# Experiment 48/216
# Эпохи: 150, Время: 1.2252c, MSE: 9.4530e+04
# Experiment 49/216
# Эпохи: 150, Время: 1.6316c, MSE: 1.0227e+05
# Experiment 50/216
# Эпохи: 150, Время: 1.7929c, MSE: 9.0861e+04
# Experiment 51/216
# Эпохи: 150, Время: 2.0606c, MSE: 9.0924e+04
# Experiment 52/216
# Эпохи: 150, Время: 2.1596c, MSE: 9.1140e+04
# Experiment 53/216
# Эпохи: 150, Время: 1.5869c, MSE: 3.2525e-02
# Experiment 54/216
# Эпохи: 150, Время: 1.7992c, MSE: 1.0452e-02
# Experiment 55/216
# Эпохи: 150, Время: 1.6581c, MSE: 4.0922e-02
# Experiment 56/216
# Эпохи: 150, Время: 1.5973c, MSE: 1.9861e-02
# Experiment 57/216
# Эпохи: 150, Время: 1.5594c, MSE: 1.0069e+05
# Experiment 58/216
# Эпохи: 150, Время: 1.4107c, MSE: 9.1180e+04
# Experiment 59/216
# Эпохи: 150, Время: 1.3573c, MSE: 9.0161e+04
# Experiment 60/216
# Эпохи: 150, Время: 1.5300c, MSE: 9.0189e+04
# Experiment 61/216
# Эпохи: 150, Время: 2.2428c, MSE: 7.8358e+03
# Experiment 62/216
# Эпохи: 150, Время: 2.4326c, MSE: 1.2374e-01
# Experiment 63/216
# Эпохи: 150, Время: 2.4150c, MSE: 1.2249e-02
# Experiment 64/216
# Эпохи: 150, Время: 2.4615c, MSE: 8.0308e-03
# Experiment 65/216
# Эпохи: 150, Время: 0.8052c, MSE: 8.9108e+04
# Experiment 66/216
# Эпохи: 150, Время: 0.8843c, MSE: 8.9108e+04
# Experiment 67/216
# Эпохи: 150, Время: 0.8337c, MSE: 8.9108e+04
# Experiment 68/216
# Эпохи: 150, Время: 0.8168c, MSE: 8.9108e+04
# Experiment 69/216
# Эпохи: 150, Время: 1.3671c, MSE: 9.5249e+04
# Experiment 70/216
# Эпохи: 150, Время: 1.5499c, MSE: 9.5249e+04
# Experiment 71/216
# Эпохи: 150, Время: 1.4162c, MSE: 9.5249e+04
# Experiment 72/216
# Эпохи: 150, Время: 1.4337c, MSE: 9.5249e+04
# Experiment 73/216
# Эпохи: 150, Время: 0.7453c, MSE: 6.3517e+04
# Experiment 74/216
# Эпохи: 150, Время: 0.7644c, MSE: 6.2904e+04
# Experiment 75/216
# Эпохи: 150, Время: 0.7932c, MSE: 6.2776e+04
# Experiment 76/216
# Эпохи: 150, Время: 0.7693c, MSE: 6.2768e+04
# Experiment 77/216
# Эпохи: 150, Время: 0.9300c, MSE: 1.5934e+04
# Experiment 78/216
# Эпохи: 150, Время: 0.8115c, MSE: 1.5976e+04
# Experiment 79/216
# Эпохи: 150, Время: 0.8655c, MSE: 1.5988e+04
# Experiment 80/216
# Эпохи: 150, Время: 0.8290c, MSE: 1.5982e+04
# Experiment 81/216
# Эпохи: 150, Время: 0.9789c, MSE: 6.4730e+04
# Experiment 82/216
# Эпохи: 150, Время: 0.6390c, MSE: 6.3691e+04
# Experiment 83/216
# Эпохи: 150, Время: 0.5919c, MSE: 6.3498e+04
# Experiment 84/216
# Эпохи: 150, Время: 0.6913c, MSE: 6.3574e+04
# Experiment 85/216
# Эпохи: 150, Время: 1.0308c, MSE: 1.2188e+04
# Experiment 86/216
# Эпохи: 150, Время: 1.0103c, MSE: 1.0867e+04
# Experiment 87/216
# Эпохи: 150, Время: 1.0506c, MSE: 1.0735e+04
# Experiment 88/216
# Эпохи: 150, Время: 1.1271c, MSE: 1.0730e+04
# Experiment 89/216
# Эпохи: 150, Время: 0.4918c, MSE: 8.9113e+04
# Experiment 90/216
# Эпохи: 150, Время: 0.4814c, MSE: 8.9113e+04
# Experiment 91/216
# Эпохи: 150, Время: 0.5159c, MSE: 8.9113e+04
# Experiment 92/216
# Эпохи: 150, Время: 0.5020c, MSE: 8.9113e+04
# Experiment 93/216
# Эпохи: 150, Время: 0.6668c, MSE: 6.8801e+04
# Experiment 94/216
# Эпохи: 150, Время: 0.7370c, MSE: 6.8714e+04
# Experiment 95/216
# Эпохи: 150, Время: 0.6741c, MSE: 6.8682e+04
# Experiment 96/216
# Эпохи: 150, Время: 0.7070c, MSE: 6.8685e+04
# Experiment 97/216
# Эпохи: 150, Время: 1.2006c, MSE: 7.1032e+04
# Experiment 98/216
# Эпохи: 150, Время: 1.2055c, MSE: 6.6555e+04
# Experiment 99/216
# Эпохи: 150, Время: 1.1956c, MSE: 6.4258e+04
# Experiment 100/216
# Эпохи: 150, Время: 1.1952c, MSE: 6.4256e+04
# Experiment 101/216
# Эпохи: 150, Время: 1.2424c, MSE: 5.1925e+00
# Experiment 102/216
# Эпохи: 150, Время: 1.3149c, MSE: 3.4062e-02
# Experiment 103/216
# Эпохи: 150, Время: 1.3138c, MSE: 6.2622e-03
# Experiment 104/216
# Эпохи: 150, Время: 1.3999c, MSE: 7.3044e-03
# Experiment 105/216
# Эпохи: 150, Время: 1.1104c, MSE: 6.7073e+04
# Experiment 106/216
# Эпохи: 150, Время: 1.2702c, MSE: 6.5310e+04
# Experiment 107/216
# Эпохи: 150, Время: 1.2101c, MSE: 6.4473e+04
# Experiment 108/216
# Эпохи: 150, Время: 1.4198c, MSE: 6.4489e+04
# Experiment 109/216
# Эпохи: 150, Время: 1.8374c, MSE: 3.0598e+02
# Experiment 110/216
# Эпохи: 150, Время: 1.8095c, MSE: 2.0594e-03
# Experiment 111/216
# Эпохи: 150, Время: 1.8038c, MSE: 1.7956e-02
# Experiment 112/216
# Эпохи: 150, Время: 1.8601c, MSE: 4.7060e-02
# Experiment 113/216
# Эпохи: 150, Время: 0.7207c, MSE: 8.9123e+04
# Experiment 114/216
# Эпохи: 150, Время: 0.6484c, MSE: 8.9123e+04
# Experiment 115/216
# Эпохи: 150, Время: 0.6834c, MSE: 8.9123e+04
# Experiment 116/216
# Эпохи: 150, Время: 0.7239c, MSE: 8.9123e+04
# Experiment 117/216
# Эпохи: 150, Время: 1.0402c, MSE: 7.3524e+04
# Experiment 118/216
# Эпохи: 150, Время: 1.1099c, MSE: 7.3524e+04
# Experiment 119/216
# Эпохи: 150, Время: 1.0965c, MSE: 7.3524e+04
# Experiment 120/216
# Эпохи: 150, Время: 1.1602c, MSE: 7.3524e+04
# Experiment 121/216
# Эпохи: 150, Время: 1.4869c, MSE: 6.3386e+04
# Experiment 122/216
# Эпохи: 150, Время: 1.5404c, MSE: 6.2990e+04
# Experiment 123/216
# Эпохи: 150, Время: 1.5146c, MSE: 6.5551e+04
# Experiment 124/216
# Эпохи: 150, Время: 1.5951c, MSE: 6.2918e+04
# Experiment 125/216
# Эпохи: 150, Время: 1.5655c, MSE: 9.2320e-02
# Experiment 126/216
# Эпохи: 150, Время: 1.5815c, MSE: 3.9057e-03
# Experiment 127/216
# Эпохи: 150, Время: 1.6975c, MSE: 7.0519e-05
# Experiment 128/216
# Эпохи: 150, Время: 1.7887c, MSE: 1.4754e-03
# Experiment 129/216
# Эпохи: 150, Время: 1.5461c, MSE: 8.5838e+04
# Experiment 130/216
# Эпохи: 150, Время: 1.6361c, MSE: 7.0254e+04
# Experiment 131/216
# Эпохи: 150, Время: 1.8588c, MSE: 6.4750e+04
# Experiment 132/216
# Эпохи: 150, Время: 1.8092c, MSE: 6.4952e+04
# Experiment 133/216
# Эпохи: 150, Время: 2.4457c, MSE: 7.1765e+04
# Experiment 134/216
# Эпохи: 150, Время: 2.5314c, MSE: 2.0122e-02
# Experiment 135/216
# Эпохи: 150, Время: 2.6831c, MSE: 3.4416e-02
# Experiment 136/216
# Эпохи: 150, Время: 2.6240c, MSE: 7.3091e-03
# Experiment 137/216
# Эпохи: 150, Время: 0.8288c, MSE: 8.9094e+04
# Experiment 138/216
# Эпохи: 150, Время: 0.8986c, MSE: 8.9094e+04
# Experiment 139/216
# Эпохи: 150, Время: 0.8353c, MSE: 8.9094e+04
# Experiment 140/216
# Эпохи: 150, Время: 0.8248c, MSE: 8.9094e+04
# Experiment 141/216
# Эпохи: 150, Время: 1.3764c, MSE: 8.1363e+04
# Experiment 142/216
# Эпохи: 150, Время: 1.4059c, MSE: 8.1363e+04
# Experiment 143/216
# Эпохи: 150, Время: 1.3965c, MSE: 8.1363e+04
# Experiment 144/216
# Эпохи: 150, Время: 1.5210c, MSE: 8.1363e+04
# Experiment 145/216
# Эпохи: 150, Время: 0.8676c, MSE: 2.7233e+04
# Experiment 146/216
# Эпохи: 150, Время: 0.8338c, MSE: 2.6618e+04
# Experiment 147/216
# Эпохи: 150, Время: 0.7859c, MSE: 2.6453e+04
# Experiment 148/216
# Эпохи: 150, Время: 0.8114c, MSE: 2.6458e+04
# Experiment 149/216
# Эпохи: 150, Время: 1.0210c, MSE: 1.0636e+03
# Experiment 150/216
# Эпохи: 150, Время: 0.8988c, MSE: 1.0497e+03
# Experiment 151/216
# Эпохи: 150, Время: 0.8521c, MSE: 1.0405e+03
# Experiment 152/216
# Эпохи: 150, Время: 0.9070c, MSE: 1.0398e+03
# Experiment 153/216
# Эпохи: 150, Время: 0.6510c, MSE: 3.0729e+04
# Experiment 154/216
# Эпохи: 150, Время: 0.6735c, MSE: 2.9923e+04
# Experiment 155/216
# Эпохи: 150, Время: 0.6889c, MSE: 2.9828e+04
# Experiment 156/216
# Эпохи: 150, Время: 0.7036c, MSE: 2.9895e+04
# Experiment 157/216
# Эпохи: 150, Время: 1.1152c, MSE: 2.8487e+02
# Experiment 158/216
# Эпохи: 150, Время: 1.1763c, MSE: 2.8692e+02
# Experiment 159/216
# Эпохи: 150, Время: 1.1123c, MSE: 2.4142e+02
# Experiment 160/216
# Эпохи: 150, Время: 1.0975c, MSE: 2.3992e+02
# Experiment 161/216
# Эпохи: 150, Время: 0.4805c, MSE: 8.9149e+04
# Experiment 162/216
# Эпохи: 150, Время: 0.4954c, MSE: 8.9149e+04
# Experiment 163/216
# Эпохи: 150, Время: 0.4850c, MSE: 8.9149e+04
# Experiment 164/216
# Эпохи: 150, Время: 0.4954c, MSE: 8.9149e+04
# Experiment 165/216
# Эпохи: 150, Время: 0.8082c, MSE: 3.6636e+04
# Experiment 166/216
# Эпохи: 150, Время: 0.6840c, MSE: 3.6395e+04
# Experiment 167/216
# Эпохи: 150, Время: 0.7423c, MSE: 3.6294e+04
# Experiment 168/216
# Эпохи: 150, Время: 0.7246c, MSE: 3.6297e+04
# Experiment 169/216
# Эпохи: 150, Время: 1.2570c, MSE: 3.5472e+04
# Experiment 170/216
# Эпохи: 150, Время: 1.3382c, MSE: 3.6065e+04
# Experiment 171/216
# Эпохи: 150, Время: 1.3639c, MSE: 3.4072e+04
# Experiment 172/216
# Эпохи: 150, Время: 1.4411c, MSE: 3.3351e+04
# Experiment 173/216
# Эпохи: 150, Время: 1.3316c, MSE: 1.1192e+00
# Experiment 174/216
# Эпохи: 150, Время: 1.3746c, MSE: 6.1544e-02
# Experiment 175/216
# Эпохи: 150, Время: 1.4228c, MSE: 6.9166e-02
# Experiment 176/216
# Эпохи: 150, Время: 1.6097c, MSE: 5.8280e-02
# Experiment 177/216
# Эпохи: 150, Время: 1.3230c, MSE: 4.1663e+04
# Experiment 178/216
# Эпохи: 150, Время: 1.4870c, MSE: 3.4654e+04
# Experiment 179/216
# Эпохи: 150, Время: 1.5144c, MSE: 3.2922e+04
# Experiment 180/216
# Эпохи: 150, Время: 1.7813c, MSE: 3.1597e+04
# Experiment 181/216
# Эпохи: 150, Время: 1.8465c, MSE: 8.0883e+03
# Experiment 182/216
# Эпохи: 150, Время: 1.9616c, MSE: 3.9118e-02
# Experiment 183/216
# Эпохи: 150, Время: 2.0130c, MSE: 1.8696e-03
# Experiment 184/216
# Эпохи: 150, Время: 2.1637c, MSE: 9.6752e-04
# Experiment 185/216
# Эпохи: 150, Время: 0.7927c, MSE: 8.9097e+04
# Experiment 186/216
# Эпохи: 150, Время: 0.7317c, MSE: 8.9097e+04
# Experiment 187/216
# Эпохи: 150, Время: 0.7025c, MSE: 8.9097e+04
# Experiment 188/216
# Эпохи: 150, Время: 0.6671c, MSE: 8.9097e+04
# Experiment 189/216
# Эпохи: 150, Время: 1.1669c, MSE: 4.9786e+04
# Experiment 190/216
# Эпохи: 150, Время: 1.2398c, MSE: 4.9786e+04
# Experiment 191/216
# Эпохи: 150, Время: 1.2726c, MSE: 4.9786e+04
# Experiment 192/216
# Эпохи: 150, Время: 1.3948c, MSE: 4.9786e+04
# Experiment 193/216
# Эпохи: 150, Время: 1.7196c, MSE: 3.0702e+04
# Experiment 194/216
# Эпохи: 150, Время: 1.7431c, MSE: 3.0636e+04
# Experiment 195/216
# Эпохи: 150, Время: 1.7990c, MSE: 3.0249e+04
# Experiment 196/216
# Эпохи: 150, Время: 2.0957c, MSE: 3.0280e+04
# Experiment 197/216
# Эпохи: 150, Время: 1.7777c, MSE: 1.4999e+01
# Experiment 198/216
# Эпохи: 150, Время: 1.8219c, MSE: 9.9045e-04
# Experiment 199/216
# Эпохи: 150, Время: 1.8906c, MSE: 1.5293e-04
# Experiment 200/216
# Эпохи: 150, Время: 2.3352c, MSE: 1.2074e-02
# Experiment 201/216
# Эпохи: 150, Время: 1.7775c, MSE: 6.0330e+04
# Experiment 202/216
# Эпохи: 150, Время: 2.0098c, MSE: 4.3698e+04
# Experiment 203/216
# Эпохи: 150, Время: 2.3665c, MSE: 4.9292e+04
# Experiment 204/216
# Эпохи: 150, Время: 2.5693c, MSE: 5.5773e+04
# Experiment 205/216
# Эпохи: 150, Время: 2.6028c, MSE: 7.9372e+04
# Experiment 206/216
# Эпохи: 150, Время: 2.7774c, MSE: 1.0692e+00
# Experiment 207/216
# Эпохи: 150, Время: 2.7733c, MSE: 3.4683e-03
# Experiment 208/216
# Эпохи: 150, Время: 3.4677c, MSE: 2.7164e-03
# Experiment 209/216
# Эпохи: 150, Время: 0.8784c, MSE: 8.9112e+04
# Experiment 210/216
# Эпохи: 150, Время: 0.8772c, MSE: 8.9112e+04
# Experiment 211/216
# Эпохи: 150, Время: 0.9551c, MSE: 8.9112e+04
# Experiment 212/216
# Эпохи: 150, Время: 0.8981c, MSE: 8.9112e+04
# Experiment 213/216
# Эпохи: 150, Время: 1.5293c, MSE: 5.1267e+04
# Experiment 214/216
# Эпохи: 150, Время: 1.5380c, MSE: 5.1267e+04
# Experiment 215/216
# Эпохи: 150, Время: 1.6667c, MSE: 5.1267e+04
# Experiment 216/216
# Эпохи: 150, Время: 2.1107c, MSE: 5.1267e+04
# Experiments finished. Results saved to csv_results/1D_line_neuman_results.csv
#      bc_left bc_right training_time  epoches    lr activation_func  layers  \
# 0  dirichlet   neuman        0.8642      150  0.01            tanh       1
# 1  dirichlet   neuman        0.9486      150  0.01            tanh       1
# 2  dirichlet   neuman        1.0545      150  0.01            tanh       1
# 3  dirichlet   neuman        1.1039      150  0.01            tanh       1
# 4  dirichlet   neuman        0.8867      150  0.01           Swish       1
#
#    neurons optimizer  collocation_points        mape         mae         mse  \
# 0       32      adam                  12  8.4061e-01  2.9478e+02  8.7873e+04
# 1       32      adam                  22  8.3941e-01  2.9436e+02  8.7620e+04
# 2       32      adam                  52  8.4061e-01  2.9478e+02  8.7877e+04
# 3       32      adam                 102  8.4052e-01  2.9476e+02  8.7865e+04
# 4       32      adam                  12  6.4541e-01  2.2483e+02  5.0587e+04
#
#          rmse   max_error          weights
# 0  2.9643e+02  3.4732e+02  [1.0, 1.0, 1.0]
# 1  2.9601e+02  3.4701e+02  [1.0, 1.0, 1.0]
# 2  2.9644e+02  3.4725e+02  [1.0, 1.0, 1.0]
# 3  2.9642e+02  3.4732e+02  [1.0, 1.0, 1.0]
# 4  2.2492e+02  2.3376e+02  [1.0, 1.0, 1.0]
