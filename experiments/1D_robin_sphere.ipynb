# %%
import jax
import jax.numpy as jnp
import flax.nnx as nnx
import optax
import matplotlib.pyplot as plt
import pandas as pd
import os
from dataclasses import dataclass
from functools import partial

# %%
from geom import Interval
from pinn_core import PINN, FCNet
from pde import sphere_1d
from bc import dirichlet_bc, robin_bc
from analytic import sphere_1d_robin_exact

# %%
plt.rcParams.update({
    'font.size': 14,
    'axes.titlesize': 14,
    'axes.labelsize': 14,
    'xtick.labelsize': 14,
    'ytick.labelsize': 14,
    'legend.fontsize': 14,
    'figure.titlesize': 16,
})

# %%
@dataclass(frozen=True)
class PhysicsParams:
    x_left: float = 0.3
    x_right: float = 0.6
    T_left: float = 300.0
    T_inf: float = 500.0
    _lambda: float = 1.0
    h: float = 10.0

    @property
    def alpha_right(self):
        """Коэффициент при T в условии Робина: α = h"""
        return self.h

    @property
    def beta_right(self):
        """Коэффициент при dT/dx в условии Робина: β = λ"""
        return self._lambda

    @property
    def gamma_right(self):
        """Свободный член в условии Робина: γ = h · T_inf"""
        return self.h * self.T_inf

# %%
def get_activation(name):
    mapping = {
        'tanh': nnx.tanh,
        'Swish': nnx.silu,
        'sin': jnp.sin,
        'GELU': nnx.gelu,
        'ReLU': nnx.relu,
        'Sigmoid': nnx.sigmoid,
    }
    return mapping.get(name, nnx.relu)

def get_optimizer(name, lr):
    mapping = {'adam': optax.adam(lr)}
    return mapping.get(name, optax.adam(lr))

# %%
def train_model(
    hidden_features, num_layers, activation_name, lr,
    num_points, opt_name, epochs, weights, save_img=False, show_plot=False
):
    phys = PhysicsParams()
    
    geom = Interval(phys.x_left, phys.x_right)
    x_collocation = geom.generate_collocation(n_interior=num_points, method='random')
    total_points = x_collocation.shape[0]

    act_fn = get_activation(activation_name)
    net = FCNet(din=1, dmid=hidden_features, dout=1, num_layers=num_layers, activation=act_fn, rngs=nnx.Rngs(0))
    
    optimizer = get_optimizer(opt_name, lr=lr)
    pinn = PINN(net, opt=optimizer, weights=weights)

    bc_fns = [
        partial(dirichlet_bc, x=phys.x_left, T=phys.T_left),
        partial(robin_bc, x=phys.x_right, alpha=phys.alpha_right, beta=phys.beta_right, h=phys.gamma_right)
    ]

    history, training_time = pinn.fit(
        x_collocation=x_collocation,
        pde_fn=sphere_1d,
        bc_fns=bc_fns,
        phys=phys,
        epochs=epochs
    )

    x_test = jnp.linspace(phys.x_left, phys.x_right, 100).reshape(-1, 1)
    metrics, T_pred, T_exact = pinn.evaluate(
        x_test, sphere_1d_robin_exact, phys, bc_names=['dirichlet', 'robin']
    )

    print(f'Эпохи: {epochs}, Время: {training_time:.4f}c, MSE: {metrics['mse']}')

    if save_img:
        pinn.save_plot(x_test, T_pred, T_exact, phys, save_path=f'images/pinn/1D_sphere_Robin_{epochs}.png')

    if show_plot:
        pinn.show_plot(x_test, T_pred, T_exact, phys)

    result = {
        'bc_left': metrics['bc_left'],
        'bc_right': metrics['bc_right'],
        'training_time': f'{training_time:.4f}',
        'epoches': epochs,
        'lr': lr,
        'activation_func': activation_name,
        'layers': num_layers,
        'neurons': hidden_features,
        'optimizer': opt_name,
        'collocation_points': total_points,
        'mape': metrics['mape'],
        'mae': metrics['mae'],
        'mse': metrics['mse'],
        'rmse': metrics['rmse'],
        'max_error': metrics['max_error'],
        'weights': f'{weights}',
    }

    return result, history

# %%
def find_optimal_epochs(
    target_mape, max_epochs, step,
    hidden_features, num_layers,
    activation_name, lr,
    num_points, opt_name,
    weights
):
    for epochs in range(step, max_epochs + 1, step):
        metrics, history = train_model(
            hidden_features, num_layers, activation_name, lr,
            num_points, opt_name, epochs, weights, save_img=False
        )
        if float(metrics['mape']) < target_mape:
            return epochs
    return max_epochs

# %%
def try_experiments(eph, lr, csv_path='csv_results/1D_sphere_robin_results.csv'):
    num_hidden = [32, 64, 128]
    num_layers = [1, 2, 3]
    activation = ['tanh', 'Swish', 'sin', 'GELU', 'ReLU', 'Sigmoid']
    num_col = [10, 20, 50, 100]
    optimizer = ['adam']
    epochs = [eph, eph*2, eph*3]
    weights = [1, 5, 5]
    
    results = []
    exp = 0

    for h in num_hidden:
        for l in num_layers:
            for a in activation:
                for col in num_col:
                    for opt in optimizer:
                        for epoch in epochs:
                            exp += 1
                            print(f'Experiment {exp}/{len(num_hidden)*len(num_layers)*len(activation)*len(num_col)}')
                            res, history = train_model(h, l, a, lr, col, opt, epoch, weights)
                            results.append(res)

    df_results = pd.DataFrame(results)
    os.makedirs(os.path.dirname(csv_path), exist_ok=True)
    df_results.to_csv(csv_path, mode='a', header=not os.path.exists(csv_path), index=False)
    print(f'Experiments finished. Results saved to {csv_path}')
    return df_results

# %%
# Оптимальные эпохи
learning_rate = 0.01
weights=[1, 5, 5]

optimal_epochs = find_optimal_epochs(
    target_mape=0.001, max_epochs=6000, step=100,
    hidden_features=64, num_layers=2,
    activation_name='GELU', lr=learning_rate,
    num_points=100, opt_name='adam',
    weights=weights
)
optimal_epochs
# Out:
# Эпохи: 100, Время: 1.2523c, MSE: 5.7125e+02
# Эпохи: 200, Время: 1.2425c, MSE: 7.2494e+01
# Эпохи: 300, Время: 1.3941c, MSE: 1.2620e+02
# Эпохи: 400, Время: 1.3553c, MSE: 9.1402e+01
# Эпохи: 500, Время: 1.6140c, MSE: 6.2921e+01
# Эпохи: 600, Время: 1.6327c, MSE: 3.8972e+01
# Эпохи: 700, Время: 1.5781c, MSE: 2.4035e+01
# Эпохи: 800, Время: 1.7536c, MSE: 1.7872e+01
# Эпохи: 900, Время: 1.5524c, MSE: 1.1398e+01
# Эпохи: 1000, Время: 1.6171c, MSE: 7.5597e+00
# Эпохи: 1100, Время: 1.7140c, MSE: 3.6446e+00
# Эпохи: 1200, Время: 1.7945c, MSE: 2.9704e+00
# Эпохи: 1300, Время: 1.7936c, MSE: 2.7032e+00
# Эпохи: 1400, Время: 2.0976c, MSE: 1.6058e+00
# Эпохи: 1500, Время: 2.7561c, MSE: 2.9653e+00
# Эпохи: 1600, Время: 2.9587c, MSE: 1.0623e+00
# Эпохи: 1700, Время: 2.6292c, MSE: 1.0235e+00
# Эпохи: 1800, Время: 2.5143c, MSE: 5.6696e-01
# Эпохи: 1900, Время: 2.8891c, MSE: 9.1513e-01
# Эпохи: 2000, Время: 2.6322c, MSE: 5.0806e-01
# Эпохи: 2100, Время: 2.6843c, MSE: 3.4661e+01
# Эпохи: 2200, Время: 2.8344c, MSE: 4.8153e+00
# Эпохи: 2300, Время: 3.0262c, MSE: 7.8058e-01
# Эпохи: 2400, Время: 2.9588c, MSE: 1.7569e-01
# 2400

# %%
metrics, history = train_model(
    hidden_features=64, num_layers=2, 
    activation_name='GELU', lr=learning_rate, 
    num_points=100, opt_name='adam', 
    epochs=optimal_epochs, show_plot=True,save_img=True,
    weights=weights
)
metrics
# Out:
# Эпохи: 2400, Время: 2.9729c, MSE: 1.7569e-01
# {'bc_left': 'dirichlet',
#  'bc_right': 'robin',
#  'training_time': '2.9729',
#  'epoches': 2400,
#  'lr': 0.01,
#  'activation_func': 'GELU',
#  'layers': 2,
#  'neurons': 64,
#  'optimizer': 'adam',
#  'collocation_points': 102,
#  'mape': '9.8783e-04',
#  'mae': '3.6796e-01',
#  'mse': '1.7569e-01',
#  'rmse': '4.1915e-01',
#  'max_error': '8.0948e-01',
#  'weights': '[1, 5, 5]'}

# %%
history.keys()
# Out:
# dict_keys(['steps', 'total_loss', 'pde', 'bc_0', 'bc_1'])

# %%
plt.figure(figsize=(12, 7))
steps = history['steps']

plt.semilogy(steps, history['pde'], 'b', label='PDE Потери', linewidth=2) # PDE
plt.semilogy(steps, history['bc_0'], 'r--', label='ГУ слева', linewidth=2, alpha=0.7) # Boundary Conditions
plt.semilogy(steps, history['bc_1'], 'r--', label='ГУ справа', linewidth=2, alpha=0.7)
plt.semilogy(steps, history['total_loss'], 'g--', label='Общая ошибка', linewidth=2, alpha=0.7)

plt.title('История Обучения')
plt.xlabel('Эпохи')
plt.ylabel('Потери')
plt.legend(loc='upper right')
plt.grid(True, alpha=0.3, which="both")
plt.tight_layout()
plt.savefig('images/history_sphere_robin', dpi=72, bbox_inches='tight')
plt.show()

# %%
df_results = try_experiments(optimal_epochs, lr=learning_rate)
df_results.head()
# Out:
# Experiment 1/216
# Эпохи: 2400, Время: 0.8373c, MSE: 6.9715e+03
# Experiment 2/216
# Эпохи: 4800, Время: 1.3386c, MSE: 1.1397e+02
# Experiment 3/216
# Эпохи: 7200, Время: 1.6041c, MSE: 1.4644e+00
# Experiment 4/216
# Эпохи: 2400, Время: 0.9624c, MSE: 6.9713e+03
# Experiment 5/216
# Эпохи: 4800, Время: 1.3312c, MSE: 1.1982e+02
# Experiment 6/216
# Эпохи: 7200, Время: 1.6637c, MSE: 2.5799e-01
# Experiment 7/216
# Эпохи: 2400, Время: 0.9948c, MSE: 6.9712e+03
# Experiment 8/216
# Эпохи: 4800, Время: 1.2664c, MSE: 1.0870e+02
# Experiment 9/216
# Эпохи: 7200, Время: 1.6597c, MSE: 2.2028e-01
# Experiment 10/216
# Эпохи: 2400, Время: 1.1963c, MSE: 9.5479e+03
# Experiment 251/216
# Эпохи: 4800, Время: 2.0446c, MSE: 9.5825e+03
# Experiment 252/216
# Эпохи: 7200, Время: 2.8584c, MSE: 9.5807e+03
# Experiment 253/216
# Эпохи: 2400, Время: 1.1128c, MSE: 1.5819e+02
# Experiment 254/216
# Эпохи: 4800, Время: 1.4972c, MSE: 5.5050e+00
# Experiment 255/216
# Эпохи: 7200, Время: 1.9488c, MSE: 8.8268e-01
# Experiment 256/216
# Эпохи: 2400, Время: 1.3412c, MSE: 1.1897e+02
# Experiment 257/216
# Эпохи: 4800, Время: 1.4966c, MSE: 1.7337e+00
# Experiment 258/216
# Эпохи: 7200, Время: 2.1711c, MSE: 2.6056e-02
# Experiment 259/216
# Эпохи: 2400, Время: 1.3652c, MSE: 8.4712e+01
# Experiment 260/216
# Эпохи: 4800, Время: 1.6212c, MSE: 1.2384e+00
# Experiment 261/216
# Эпохи: 7200, Время: 1.9811c, MSE: 5.1782e-02
# Experiment 262/216
# Эпохи: 2400, Время: 1.2114c, MSE: 8.4101e+01
# Experiment 263/216
# Эпохи: 4800, Время: 1.7922c, MSE: 1.4389e+00
# Experiment 264/216
# Эпохи: 7200, Время: 2.2564c, MSE: 6.1836e-02
# Experiment 265/216
# Эпохи: 2400, Время: 0.5976c, MSE: 9.4109e+03
# Experiment 266/216
# Эпохи: 4800, Время: 1.0137c, MSE: 1.0221e+04
# Experiment 267/216
# Эпохи: 7200, Время: 1.3007c, MSE: 1.0221e+04
# Experiment 268/216
# Эпохи: 2400, Время: 0.8622c, MSE: 8.9990e+03
# Experiment 269/216
# Эпохи: 4800, Время: 1.0358c, MSE: 1.0142e+04
# Experiment 270/216
# Эпохи: 7200, Время: 1.2010c, MSE: 1.0142e+04
# Experiment 271/216
# Эпохи: 2400, Время: 0.7436c, MSE: 8.7273e+03
# Experiment 272/216
# Эпохи: 4800, Время: 1.0507c, MSE: 1.0092e+04
# Experiment 273/216
# Эпохи: 7200, Время: 1.2846c, MSE: 1.0092e+04
# Experiment 274/216
# Эпохи: 2400, Время: 0.6449c, MSE: 8.6983e+03
# Experiment 275/216
# Эпохи: 4800, Время: 0.9347c, MSE: 1.0087e+04
# Experiment 276/216
# Эпохи: 7200, Время: 1.2322c, MSE: 1.0087e+04
# Experiment 277/216
# Эпохи: 2400, Время: 0.8310c, MSE: 1.0584e+04
# Experiment 278/216
# Эпохи: 4800, Время: 1.0086c, MSE: 9.2985e+03
# Experiment 279/216
# Эпохи: 7200, Время: 1.2769c, MSE: 1.4797e+03
# Experiment 280/216
# Эпохи: 2400, Время: 0.6346c, MSE: 1.0579e+04
# Experiment 281/216
# Эпохи: 4800, Время: 0.9885c, MSE: 9.0420e+03
# Experiment 282/216
# Эпохи: 7200, Время: 1.4774c, MSE: 1.4701e+03
# Experiment 283/216
# Эпохи: 2400, Время: 0.8128c, MSE: 1.0576e+04
# Experiment 284/216
# Эпохи: 4800, Время: 1.0303c, MSE: 8.9154e+03
# Эпохи: 2400, Время: 2.6881c, MSE: 2.7628e+02
# Experiment 320/216
# Эпохи: 4800, Время: 4.7417c, MSE: 9.8924e-04
# Experiment 321/216
# Эпохи: 7200, Время: 6.4563c, MSE: 7.9616e+00
# Experiment 322/216
# Эпохи: 2400, Время: 3.9404c, MSE: 7.1555e+02
# Experiment 323/216
# Эпохи: 4800, Время: 7.3961c, MSE: 6.2127e-01
# Experiment 324/216
# Эпохи: 7200, Время: 10.7022c, MSE: 5.2591e+00
# Experiment 325/216
# Эпохи: 2400, Время: 1.6287c, MSE: 1.8761e+02
# Experiment 326/216
# Эпохи: 4800, Время: 2.0619c, MSE: 8.0668e+01
# Experiment 327/216
# Эпохи: 7200, Время: 2.7236c, MSE: 1.5086e+02
# Experiment 328/216
# Эпохи: 2400, Время: 1.8797c, MSE: 2.8697e+00
# Experiment 329/216
# Эпохи: 4800, Время: 2.5935c, MSE: 6.3243e-01
# Experiment 330/216
# Эпохи: 7200, Время: 3.1965c, MSE: 1.8212e-01
# Experiment 331/216
# Эпохи: 2400, Время: 2.0263c, MSE: 8.2107e+00
# Experiment 332/216
# Эпохи: 4800, Время: 2.9573c, MSE: 1.8605e-02
# Experiment 333/216
# Эпохи: 7200, Время: 4.0251c, MSE: 4.3323e-03
# Experiment 334/216
# Эпохи: 2400, Время: 2.6256c, MSE: 1.7569e-01
# Experiment 335/216
# Эпохи: 4800, Время: 3.8166c, MSE: 6.0246e-02
# Experiment 336/216
# Эпохи: 7200, Время: 5.3105c, MSE: 2.8890e-01
# Experiment 337/216
# Эпохи: 2400, Время: 0.8708c, MSE: 1.0221e+04
# Experiment 338/216
# Эпохи: 4800, Время: 1.2596c, MSE: 1.0221e+04
# Experiment 339/216
# Эпохи: 7200, Время: 1.5617c, MSE: 1.0221e+04
# Experiment 340/216
# Эпохи: 2400, Время: 0.9833c, MSE: 1.0142e+04
# Experiment 341/216
# Эпохи: 4800, Время: 1.1911c, MSE: 1.0142e+04
# Experiment 342/216
# Эпохи: 7200, Время: 1.9382c, MSE: 1.0142e+04
# Experiment 343/216
# Эпохи: 2400, Время: 0.7930c, MSE: 1.0092e+04
# Experiment 344/216
# Эпохи: 4800, Время: 1.3179c, MSE: 1.0092e+04
# Experiment 345/216
# Эпохи: 7200, Время: 1.8115c, MSE: 1.0092e+04
# Experiment 346/216
# Эпохи: 2400, Время: 0.8618c, MSE: 1.0087e+04
# Experiment 347/216
# Эпохи: 4800, Время: 1.2786c, MSE: 1.0087e+04
# Experiment 348/216
# Эпохи: 7200, Время: 1.8513c, MSE: 1.0087e+04
# Experiment 349/216
# Эпохи: 2400, Время: 0.8804c, MSE: 1.0989e+04
# Experiment 350/216
# Эпохи: 4800, Время: 1.5794c, MSE: 1.1004e+04
# Experiment 351/216
# Эпохи: 7200, Время: 1.9938c, MSE: 7.0071e+01
# Experiment 352/216
# Эпохи: 2400, Время: 1.1081c, MSE: 1.0989e+04
# Experiment 353/216
# Эпохи: 4800, Время: 1.4348c, MSE: 1.1004e+04
# Experiment 354/216
# Эпохи: 7200, Время: 2.0461c, MSE: 3.4498e+00
# Experiment 355/216
# Эпохи: 2400, Время: 1.2161c, MSE: 1.0989e+04
# Experiment 356/216
# Эпохи: 4800, Время: 1.8297c, MSE: 1.1003e+04
# Experiment 357/216
# Эпохи: 7200, Время: 2.3006c, MSE: 6.8086e-01
# Experiment 358/216
# Эпохи: 2400, Время: 1.4263c, MSE: 1.0989e+04
# Experiment 359/216
# Эпохи: 4800, Время: 2.2934c, MSE: 1.1003e+04
# Experiment 360/216
# Эпохи: 7200, Время: 3.2525c, MSE: 2.0873e-01
# Experiment 361/216
# Эпохи: 2400, Время: 1.2213c, MSE: 1.0987e+04
# Experiment 362/216
# Эпохи: 4800, Время: 1.7971c, MSE: 1.1004e+04
# Experiment 363/216
# Эпохи: 7200, Время: 2.3282c, MSE: 1.1004e+04
# Experiment 364/216
# Эпохи: 2400, Время: 1.5828c, MSE: 1.0987e+04
# Experiment 365/216
# Эпохи: 4800, Время: 2.1562c, MSE: 1.1004e+04
# Experiment 366/216
# Эпохи: 7200, Время: 2.8903c, MSE: 1.1029e+04
# Experiment 367/216
# Эпохи: 2400, Время: 1.6916c, MSE: 1.0987e+04
# Experiment 368/216
# Эпохи: 4800, Время: 2.6534c, MSE: 1.1038e+04
# Experiment 369/216
# Эпохи: 7200, Время: 3.5021c, MSE: 1.1003e+04
# Experiment 370/216
# Эпохи: 2400, Время: 2.4806c, MSE: 1.0987e+04
# Experiment 371/216
# Эпохи: 4800, Время: 4.0072c, MSE: 1.1005e+04
# Experiment 372/216
# Эпохи: 7200, Время: 5.7701c, MSE: 1.1004e+04
# Experiment 373/216
# Эпохи: 2400, Время: 1.5570c, MSE: 1.0056e-01
# Experiment 374/216
# Эпохи: 4800, Время: 2.3381c, MSE: 1.0731e+00
# Experiment 375/216
# Эпохи: 7200, Время: 3.0613c, MSE: 2.8443e+00
# Experiment 376/216
# Эпохи: 2400, Время: 1.7814c, MSE: 2.9142e-02
# Experiment 377/216
# Эпохи: 4800, Время: 2.7635c, MSE: 2.4111e-01
# Experiment 378/216
# Эпохи: 7200, Время: 3.8680c, MSE: 6.5288e-03
# Experiment 379/216
# Эпохи: 2400, Время: 2.1020c, MSE: 1.0896e-01
# Experiment 380/216
# Эпохи: 4800, Время: 3.3485c, MSE: 7.7137e-01
# Experiment 381/216
# Эпохи: 7200, Время: 4.3670c, MSE: 2.4403e+00
# Experiment 382/216
# Эпохи: 2400, Время: 3.5429c, MSE: 1.0269e-02
# Experiment 383/216
# Эпохи: 4800, Время: 6.3654c, MSE: 1.1422e+00
# Experiment 384/216
# Эпохи: 7200, Время: 10.5039c, MSE: 7.7847e-02
# Experiment 385/216
# Эпохи: 2400, Время: 2.6718c, MSE: 9.9126e+04
# Experiment 386/216
# Эпохи: 4800, Время: 3.6343c, MSE: 2.7412e+04
# Experiment 387/216
# Эпохи: 7200, Время: 5.9660c, MSE: 1.8273e+04
# Experiment 388/216
# Эпохи: 2400, Время: 3.5119c, MSE: 1.5774e+03
# Experiment 389/216
# Эпохи: 4800, Время: 5.4347c, MSE: 3.3118e-02
# Experiment 390/216
# Эпохи: 7200, Время: 7.7513c, MSE: 3.3347e+01
# Experiment 391/216
# Эпохи: 2400, Время: 4.0580c, MSE: 2.1142e+02
# Experiment 392/216
# Эпохи: 4800, Время: 8.3766c, MSE: 6.7893e+01
# Experiment 393/216
# Эпохи: 7200, Время: 12.2521c, MSE: 4.6685e-01
# Experiment 394/216
# Эпохи: 2400, Время: 7.5282c, MSE: 5.3384e+02
# Experiment 395/216
# Эпохи: 4800, Время: 14.7108c, MSE: 5.7646e-01
# Experiment 396/216
# Эпохи: 7200, Время: 21.2671c, MSE: 1.0459e-02
# Experiment 397/216
# Эпохи: 2400, Время: 2.7659c, MSE: 4.4610e-01
# Experiment 398/216
# Эпохи: 4800, Время: 3.7930c, MSE: 1.3449e+00
# Experiment 399/216
# Эпохи: 7200, Время: 4.9802c, MSE: 7.3991e-01
# Experiment 400/216
# Эпохи: 2400, Время: 3.9590c, MSE: 4.0419e-01
# Experiment 401/216
# Эпохи: 4800, Время: 4.7193c, MSE: 1.8800e-03
# Experiment 402/216
# Эпохи: 7200, Время: 6.3851c, MSE: 4.0543e-03
# Experiment 403/216
# Эпохи: 2400, Время: 3.2223c, MSE: 7.4633e-01
# Experiment 404/216
# Эпохи: 4800, Время: 5.8619c, MSE: 3.5719e-02
# Experiment 405/216
# Эпохи: 7200, Время: 7.7068c, MSE: 3.9968e+00
# Experiment 406/216
# Эпохи: 2400, Время: 5.6639c, MSE: 5.6598e-02
# Experiment 407/216
# Эпохи: 4800, Время: 9.8281c, MSE: 6.7123e-02
# Experiment 408/216
# Эпохи: 7200, Время: 14.3586c, MSE: 1.1458e+01
# Experiment 409/216
# Эпохи: 2400, Время: 1.0571c, MSE: 1.0221e+04
# Experiment 410/216
# Эпохи: 4800, Время: 1.5602c, MSE: 1.0698e+04
# Experiment 411/216
# Эпохи: 7200, Время: 2.0709c, MSE: 1.0221e+04
# Experiment 412/216
# Эпохи: 2400, Время: 1.3322c, MSE: 1.0142e+04
# Experiment 413/216
# Эпохи: 4800, Время: 1.6665c, MSE: 1.0151e+04
# Experiment 414/216
# Эпохи: 7200, Время: 2.0081c, MSE: 1.0145e+04
# Experiment 415/216
# Эпохи: 2400, Время: 1.0103c, MSE: 1.0092e+04
# Experiment 416/216
# Эпохи: 4800, Время: 1.4882c, MSE: 1.0092e+04
# Experiment 417/216
# Эпохи: 7200, Время: 2.0564c, MSE: 1.0092e+04
# Experiment 418/216
# Эпохи: 2400, Время: 1.3285c, MSE: 1.0087e+04
# Experiment 419/216
# Эпохи: 4800, Время: 1.9517c, MSE: 1.0087e+04
# Experiment 420/216
# Эпохи: 7200, Время: 2.4269c, MSE: 1.0087e+04
# Experiment 421/216
# Эпохи: 2400, Время: 1.4609c, MSE: 1.0927e+04
# Experiment 422/216
# Эпохи: 4800, Время: 2.2021c, MSE: 1.1004e+04
# Experiment 423/216
# Эпохи: 7200, Время: 2.8044c, MSE: 1.1004e+04
# Experiment 424/216
# Эпохи: 2400, Время: 1.5877c, MSE: 1.0927e+04
# Experiment 425/216
# Эпохи: 4800, Время: 2.4454c, MSE: 1.1004e+04
# Experiment 426/216
# Эпохи: 7200, Время: 3.1654c, MSE: 1.1004e+04
# Experiment 427/216
# Эпохи: 2400, Время: 1.8026c, MSE: 1.0927e+04
# Experiment 428/216
# Эпохи: 4800, Время: 2.9740c, MSE: 1.1004e+04
# Experiment 429/216
# Эпохи: 7200, Время: 4.0433c, MSE: 1.1004e+04
# Experiment 430/216
# Эпохи: 2400, Время: 2.6895c, MSE: 1.0927e+04
# Experiment 431/216
# Эпохи: 4800, Время: 5.0301c, MSE: 1.1004e+04
# Experiment 432/216
# Эпохи: 7200, Время: 7.6868c, MSE: 1.1004e+04
# Experiment 433/216
# Эпохи: 2400, Время: 1.0108c, MSE: 3.3191e+03
# Experiment 434/216
# Эпохи: 4800, Время: 1.3041c, MSE: 1.5145e+00
# Experiment 435/216
# Эпохи: 7200, Время: 1.5916c, MSE: 2.6951e-02
# Experiment 436/216
# Эпохи: 2400, Время: 0.8886c, MSE: 3.7456e+03
# Experiment 437/216
# Эпохи: 4800, Время: 1.2801c, MSE: 1.4317e+00
# Experiment 438/216
# Эпохи: 7200, Время: 1.6226c, MSE: 9.9762e-03
# Experiment 439/216
# Эпохи: 2400, Время: 0.9095c, MSE: 3.5893e+03
# Experiment 440/216
# Эпохи: 4800, Время: 1.3001c, MSE: 1.5217e+00
# Experiment 441/216
# Эпохи: 7200, Время: 1.6215c, MSE: 1.7311e-02
# Experiment 442/216
# Эпохи: 2400, Время: 1.0526c, MSE: 3.4552e+03
# Experiment 443/216
# Эпохи: 4800, Время: 1.6173c, MSE: 1.5237e+00
# Experiment 444/216
# Эпохи: 7200, Время: 2.3365c, MSE: 3.3723e-02
# Experiment 445/216
# Эпохи: 2400, Время: 1.1689c, MSE: 2.6349e+02
# Experiment 446/216
# Эпохи: 4800, Время: 1.5823c, MSE: 7.8665e+00
# Experiment 447/216
# Эпохи: 7200, Время: 2.0131c, MSE: 1.5238e-01
# Experiment 448/216
# Эпохи: 2400, Время: 1.0437c, MSE: 3.0697e+02
# Experiment 449/216
# Эпохи: 4800, Время: 1.2257c, MSE: 2.7958e+00
# Experiment 450/216
# Эпохи: 7200, Время: 2.1119c, MSE: 6.7360e-02
# Experiment 451/216
# Эпохи: 2400, Время: 1.1303c, MSE: 2.9286e+02
# Experiment 452/216
# Эпохи: 4800, Время: 1.5361c, MSE: 2.4112e+00
# Experiment 453/216
# Эпохи: 7200, Время: 2.1753c, MSE: 4.9156e-02
# Experiment 454/216
# Эпохи: 2400, Время: 1.4100c, MSE: 2.6430e+02
# Experiment 455/216
# Эпохи: 4800, Время: 2.1272c, MSE: 2.0481e+00
# Experiment 456/216
# Эпохи: 7200, Время: 2.7469c, MSE: 5.3733e-02
# Experiment 457/216
# Эпохи: 2400, Время: 1.0225c, MSE: 1.0063e+04
# Experiment 458/216
# Эпохи: 4800, Время: 1.2497c, MSE: 1.0088e+04
# Experiment 459/216
# Эпохи: 7200, Время: 1.8115c, MSE: 1.0086e+04
# Experiment 460/216
# Эпохи: 2400, Время: 1.0608c, MSE: 9.7863e+03
# Experiment 461/216
# Эпохи: 4800, Время: 1.6642c, MSE: 9.8097e+03
# Experiment 462/216
# Эпохи: 7200, Время: 2.2491c, MSE: 9.8056e+03
# Experiment 463/216
# Эпохи: 2400, Время: 1.3816c, MSE: 9.5857e+03
# Experiment 464/216
# Эпохи: 4800, Время: 2.3381c, MSE: 9.6052e+03
# Experiment 465/216
# Эпохи: 7200, Время: 3.0995c, MSE: 9.5993e+03
# Experiment 466/216
# Эпохи: 2400, Время: 1.6224c, MSE: 9.5669e+03
# Experiment 467/216
# Эпохи: 4800, Время: 3.0328c, MSE: 9.5859e+03
# Experiment 468/216
# Эпохи: 7200, Время: 4.8004c, MSE: 9.5798e+03
# Experiment 469/216
# Эпохи: 2400, Время: 1.0779c, MSE: 9.0036e+01
# Experiment 470/216
# Эпохи: 4800, Время: 1.2801c, MSE: 2.8367e+00
# Experiment 471/216
# Эпохи: 7200, Время: 1.6027c, MSE: 2.7210e-01
# Experiment 472/216
# Эпохи: 2400, Время: 1.0695c, MSE: 7.4307e+01
# Experiment 473/216
# Эпохи: 4800, Время: 1.5878c, MSE: 5.9793e-01
# Experiment 474/216
# Эпохи: 7200, Время: 2.0702c, MSE: 2.4958e-02
# Experiment 475/216
# Эпохи: 2400, Время: 1.1330c, MSE: 6.1606e+01
# Experiment 476/216
# Эпохи: 4800, Время: 2.1007c, MSE: 4.8333e-01
# Experiment 477/216
# Эпохи: 7200, Время: 2.6193c, MSE: 2.5093e-02
# Experiment 478/216
# Эпохи: 2400, Время: 1.4980c, MSE: 5.7570e+01
# Experiment 479/216
# Эпохи: 4800, Время: 2.3507c, MSE: 4.4901e-01
# Experiment 480/216
# Эпохи: 7200, Время: 2.9792c, MSE: 1.8380e-02
# Experiment 481/216
# Эпохи: 2400, Время: 0.7973c, MSE: 1.0171e+04
# Experiment 482/216
# Эпохи: 4800, Время: 0.9225c, MSE: 1.0221e+04
# Experiment 483/216
# Эпохи: 7200, Время: 1.3570c, MSE: 1.0221e+04
# Experiment 484/216
# Эпохи: 2400, Время: 0.6199c, MSE: 1.0043e+04
# Experiment 485/216
# Эпохи: 4800, Время: 0.9318c, MSE: 1.0142e+04
# Experiment 486/216
# Эпохи: 7200, Время: 1.2215c, MSE: 1.0142e+04
# Experiment 487/216
# Эпохи: 2400, Время: 0.7382c, MSE: 9.9510e+03
# Experiment 488/216
# Эпохи: 4800, Время: 0.9025c, MSE: 1.0092e+04
# Experiment 489/216
# Эпохи: 7200, Время: 1.3035c, MSE: 1.0092e+04
# Experiment 490/216
# Эпохи: 2400, Время: 0.6815c, MSE: 9.9407e+03
# Experiment 491/216
# Эпохи: 4800, Время: 0.9291c, MSE: 1.0087e+04
# Experiment 492/216
# Эпохи: 7200, Время: 1.3354c, MSE: 1.0087e+04
# Experiment 493/216
# Эпохи: 2400, Время: 0.7496c, MSE: 9.8985e+03
# Experiment 494/216
# Эпохи: 4800, Время: 1.1456c, MSE: 9.3407e+03
# Experiment 495/216
# Эпохи: 7200, Время: 1.4053c, MSE: 1.7817e+03
# Experiment 496/216
# Эпохи: 2400, Время: 0.6197c, MSE: 9.8243e+03
# Experiment 497/216
# Эпохи: 4800, Время: 0.8828c, MSE: 8.9330e+03
# Experiment 498/216
# Эпохи: 7200, Время: 1.1711c, MSE: 1.6710e+03
# Experiment 499/216
# Эпохи: 2400, Время: 0.6439c, MSE: 9.7840e+03
# Experiment 500/216
# Эпохи: 4800, Время: 0.9080c, MSE: 8.7129e+03
# Experiment 501/216
# Эпохи: 7200, Время: 1.2932c, MSE: 1.6391e+03
# Experiment 502/216
# Эпохи: 2400, Время: 0.7280c, MSE: 9.7789e+03
# Experiment 503/216
# Эпохи: 4800, Время: 1.0932c, MSE: 8.6594e+03
# Experiment 504/216
# Эпохи: 7200, Время: 1.4999c, MSE: 1.5813e+03
# Experiment 505/216
# Эпохи: 2400, Время: 1.4382c, MSE: 4.5004e+00
# Experiment 506/216
# Эпохи: 4800, Время: 2.3641c, MSE: 1.8750e+00
# Experiment 507/216
# Эпохи: 7200, Время: 3.1835c, MSE: 1.0662e+04
# Experiment 508/216
# Эпохи: 2400, Время: 1.8753c, MSE: 1.5332e-02
# Experiment 509/216
# Эпохи: 4800, Время: 2.9455c, MSE: 5.5567e-02
# Experiment 510/216
# Эпохи: 7200, Время: 4.7080c, MSE: 1.4751e+00
# Experiment 511/216
# Эпохи: 2400, Время: 2.5300c, MSE: 1.6211e-03
# Experiment 512/216
# Эпохи: 4800, Время: 4.3063c, MSE: 1.1265e+00
# Experiment 513/216
# Эпохи: 7200, Время: 6.1792c, MSE: 1.9970e-03
# Experiment 514/216
# Эпохи: 2400, Время: 4.3133c, MSE: 9.1548e-03
# Experiment 515/216
# Эпохи: 4800, Время: 8.4878c, MSE: 1.3181e+00
# Experiment 516/216
# Эпохи: 7200, Время: 12.3763c, MSE: 3.2835e-01
# Experiment 517/216
# Эпохи: 2400, Время: 2.0320c, MSE: 4.5554e+01
# Experiment 518/216
# Эпохи: 4800, Время: 2.8224c, MSE: 9.0578e+01
# Experiment 519/216
# Эпохи: 7200, Время: 4.3560c, MSE: 9.5808e+01
# Experiment 520/216
# Эпохи: 2400, Время: 2.1309c, MSE: 1.3182e-01
# Experiment 521/216
# Эпохи: 4800, Время: 3.3446c, MSE: 1.8076e-01
# Experiment 522/216
# Эпохи: 7200, Время: 4.6104c, MSE: 1.2909e-01
# Experiment 523/216
# Эпохи: 2400, Время: 2.5740c, MSE: 1.8472e+00
# Experiment 524/216
# Эпохи: 4800, Время: 4.8679c, MSE: 2.4308e-01
# Experiment 525/216
# Эпохи: 7200, Время: 9.0562c, MSE: 2.9076e-01
# Experiment 526/216
# Эпохи: 2400, Время: 5.2737c, MSE: 3.2118e+00
# Experiment 527/216
# Эпохи: 4800, Время: 9.4004c, MSE: 2.4438e+00
# Experiment 528/216
# Эпохи: 7200, Время: 13.3125c, MSE: 4.4723e-01
# Experiment 529/216
# Эпохи: 2400, Время: 2.3726c, MSE: 7.7257e+00
# Experiment 530/216
# Эпохи: 4800, Время: 4.4459c, MSE: 3.9531e-02
# Experiment 531/216
# Эпохи: 7200, Время: 6.2632c, MSE: 1.4438e-02
# Experiment 532/216
# Эпохи: 2400, Время: 3.0824c, MSE: 4.2535e-01
# Experiment 533/216
# Эпохи: 4800, Время: 6.0949c, MSE: 2.6099e-01
# Experiment 534/216
# Эпохи: 7200, Время: 8.7785c, MSE: 2.6838e-01
# Experiment 535/216
# Эпохи: 2400, Время: 4.3939c, MSE: 7.3891e-01
# Experiment 536/216
# Эпохи: 4800, Время: 8.6255c, MSE: 1.1866e-01
# Experiment 537/216
# Эпохи: 7200, Время: 14.8809c, MSE: 1.2117e-01
# Experiment 538/216
# Эпохи: 2400, Время: 8.8604c, MSE: 7.6004e-01
# Experiment 539/216
# Эпохи: 4800, Время: 16.4943c, MSE: 4.0054e-05
# Experiment 540/216
# Эпохи: 7200, Время: 23.4726c, MSE: 1.7207e+00
# Experiment 541/216
# Эпохи: 2400, Время: 2.4668c, MSE: 1.7942e+02
# Experiment 542/216
# Эпохи: 4800, Время: 3.8736c, MSE: 1.5515e+02
# Experiment 543/216
# Эпохи: 7200, Время: 5.3198c, MSE: 2.0206e+02
# Experiment 544/216
# Эпохи: 2400, Время: 3.1170c, MSE: 3.3787e+01
# Experiment 545/216
# Эпохи: 4800, Время: 5.0185c, MSE: 1.1206e-01
# Experiment 546/216
# Эпохи: 7200, Время: 7.5312c, MSE: 4.5227e-03
# Experiment 547/216
# Эпохи: 2400, Время: 3.8538c, MSE: 1.4162e+00
# Experiment 548/216
# Эпохи: 4800, Время: 6.5269c, MSE: 6.9107e-01
# Experiment 549/216
# Эпохи: 7200, Время: 9.1180c, MSE: 1.0644e-02
# Experiment 550/216
# Эпохи: 2400, Время: 6.1842c, MSE: 6.8356e-01
# Experiment 551/216
# Эпохи: 4800, Время: 10.9085c, MSE: 3.1392e-01
# Experiment 552/216
# Эпохи: 7200, Время: 15.7181c, MSE: 9.3915e-03
# Experiment 553/216
# Эпохи: 2400, Время: 0.8282c, MSE: 1.0221e+04
# Experiment 554/216
# Эпохи: 4800, Время: 1.4641c, MSE: 1.0220e+04
# Experiment 555/216
# Эпохи: 7200, Время: 1.7796c, MSE: 1.0221e+04
# Experiment 556/216
# Эпохи: 2400, Время: 0.9782c, MSE: 1.0142e+04
# Experiment 557/216
# Эпохи: 4800, Время: 1.4622c, MSE: 1.0158e+04
# Experiment 558/216
# Эпохи: 7200, Время: 1.8870c, MSE: 1.0142e+04
# Experiment 559/216
# Эпохи: 2400, Время: 1.1649c, MSE: 1.0092e+04
# Experiment 560/216
# Эпохи: 4800, Время: 1.9228c, MSE: 1.0097e+04
# Experiment 561/216
# Эпохи: 7200, Время: 2.4587c, MSE: 1.0092e+04
# Experiment 562/216
# Эпохи: 2400, Время: 1.4750c, MSE: 1.0087e+04
# Experiment 563/216
# Эпохи: 4800, Время: 2.2693c, MSE: 1.0087e+04
# Experiment 564/216
# Эпохи: 7200, Время: 3.3496c, MSE: 1.0087e+04
# Experiment 565/216
# Эпохи: 2400, Время: 1.5515c, MSE: 1.1004e+04
# Experiment 566/216
# Эпохи: 4800, Время: 2.2611c, MSE: 1.1004e+04
# Experiment 567/216
# Эпохи: 7200, Время: 3.1617c, MSE: 1.3072e+01
# Experiment 568/216
# Эпохи: 2400, Время: 1.7581c, MSE: 1.1004e+04
# Experiment 569/216
# Эпохи: 4800, Время: 3.0898c, MSE: 1.1004e+04
# Experiment 570/216
# Эпохи: 7200, Время: 4.5729c, MSE: 5.7879e+00
# Experiment 571/216
# Эпохи: 2400, Время: 2.4878c, MSE: 1.1004e+04
# Experiment 572/216
# Эпохи: 4800, Время: 4.4465c, MSE: 1.1004e+04
# Experiment 573/216
# Эпохи: 7200, Время: 6.8954c, MSE: 7.5991e+00
# Experiment 574/216
# Эпохи: 2400, Время: 4.7206c, MSE: 1.1004e+04
# Experiment 575/216
# Эпохи: 4800, Время: 9.2891c, MSE: 1.1004e+04
# Experiment 576/216
# Эпохи: 7200, Время: 14.4164c, MSE: 7.6750e-01
# Experiment 577/216
# Эпохи: 2400, Время: 3.1614c, MSE: 1.1003e+04
# Experiment 578/216
# Эпохи: 4800, Время: 6.3012c, MSE: 1.1004e+04
# Experiment 579/216
# Эпохи: 7200, Время: 8.3202c, MSE: 1.1004e+04
# Experiment 580/216
# Эпохи: 2400, Время: 4.4413c, MSE: 1.1003e+04
# Experiment 581/216
# Эпохи: 4800, Время: 7.1860c, MSE: 1.1004e+04
# Experiment 582/216
# Эпохи: 7200, Время: 11.2896c, MSE: 1.1004e+04
# Experiment 583/216
# Эпохи: 2400, Время: 5.4099c, MSE: 1.1003e+04
# Experiment 584/216
# Эпохи: 4800, Время: 9.5733c, MSE: 1.1004e+04
# Experiment 585/216
# Эпохи: 7200, Время: 14.4924c, MSE: 1.1004e+04
# Experiment 586/216
# Эпохи: 2400, Время: 9.6557c, MSE: 1.1003e+04
# Experiment 587/216
# Эпохи: 4800, Время: 19.6002c, MSE: 1.1004e+04
# Experiment 588/216
# Эпохи: 7200, Время: 29.1113c, MSE: 1.1004e+04
# Experiment 589/216
# Эпохи: 2400, Время: 2.9425c, MSE: 6.3872e-01
# Experiment 590/216
# Эпохи: 4800, Время: 5.3283c, MSE: 3.1174e-01
# Experiment 591/216
# Эпохи: 7200, Время: 7.4546c, MSE: 4.3642e+00
# Experiment 592/216
# Эпохи: 2400, Время: 4.2302c, MSE: 2.8912e-02
# Experiment 593/216
# Эпохи: 4800, Время: 7.7567c, MSE: 1.7027e+01
# Experiment 594/216
# Эпохи: 7200, Время: 11.5155c, MSE: 1.0817e-02
# Experiment 595/216
# Эпохи: 2400, Время: 6.8088c, MSE: 9.2732e-01
# Experiment 596/216
# Эпохи: 4800, Время: 12.0629c, MSE: 1.4860e+01
# Experiment 597/216
# Эпохи: 7200, Время: 16.0886c, MSE: 1.9088e+00
# Experiment 598/216
# Эпохи: 2400, Время: 9.3330c, MSE: 6.1987e-02
# Experiment 599/216
# Эпохи: 4800, Время: 17.9546c, MSE: 7.1824e+00
# Experiment 600/216
# Эпохи: 7200, Время: 25.5102c, MSE: 9.2049e-02
# Experiment 601/216
# Эпохи: 2400, Время: 3.7984c, MSE: 1.2724e+01
# Experiment 602/216
# Эпохи: 4800, Время: 7.6539c, MSE: 7.7359e+00
# Experiment 603/216
# Эпохи: 7200, Время: 11.0157c, MSE: 2.3512e+00
# Experiment 604/216
# Эпохи: 2400, Время: 5.3245c, MSE: 1.1938e-02
# Experiment 605/216
# Эпохи: 4800, Время: 10.4345c, MSE: 2.2280e-02
# Experiment 606/216
# Эпохи: 7200, Время: 14.8007c, MSE: 5.3309e+04
# Experiment 607/216
# Эпохи: 2400, Время: 8.7030c, MSE: 5.5487e-01
# Experiment 608/216
# Эпохи: 4800, Время: 17.0886c, MSE: 1.4672e-02
# Experiment 609/216
# Эпохи: 7200, Время: 26.1256c, MSE: 3.0711e+03
# Experiment 610/216
# Эпохи: 2400, Время: 15.5478c, MSE: 3.5406e-01
# Experiment 611/216
# Эпохи: 4800, Время: 27.8719c, MSE: 1.2240e-01
# Experiment 612/216
# Эпохи: 7200, Время: 44.9621c, MSE: 3.2356e+00
# Experiment 613/216
# Эпохи: 2400, Время: 3.4709c, MSE: 4.5543e-01
# Experiment 614/216
# Эпохи: 4800, Время: 5.5272c, MSE: 1.9267e+01
# Experiment 615/216
# Эпохи: 7200, Время: 7.6261c, MSE: 5.5652e-01
# Experiment 616/216
# Эпохи: 2400, Время: 5.0682c, MSE: 4.6546e-01
# Experiment 617/216
# Эпохи: 4800, Время: 9.3076c, MSE: 6.1980e-01
# Experiment 618/216
# Эпохи: 7200, Время: 12.5514c, MSE: 9.5348e-03
# Experiment 619/216
# Эпохи: 2400, Время: 7.6234c, MSE: 2.8445e+00
# Experiment 620/216
# Эпохи: 4800, Время: 13.7069c, MSE: 2.2703e-04
# Experiment 621/216
# Эпохи: 7200, Время: 16.9246c, MSE: 4.1037e-04
# Experiment 622/216
# Эпохи: 2400, Время: 9.3845c, MSE: 2.7514e-01
# Experiment 623/216
# Эпохи: 4800, Время: 19.3749c, MSE: 8.8340e-01
# Experiment 624/216
# Эпохи: 7200, Время: 30.5530c, MSE: 6.9352e+01
# Experiment 625/216
# Эпохи: 2400, Время: 0.9301c, MSE: 1.0221e+04
# Experiment 626/216
# Эпохи: 4800, Время: 1.4752c, MSE: 1.0209e+04
# Experiment 627/216
# Эпохи: 7200, Время: 1.8933c, MSE: 1.0227e+04
# Experiment 628/216
# Эпохи: 2400, Время: 1.1952c, MSE: 1.0142e+04
# Experiment 629/216
# Эпохи: 4800, Время: 1.5362c, MSE: 1.0147e+04
# Experiment 630/216
# Эпохи: 7200, Время: 2.1615c, MSE: 1.0143e+04
# Experiment 631/216
# Эпохи: 2400, Время: 1.3020c, MSE: 1.0092e+04
# Experiment 632/216
# Эпохи: 4800, Время: 2.5431c, MSE: 1.0092e+04
# Experiment 633/216
# Эпохи: 7200, Время: 3.3427c, MSE: 9.6748e+03
# Experiment 634/216
# Эпохи: 2400, Время: 2.3184c, MSE: 1.0087e+04
# Experiment 635/216
# Эпохи: 4800, Время: 4.2762c, MSE: 9.8397e+03
# Experiment 636/216
# Эпохи: 7200, Время: 6.1835c, MSE: 1.0087e+04
# Experiment 637/216
# Эпохи: 2400, Время: 2.2976c, MSE: 1.1003e+04
# Experiment 638/216
# Эпохи: 4800, Время: 3.8669c, MSE: 1.1004e+04
# Experiment 639/216
# Эпохи: 7200, Время: 5.8433c, MSE: 1.1004e+04
# Experiment 640/216
# Эпохи: 2400, Время: 3.3605c, MSE: 1.1003e+04
# Experiment 641/216
# Эпохи: 4800, Время: 5.9571c, MSE: 1.1004e+04
# Experiment 642/216
# Эпохи: 7200, Время: 8.5903c, MSE: 1.1004e+04
# Experiment 643/216
# Эпохи: 2400, Время: 5.0526c, MSE: 1.1003e+04
# Experiment 644/216
# Эпохи: 4800, Время: 9.0448c, MSE: 1.1004e+04
# Experiment 645/216
# Эпохи: 7200, Время: 13.2793c, MSE: 1.1004e+04
# Experiment 646/216
# Эпохи: 2400, Время: 9.6527c, MSE: 1.1003e+04
# Experiment 647/216
# Эпохи: 4800, Время: 15.9302c, MSE: 1.1004e+04
# Experiment 648/216
# Эпохи: 7200, Время: 21.7670c, MSE: 1.1004e+04
# Experiments finished. Results saved to csv_results/1D_sphere_robin_results.csv
#      bc_left bc_right training_time  epoches    lr activation_func  layers  \
# 0  dirichlet    robin        0.8373     2400  0.01            tanh       1
# 1  dirichlet    robin        1.3386     4800  0.01            tanh       1
# 2  dirichlet    robin        1.6041     7200  0.01            tanh       1
# 3  dirichlet    robin        0.9624     2400  0.01            tanh       1
# 4  dirichlet    robin        1.3312     4800  0.01            tanh       1
#
#    neurons optimizer  collocation_points        mape         mae         mse  \
# 0       32      adam                  12  1.8647e-01  6.8124e+01  6.9715e+03
# 1       32      adam                  12  2.4443e-02  9.0018e+00  1.1397e+02
# 2       32      adam                  12  2.7197e-03  1.1136e+00  1.4644e+00
# 3       32      adam                  22  1.8646e-01  6.8123e+01  6.9713e+03
# 4       32      adam                  22  2.5822e-02  9.6225e+00  1.1982e+02
#
#          rmse   max_error    weights
# 0  8.3495e+01  1.7259e+02  [1, 5, 5]
# 1  1.0676e+01  2.2249e+01  [1, 5, 5]
# 2  1.2101e+00  1.7433e+00  [1, 5, 5]
# 3  8.3495e+01  1.7259e+02  [1, 5, 5]
# 4  1.0946e+01  2.0994e+01  [1, 5, 5]
