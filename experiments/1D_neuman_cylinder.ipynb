# %%
import jax
import jax.numpy as jnp
import flax.nnx as nnx
import optax
import matplotlib.pyplot as plt
import pandas as pd
import os
from dataclasses import dataclass
from functools import partial

# %%
from geom import Interval
from pinn_core import PINN, FCNet
from pde import cylinder_1d
from bc import dirichlet_bc, neuman_bc
from analytic import cylinder_1d_neuman_exact

# %%
plt.rcParams.update({
    'font.size': 14,
    'axes.titlesize': 14,
    'axes.labelsize': 14,
    'xtick.labelsize': 14,
    'ytick.labelsize': 14,
    'legend.fontsize': 14,
    'figure.titlesize': 16,
})

# %%
@dataclass(frozen=True)
class PhysicsParams:
    L: float = 1.0
    x_left: float = 0.3
    x_right: float = 0.6
    T_left: float = 400.0
    q_right: float = -100.0
    _lambda: float = 1.0

    @property
    def grad_right(self):
        return -self.q_right / self._lambda

# %%
def get_activation(name):
    mapping = {
        'tanh': nnx.tanh,
        'Swish': nnx.silu,
        'sin': jnp.sin,
        'GELU': nnx.gelu,
        'ReLU': nnx.relu,
        'Sigmoid': nnx.sigmoid,
    }
    return mapping.get(name, nnx.relu)

def get_optimizer(name, lr):
    mapping = {'adam': optax.adam(lr)}
    return mapping.get(name, optax.adam(lr))

# %%
def train_model(
    hidden_features, num_layers, activation_name, lr,
    num_points, opt_name, epochs, weights, save_img=False, show_plot=False
):
    phys = PhysicsParams()
    
    geom = Interval(phys.x_left, phys.x_right)
    x_collocation = geom.generate_collocation(n_interior=num_points, method='random')
    total_points = x_collocation.shape[0]

    act_fn = get_activation(activation_name)
    net = FCNet(din=1, dmid=hidden_features, dout=1, num_layers=num_layers, activation=act_fn, rngs=nnx.Rngs(0))
    
    optimizer = get_optimizer(opt_name, lr=lr)
    pinn = PINN(net, opt=optimizer, weights=weights)

    bc_fns = [
        partial(dirichlet_bc, x=phys.x_left, T=phys.T_left),
        partial(neuman_bc, x=phys.x_right, g=phys.grad_right)
    ]

    history, training_time = pinn.fit(
        x_collocation=x_collocation,
        pde_fn=cylinder_1d,
        bc_fns=bc_fns,
        phys=phys,
        epochs=epochs
    )

    x_test = jnp.linspace(phys.x_left, phys.x_right, 100).reshape(-1, 1)
    metrics, T_pred, T_exact = pinn.evaluate(
        x_test, cylinder_1d_neuman_exact, phys, bc_names=['dirichlet', 'neuman']
    )

    print(f'Эпохи: {epochs}, Время: {training_time:.4f}c, MSE: {metrics['mse']}')

    if save_img:
        pinn.save_plot(x_test, T_pred, T_exact, phys, save_path=f'images/pinn/1D_cylinder_Neuman_{epochs}.png')

    if show_plot:
        pinn.show_plot(x_test, T_pred, T_exact, phys)

    result = {
        'bc_left': metrics['bc_left'],
        'bc_right': metrics['bc_right'],
        'training_time': f'{training_time:.4f}',
        'epoches': epochs,
        'lr': lr,
        'activation_func': activation_name,
        'layers': num_layers,
        'neurons': hidden_features,
        'optimizer': opt_name,
        'collocation_points': total_points,
        'mape': metrics['mape'],
        'mae': metrics['mae'],
        'mse': metrics['mse'],
        'rmse': metrics['rmse'],
        'max_error': metrics['max_error'],
        'weights': f'{weights}',
    }

    return result, history

# %%
def find_optimal_epochs(
    target_mape, max_epochs, step,
    hidden_features, num_layers,
    activation_name, lr,
    num_points, opt_name,
    weights
):
    for epochs in range(step, max_epochs + 1, step):
        metrics, history = train_model(
            hidden_features, num_layers, activation_name, lr,
            num_points, opt_name, epochs, weights, save_img=False
        )
        if float(metrics['mape']) < target_mape:
            return epochs
    return max_epochs

# %%
def try_experiments(eph, lr, csv_path='csv_results/1D_cylinder_neuman_results.csv'):
    num_hidden = [32, 64, 128]
    num_layers = [1, 2, 3]
    activation = ['tanh', 'Swish', 'sin', 'GELU', 'ReLU', 'Sigmoid']
    num_interior = [10, 20, 50, 100]
    optimizer = ['adam']
    epochs = [eph]
    weights = [1.0, 1.0, 1.0]
    
    results = []
    exp = 0

    for h in num_hidden:
        for l in num_layers:
            for a in activation:
                for col in num_interior:
                    for opt in optimizer:
                        for epoch in epochs:
                            exp += 1
                            print(f'Experiment {exp}/{len(num_hidden)*len(num_layers)*len(activation)*len(num_interior)}')
                            res, history = train_model(h, l, a, lr, col, opt, epoch, weights)
                            results.append(res)

    df_results = pd.DataFrame(results)
    os.makedirs(os.path.dirname(csv_path), exist_ok=True)
    df_results.to_csv(csv_path, mode='a', header=not os.path.exists(csv_path), index=False)
    print(f'Experiments finished. Results saved to {csv_path}')
    return df_results

# %%
# Оптимальные эпохи
learning_rate = 0.01
weights=[1, 1, 1]

optimal_epochs = find_optimal_epochs(
    target_mape=0.001, max_epochs=3000, step=50,
    hidden_features=64, num_layers=2,
    activation_name='GELU', lr=learning_rate,
    num_points=100, opt_name='adam',
    weights=weights
)
optimal_epochs
# Out:
# Эпохи: 50, Время: 2.3237c, MSE: 3.8108e+04
# Эпохи: 100, Время: 2.1651c, MSE: 1.0461e+01
# Эпохи: 150, Время: 2.2897c, MSE: 3.1646e-02
# 150

# %%
metrics, history = train_model(
    hidden_features=64, num_layers=2, 
    activation_name='GELU', lr=learning_rate, 
    num_points=100, opt_name='adam', 
    epochs=optimal_epochs, show_plot=True, save_img=True,
    weights=weights
)
metrics
# Out:
# Эпохи: 150, Время: 2.2116c, MSE: 3.1646e-02
# {'bc_left': 'dirichlet',
#  'bc_right': 'neuman',
#  'training_time': '2.2116',
#  'epoches': 150,
#  'lr': 0.01,
#  'activation_func': 'GELU',
#  'layers': 2,
#  'neurons': 64,
#  'optimizer': 'adam',
#  'collocation_points': 102,
#  'mape': '4.2083e-04',
#  'mae': '1.7787e-01',
#  'mse': '3.1646e-02',
#  'rmse': '1.7789e-01',
#  'max_error': '1.8622e-01',
#  'weights': '[1, 1, 1]'}

# %%
history.keys()
# Out:
# dict_keys(['steps', 'total_loss', 'pde', 'bc_0', 'bc_1'])

# %%
plt.figure(figsize=(12, 7))
steps = history['steps']

plt.semilogy(steps, history['pde'], 'b', label='PDE Потери', linewidth=2) # PDE
plt.semilogy(steps, history['bc_0'], 'r--', label='ГУ слева', linewidth=2, alpha=0.7) # Boundary Conditions
plt.semilogy(steps, history['bc_1'], 'r--', label='ГУ справа', linewidth=2, alpha=0.7)
plt.semilogy(steps, history['total_loss'], 'g--', label='Общая ошибка', linewidth=2, alpha=0.7)

plt.title('История Обучения')
plt.xlabel('Эпохи')
plt.ylabel('Потери')
plt.legend(loc='upper right')
plt.grid(True, alpha=0.3, which="both")
plt.tight_layout()
plt.savefig('images/history_cylinder_neuman', dpi=72, bbox_inches='tight')
plt.show()

# %%
df_results = try_experiments(optimal_epochs, lr=learning_rate)
df_results.head()
# Out:
# Experiment 1/216
# Эпохи: 150, Время: 1.0926c, MSE: 1.3446e+05
# Experiment 2/216
# Эпохи: 150, Время: 1.2082c, MSE: 1.3450e+05
# Experiment 3/216
# Эпохи: 150, Время: 1.2311c, MSE: 1.3451e+05
# Experiment 4/216
# Эпохи: 150, Время: 1.1883c, MSE: 1.3451e+05
# Experiment 5/216
# Эпохи: 150, Время: 0.9968c, MSE: 1.0866e+05
# Experiment 6/216
# Эпохи: 150, Время: 1.0162c, MSE: 1.0758e+05
# Experiment 7/216
# Эпохи: 150, Время: 0.9178c, MSE: 1.0695e+05
# Experiment 8/216
# Эпохи: 150, Время: 1.0627c, MSE: 1.0688e+05
# Experiment 9/216
# Эпохи: 150, Время: 0.8214c, MSE: 1.3431e+05
# Experiment 10/216
# Эпохи: 150, Время: 0.8122c, MSE: 1.3441e+05
# Experiment 11/216
# Эпохи: 150, Время: 0.7994c, MSE: 1.3445e+05
# Experiment 12/216
# Эпохи: 150, Время: 0.8634c, MSE: 1.3445e+05
# Experiment 13/216
# Эпохи: 150, Время: 1.2029c, MSE: 1.0007e+05
# Experiment 14/216
# Эпохи: 150, Время: 1.2697c, MSE: 9.9262e+04
# Experiment 15/216
# Эпохи: 150, Время: 2.0213c, MSE: 9.8896e+04
# Experiment 16/216
# Эпохи: 150, Время: 1.9473c, MSE: 9.8853e+04
# Experiment 17/216
# Эпохи: 150, Время: 0.6595c, MSE: 1.2233e+05
# Experiment 18/216
# Эпохи: 150, Время: 0.6572c, MSE: 1.2129e+05
# Experiment 19/216
# Эпохи: 150, Время: 0.6980c, MSE: 1.2064e+05
# Experiment 20/216
# Эпохи: 150, Время: 0.6488c, MSE: 1.2057e+05
# Experiment 21/216
# Эпохи: 150, Время: 0.8629c, MSE: 1.3898e+05
# Experiment 22/216
# Эпохи: 150, Время: 0.8727c, MSE: 1.3898e+05
# Experiment 23/216
# Эпохи: 150, Время: 0.8947c, MSE: 1.3898e+05
# Experiment 24/216
# Эпохи: 150, Время: 0.8609c, MSE: 1.3898e+05
# Experiment 25/216
# Эпохи: 150, Время: 1.3868c, MSE: 1.3661e+05
# Experiment 26/216
# Эпохи: 150, Время: 1.6334c, MSE: 1.3662e+05
# Experiment 27/216
# Эпохи: 150, Время: 1.7518c, MSE: 1.3663e+05
# Experiment 28/216
# Эпохи: 150, Время: 1.8617c, MSE: 1.3663e+05
# Experiment 29/216
# Эпохи: 150, Время: 1.5069c, MSE: 1.1776e-01
# Experiment 30/216
# Эпохи: 150, Время: 1.5373c, MSE: 1.5385e+00
# Experiment 31/216
# Эпохи: 150, Время: 1.5396c, MSE: 1.0950e+00
# Experiment 32/216
# Эпохи: 150, Время: 1.5112c, MSE: 1.1641e+00
# Experiment 33/216
# Эпохи: 150, Время: 1.3102c, MSE: 1.3608e+05
# Experiment 34/216
# Эпохи: 150, Время: 1.3650c, MSE: 1.3592e+05
# Experiment 35/216
# Эпохи: 150, Время: 1.1931c, MSE: 1.3592e+05
# Experiment 36/216
# Эпохи: 150, Время: 1.3664c, MSE: 1.3590e+05
# Experiment 37/216
# Эпохи: 150, Время: 2.1241c, MSE: 2.7842e+00
# Experiment 38/216
# Эпохи: 150, Время: 2.0169c, MSE: 1.1807e+00
# Experiment 39/216
# Эпохи: 150, Время: 2.1657c, MSE: 6.0929e-02
# Experiment 40/216
# Эпохи: 150, Время: 2.1122c, MSE: 9.1304e-02
# Experiment 41/216
# Эпохи: 150, Время: 0.8600c, MSE: 1.2323e+03
# Experiment 42/216
# Эпохи: 150, Время: 1.1279c, MSE: 9.9816e+02
# Experiment 43/216
# Эпохи: 150, Время: 1.0987c, MSE: 9.7933e+02
# Experiment 44/216
# Эпохи: 150, Время: 1.1521c, MSE: 9.7772e+02
# Experiment 45/216
# Эпохи: 150, Время: 1.2387c, MSE: 1.4419e+05
# Experiment 46/216
# Эпохи: 150, Время: 1.2744c, MSE: 1.4419e+05
# Experiment 47/216
# Эпохи: 150, Время: 1.3640c, MSE: 1.4419e+05
# Experiment 48/216
# Эпохи: 150, Время: 1.3553c, MSE: 1.4419e+05
# Experiment 49/216
# Эпохи: 150, Время: 1.6822c, MSE: 1.3652e+05
# Experiment 50/216
# Эпохи: 150, Время: 1.8505c, MSE: 1.3652e+05
# Experiment 51/216
# Эпохи: 150, Время: 2.0289c, MSE: 1.3653e+05
# Experiment 52/216
# Эпохи: 150, Время: 2.0696c, MSE: 1.3653e+05
# Experiment 53/216
# Эпохи: 150, Время: 1.8670c, MSE: 2.3212e-01
# Experiment 54/216
# Эпохи: 150, Время: 1.9481c, MSE: 3.4331e-01
# Experiment 55/216
# Эпохи: 150, Время: 1.8844c, MSE: 7.5301e-03
# Experiment 56/216
# Эпохи: 150, Время: 2.0250c, MSE: 7.1020e-02
# Experiment 57/216
# Эпохи: 150, Время: 1.6947c, MSE: 1.3670e+05
# Experiment 58/216
# Эпохи: 150, Время: 1.7214c, MSE: 1.3667e+05
# Experiment 59/216
# Эпохи: 150, Время: 1.5398c, MSE: 1.3649e+05
# Experiment 60/216
# Эпохи: 150, Время: 1.7283c, MSE: 1.3653e+05
# Experiment 61/216
# Эпохи: 150, Время: 2.7538c, MSE: 9.1379e-02
# Experiment 62/216
# Эпохи: 150, Время: 2.8265c, MSE: 7.0618e-02
# Experiment 63/216
# Эпохи: 150, Время: 3.0479c, MSE: 7.4251e-03
# Experiment 64/216
# Эпохи: 150, Время: 2.8511c, MSE: 1.0043e-02
# Experiment 65/216
# Эпохи: 150, Время: 1.0605c, MSE: 5.7567e+02
# Experiment 66/216
# Эпохи: 150, Время: 0.8721c, MSE: 5.6517e+02
# Experiment 67/216
# Эпохи: 150, Время: 0.6869c, MSE: 5.6108e+02
# Experiment 68/216
# Эпохи: 150, Время: 0.9038c, MSE: 5.6016e+02
# Experiment 69/216
# Эпохи: 150, Время: 1.4401c, MSE: 1.4465e+05
# Experiment 70/216
# Эпохи: 150, Время: 1.6415c, MSE: 1.4465e+05
# Experiment 71/216
# Эпохи: 150, Время: 1.7132c, MSE: 1.4465e+05
# Experiment 72/216
# Эпохи: 150, Время: 1.7679c, MSE: 1.4465e+05
# Experiment 73/216
# Эпохи: 150, Время: 0.8990c, MSE: 9.9553e+04
# Experiment 74/216
# Эпохи: 150, Время: 0.9117c, MSE: 9.9681e+04
# Experiment 75/216
# Эпохи: 150, Время: 0.9192c, MSE: 9.9741e+04
# Experiment 76/216
# Эпохи: 150, Время: 0.9027c, MSE: 9.9748e+04
# Experiment 77/216
# Эпохи: 150, Время: 1.0490c, MSE: 6.2685e+04
# Experiment 78/216
# Эпохи: 150, Время: 0.9779c, MSE: 6.1791e+04
# Experiment 79/216
# Эпохи: 150, Время: 0.9602c, MSE: 6.1396e+04
# Experiment 80/216
# Эпохи: 150, Время: 0.9712c, MSE: 6.1348e+04
# Experiment 81/216
# Эпохи: 150, Время: 0.9965c, MSE: 9.9137e+04
# Experiment 82/216
# Эпохи: 150, Время: 0.7667c, MSE: 9.9421e+04
# Experiment 83/216
# Эпохи: 150, Время: 0.7655c, MSE: 9.9539e+04
# Experiment 84/216
# Эпохи: 150, Время: 0.8064c, MSE: 9.9543e+04
# Experiment 85/216
# Эпохи: 150, Время: 1.1990c, MSE: 5.1524e+04
# Experiment 86/216
# Эпохи: 150, Время: 1.2686c, MSE: 5.1162e+04
# Experiment 87/216
# Эпохи: 150, Время: 1.3433c, MSE: 5.1250e+04
# Experiment 88/216
# Эпохи: 150, Время: 1.3339c, MSE: 5.1245e+04
# Experiment 89/216
# Эпохи: 150, Время: 0.7056c, MSE: 8.4832e+04
# Experiment 90/216
# Эпохи: 150, Время: 0.6317c, MSE: 8.4623e+04
# Experiment 91/216
# Эпохи: 150, Время: 0.4581c, MSE: 8.4466e+04
# Experiment 92/216
# Эпохи: 150, Время: 0.4178c, MSE: 8.4448e+04
# Experiment 93/216
# Эпохи: 150, Время: 0.4428c, MSE: 1.0585e+05
# Experiment 94/216
# Эпохи: 150, Время: 0.4782c, MSE: 1.0585e+05
# Experiment 95/216
# Эпохи: 150, Время: 0.5419c, MSE: 1.0584e+05
# Experiment 96/216
# Эпохи: 150, Время: 0.8641c, MSE: 1.0584e+05
# Experiment 97/216
# Эпохи: 150, Время: 1.0216c, MSE: 1.0431e+05
# Experiment 98/216
# Эпохи: 150, Время: 1.3761c, MSE: 1.0436e+05
# Experiment 99/216
# Эпохи: 150, Время: 1.2523c, MSE: 1.0438e+05
# Experiment 100/216
# Эпохи: 150, Время: 1.4577c, MSE: 1.0438e+05
# Experiment 101/216
# Эпохи: 150, Время: 1.6682c, MSE: 8.6943e-02
# Experiment 102/216
# Эпохи: 150, Время: 1.6287c, MSE: 4.3259e-02
# Experiment 103/216
# Эпохи: 150, Время: 1.5808c, MSE: 2.4661e-02
# Experiment 104/216
# Эпохи: 150, Время: 1.6033c, MSE: 9.0921e-03
# Experiment 105/216
# Эпохи: 150, Время: 1.5084c, MSE: 1.0263e+05
# Experiment 106/216
# Эпохи: 150, Время: 1.4845c, MSE: 1.0249e+05
# Experiment 107/216
# Эпохи: 150, Время: 1.3821c, MSE: 1.0253e+05
# Experiment 108/216
# Эпохи: 150, Время: 1.7807c, MSE: 1.0244e+05
# Experiment 109/216
# Эпохи: 150, Время: 2.3922c, MSE: 2.8342e-02
# Experiment 110/216
# Эпохи: 150, Время: 2.2840c, MSE: 5.7024e-02
# Experiment 111/216
# Эпохи: 150, Время: 2.2133c, MSE: 1.7655e-02
# Experiment 112/216
# Эпохи: 150, Время: 2.4914c, MSE: 3.1646e-02
# Experiment 113/216
# Эпохи: 150, Время: 1.1759c, MSE: 6.6761e+02
# Experiment 114/216
# Эпохи: 150, Время: 1.0906c, MSE: 6.3747e+02
# Experiment 115/216
# Эпохи: 150, Время: 0.9522c, MSE: 6.2047e+02
# Experiment 116/216
# Эпохи: 150, Время: 0.9088c, MSE: 6.5078e+02
# Experiment 117/216
# Эпохи: 150, Время: 1.3377c, MSE: 1.1759e+05
# Experiment 118/216
# Эпохи: 150, Время: 1.3465c, MSE: 1.1759e+05
# Experiment 119/216
# Эпохи: 150, Время: 1.3468c, MSE: 1.1759e+05
# Experiment 120/216
# Эпохи: 150, Время: 1.3706c, MSE: 1.1759e+05
# Experiment 121/216
# Эпохи: 150, Время: 1.9865c, MSE: 1.0436e+05
# Experiment 122/216
# Эпохи: 150, Время: 1.9925c, MSE: 1.0438e+05
# Experiment 123/216
# Эпохи: 150, Время: 1.8233c, MSE: 1.0438e+05
# Experiment 124/216
# Эпохи: 150, Время: 2.0029c, MSE: 1.0438e+05
# Experiment 125/216
# Эпохи: 150, Время: 1.9917c, MSE: 1.0805e-02
# Experiment 126/216
# Эпохи: 150, Время: 1.9461c, MSE: 3.1147e-02
# Experiment 127/216
# Эпохи: 150, Время: 1.9874c, MSE: 3.8366e-02
# Experiment 128/216
# Эпохи: 150, Время: 1.9928c, MSE: 8.5826e-03
# Experiment 129/216
# Эпохи: 150, Время: 1.8741c, MSE: 1.0363e+05
# Experiment 130/216
# Эпохи: 150, Время: 1.7989c, MSE: 1.0379e+05
# Experiment 131/216
# Эпохи: 150, Время: 1.8762c, MSE: 1.0385e+05
# Experiment 132/216
# Эпохи: 150, Время: 2.4005c, MSE: 1.0382e+05
# Experiment 133/216
# Эпохи: 150, Время: 3.1616c, MSE: 1.4790e-01
# Experiment 134/216
# Эпохи: 150, Время: 3.2554c, MSE: 1.6725e-03
# Experiment 135/216
# Эпохи: 150, Время: 3.0679c, MSE: 1.7213e-02
# Experiment 136/216
# Эпохи: 150, Время: 3.2268c, MSE: 1.3042e-02
# Experiment 137/216
# Эпохи: 150, Время: 1.1531c, MSE: 5.2965e+02
# Experiment 138/216
# Эпохи: 150, Время: 1.2232c, MSE: 5.2036e+02
# Experiment 139/216
# Эпохи: 150, Время: 1.0810c, MSE: 5.1484e+02
# Experiment 140/216
# Эпохи: 150, Время: 1.0226c, MSE: 5.1383e+02
# Experiment 141/216
# Эпохи: 150, Время: 1.6616c, MSE: 1.2694e+05
# Experiment 142/216
# Эпохи: 150, Время: 1.6710c, MSE: 1.2694e+05
# Experiment 143/216
# Эпохи: 150, Время: 1.6163c, MSE: 1.2694e+05
# Experiment 144/216
# Эпохи: 150, Время: 1.7578c, MSE: 1.2694e+05
# Experiment 145/216
# Эпохи: 150, Время: 1.0221c, MSE: 4.9801e+04
# Experiment 146/216
# Эпохи: 150, Время: 0.9757c, MSE: 5.0012e+04
# Experiment 147/216
# Эпохи: 150, Время: 1.0204c, MSE: 5.0128e+04
# Experiment 148/216
# Эпохи: 150, Время: 1.0537c, MSE: 5.0146e+04
# Experiment 149/216
# Эпохи: 150, Время: 1.2539c, MSE: 2.0134e+04
# Experiment 150/216
# Эпохи: 150, Время: 0.9409c, MSE: 1.9606e+04
# Experiment 151/216
# Эпохи: 150, Время: 1.0691c, MSE: 1.9431e+04
# Experiment 152/216
# Эпохи: 150, Время: 1.0146c, MSE: 1.9394e+04
# Experiment 153/216
# Эпохи: 150, Время: 0.8050c, MSE: 4.8909e+04
# Experiment 154/216
# Эпохи: 150, Время: 0.8114c, MSE: 4.9361e+04
# Experiment 155/216
# Эпохи: 150, Время: 0.7660c, MSE: 4.9574e+04
# Experiment 156/216
# Эпохи: 150, Время: 0.9474c, MSE: 4.9581e+04
# Experiment 157/216
# Эпохи: 150, Время: 1.3503c, MSE: 1.2878e+04
# Experiment 158/216
# Эпохи: 150, Время: 1.3100c, MSE: 1.2873e+04
# Experiment 159/216
# Эпохи: 150, Время: 1.3220c, MSE: 1.3098e+04
# Experiment 160/216
# Эпохи: 150, Время: 1.3554c, MSE: 1.3122e+04
# Experiment 161/216
# Эпохи: 150, Время: 1.0777c, MSE: 4.1919e+04
# Experiment 162/216
# Эпохи: 150, Время: 0.7890c, MSE: 4.1990e+04
# Experiment 163/216
# Эпохи: 150, Время: 0.7364c, MSE: 4.1496e+04
# Experiment 164/216
# Эпохи: 150, Время: 0.6961c, MSE: 4.1485e+04
# Experiment 165/216
# Эпохи: 150, Время: 0.9778c, MSE: 5.7665e+04
# Experiment 166/216
# Эпохи: 150, Время: 0.8641c, MSE: 5.7626e+04
# Experiment 167/216
# Эпохи: 150, Время: 1.0058c, MSE: 5.7611e+04
# Experiment 168/216
# Эпохи: 150, Время: 0.9197c, MSE: 5.7609e+04
# Experiment 169/216
# Эпохи: 150, Время: 1.4568c, MSE: 5.7731e+04
# Experiment 170/216
# Эпохи: 150, Время: 1.4517c, MSE: 5.7833e+04
# Experiment 171/216
# Эпохи: 150, Время: 1.4693c, MSE: 5.7882e+04
# Experiment 172/216
# Эпохи: 150, Время: 1.6655c, MSE: 5.7887e+04
# Experiment 173/216
# Эпохи: 150, Время: 1.8149c, MSE: 1.9693e-01
# Experiment 174/216
# Эпохи: 150, Время: 1.7976c, MSE: 1.9116e-01
# Experiment 175/216
# Эпохи: 150, Время: 1.8053c, MSE: 4.8637e-02
# Experiment 176/216
# Эпохи: 150, Время: 2.1727c, MSE: 3.8523e-02
# Experiment 177/216
# Эпохи: 150, Время: 1.4588c, MSE: 5.4805e+04
# Experiment 178/216
# Эпохи: 150, Время: 1.6348c, MSE: 5.4666e+04
# Experiment 179/216
# Эпохи: 150, Время: 1.6605c, MSE: 5.4430e+04
# Experiment 180/216
# Эпохи: 150, Время: 1.9662c, MSE: 5.4630e+04
# Experiment 181/216
# Эпохи: 150, Время: 2.1915c, MSE: 9.6209e-02
# Experiment 182/216
# Эпохи: 150, Время: 2.3305c, MSE: 8.2479e-03
# Experiment 183/216
# Эпохи: 150, Время: 2.2477c, MSE: 4.8981e-02
# Experiment 184/216
# Эпохи: 150, Время: 2.6022c, MSE: 2.5236e-02
# Experiment 185/216
# Эпохи: 150, Время: 0.9568c, MSE: 6.1446e+02
# Experiment 186/216
# Эпохи: 150, Время: 1.0645c, MSE: 6.0215e+02
# Experiment 187/216
# Эпохи: 150, Время: 1.0015c, MSE: 5.9183e+02
# Experiment 188/216
# Эпохи: 150, Время: 0.9505c, MSE: 5.9115e+02
# Experiment 189/216
# Эпохи: 150, Время: 1.3361c, MSE: 8.5461e+04
# Experiment 190/216
# Эпохи: 150, Время: 1.4305c, MSE: 8.5461e+04
# Experiment 191/216
# Эпохи: 150, Время: 1.4820c, MSE: 8.5461e+04
# Experiment 192/216
# Эпохи: 150, Время: 1.6448c, MSE: 8.5461e+04
# Experiment 193/216
# Эпохи: 150, Время: 1.9522c, MSE: 5.8266e+04
# Experiment 194/216
# Эпохи: 150, Время: 1.9630c, MSE: 5.8280e+04
# Experiment 195/216
# Эпохи: 150, Время: 1.9616c, MSE: 5.8286e+04
# Experiment 196/216
# Эпохи: 150, Время: 2.4744c, MSE: 5.8287e+04
# Experiment 197/216
# Эпохи: 150, Время: 2.3531c, MSE: 4.4033e-03
# Experiment 198/216
# Эпохи: 150, Время: 2.1370c, MSE: 5.2473e-03
# Experiment 199/216
# Эпохи: 150, Время: 2.3577c, MSE: 4.8189e-03
# Experiment 200/216
# Эпохи: 150, Время: 2.6220c, MSE: 7.3029e-03
# Experiment 201/216
# Эпохи: 150, Время: 2.0220c, MSE: 7.3254e+04
# Experiment 202/216
# Эпохи: 150, Время: 2.3200c, MSE: 7.8573e+04
# Experiment 203/216
# Эпохи: 150, Время: 2.2705c, MSE: 5.9236e+04
# Experiment 204/216
# Эпохи: 150, Время: 3.0912c, MSE: 6.0729e+04
# Experiment 205/216
# Эпохи: 150, Время: 3.1701c, MSE: 9.2948e-03
# Experiment 206/216
# Эпохи: 150, Время: 3.3685c, MSE: 2.3110e-02
# Experiment 207/216
# Эпохи: 150, Время: 3.5382c, MSE: 1.4830e-04
# Experiment 208/216
# Эпохи: 150, Время: 3.8636c, MSE: 2.0734e-03
# Experiment 209/216
# Эпохи: 150, Время: 1.1817c, MSE: 5.7966e+02
# Experiment 210/216
# Эпохи: 150, Время: 1.2698c, MSE: 5.6488e+02
# Experiment 211/216
# Эпохи: 150, Время: 1.2338c, MSE: 5.6543e+02
# Experiment 212/216
# Эпохи: 150, Время: 1.2797c, MSE: 5.4838e+02
# Experiment 213/216
# Эпохи: 150, Время: 1.7327c, MSE: 8.6739e+04
# Experiment 214/216
# Эпохи: 150, Время: 1.8660c, MSE: 8.6739e+04
# Experiment 215/216
# Эпохи: 150, Время: 2.1028c, MSE: 8.6739e+04
# Experiment 216/216
# Эпохи: 150, Время: 2.5517c, MSE: 8.6739e+04
# Experiments finished. Results saved to csv_results/1D_cylinder_neuman_results.csv
#      bc_left bc_right training_time  epoches    lr activation_func  layers  \
# 0  dirichlet   neuman        1.0926      150  0.01            tanh       1
# 1  dirichlet   neuman        1.2082      150  0.01            tanh       1
# 2  dirichlet   neuman        1.2311      150  0.01            tanh       1
# 3  dirichlet   neuman        1.1883      150  0.01            tanh       1
# 4  dirichlet   neuman        0.9968      150  0.01           Swish       1
#
#    neurons optimizer  collocation_points        mape         mae         mse  \
# 0       32      adam                  12  8.6605e-01  3.6650e+02  1.3446e+05
# 1       32      adam                  22  8.6617e-01  3.6656e+02  1.3450e+05
# 2       32      adam                  52  8.6622e-01  3.6658e+02  1.3451e+05
# 3       32      adam                 102  8.6623e-01  3.6658e+02  1.3451e+05
# 4       32      adam                  12  7.7887e-01  3.2954e+02  1.0866e+05
#
#          rmse   max_error          weights
# 0  3.6668e+02  3.8430e+02  [1.0, 1.0, 1.0]
# 1  3.6674e+02  3.8436e+02  [1.0, 1.0, 1.0]
# 2  3.6676e+02  3.8439e+02  [1.0, 1.0, 1.0]
# 3  3.6676e+02  3.8439e+02  [1.0, 1.0, 1.0]
# 4  3.2963e+02  3.4125e+02  [1.0, 1.0, 1.0]
