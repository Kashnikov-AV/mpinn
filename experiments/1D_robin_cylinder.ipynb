# %%
import jax
import jax.numpy as jnp
import flax.nnx as nnx
import optax
import matplotlib.pyplot as plt
import pandas as pd
import os
from dataclasses import dataclass
from functools import partial

# %%
from geom import Interval
from pinn_core import PINN, FCNet
from pde import cylinder_1d
from bc import dirichlet_bc, robin_bc
from analytic import cylinder_1d_robin_exact

# %%
plt.rcParams.update({
    'font.size': 14,
    'axes.titlesize': 14,
    'axes.labelsize': 14,
    'xtick.labelsize': 14,
    'ytick.labelsize': 14,
    'legend.fontsize': 14,
    'figure.titlesize': 16,
})

# %%
@dataclass(frozen=True)
class PhysicsParams:
    x_left: float = 0.3
    x_right: float = 0.6
    T_left: float = 300.0
    T_inf: float = 500.0
    _lambda: float = 1.0
    h: float = 10.0

    @property
    def alpha_right(self):
        """Коэффициент при T в условии Робина: α = h"""
        return self.h

    @property
    def beta_right(self):
        """Коэффициент при dT/dx в условии Робина: β = λ"""
        return self._lambda

    @property
    def gamma_right(self):
        """Свободный член в условии Робина: γ = h · T_inf"""
        return self.h * self.T_inf

# %%
def get_activation(name):
    mapping = {
        'tanh': nnx.tanh,
        'Swish': nnx.silu,
        'sin': jnp.sin,
        'GELU': nnx.gelu,
        'ReLU': nnx.relu,
        'Sigmoid': nnx.sigmoid,
    }
    return mapping.get(name, nnx.relu)

def get_optimizer(name, lr):
    mapping = {'adam': optax.adam(lr)}
    return mapping.get(name, optax.adam(lr))

# %%
def train_model(
    hidden_features, num_layers, activation_name, lr,
    num_points, opt_name, epochs, weights, save_img=False, show_plot=False
):
    phys = PhysicsParams()
    
    geom = Interval(phys.x_left, phys.x_right)
    x_collocation = geom.generate_collocation(n_interior=num_points, method='random')
    total_points = x_collocation.shape[0]

    act_fn = get_activation(activation_name)
    net = FCNet(din=1, dmid=hidden_features, dout=1, num_layers=num_layers, activation=act_fn, rngs=nnx.Rngs(0))
    
    optimizer = get_optimizer(opt_name, lr=lr)
    pinn = PINN(net, opt=optimizer, weights=weights)

    bc_fns = [
        partial(dirichlet_bc, x=phys.x_left, T=phys.T_left),
        partial(robin_bc, x=phys.x_right, alpha=phys.alpha_right, beta=phys.beta_right, h=phys.gamma_right)
    ]

    history, training_time = pinn.fit(
        x_collocation=x_collocation,
        pde_fn=cylinder_1d,
        bc_fns=bc_fns,
        phys=phys,
        epochs=epochs
    )

    x_test = jnp.linspace(phys.x_left, phys.x_right, 100).reshape(-1, 1)
    metrics, T_pred, T_exact = pinn.evaluate(
        x_test, cylinder_1d_robin_exact, phys, bc_names=['dirichlet', 'robin']
    )

    print(f'Эпохи: {epochs}, Время: {training_time:.4f}c, MSE: {metrics['mse']}')

    if save_img:
        pinn.save_plot(x_test, T_pred, T_exact, phys, save_path=f'images/pinn/1D_cylinder_Robin_{epochs}.png')

    if show_plot:
        pinn.show_plot(x_test, T_pred, T_exact, phys)

    result = {
        'bc_left': metrics['bc_left'],
        'bc_right': metrics['bc_right'],
        'training_time': f'{training_time:.4f}',
        'epoches': epochs,
        'lr': lr,
        'activation_func': activation_name,
        'layers': num_layers,
        'neurons': hidden_features,
        'optimizer': opt_name,
        'collocation_points': total_points,
        'mape': metrics['mape'],
        'mae': metrics['mae'],
        'mse': metrics['mse'],
        'rmse': metrics['rmse'],
        'max_error': metrics['max_error'],
        'weights': f'{weights}',
    }

    return result, history

# %%
def find_optimal_epochs(
    target_mape, max_epochs, step,
    hidden_features, num_layers,
    activation_name, lr,
    num_points, opt_name,
    weights
):
    for epochs in range(step, max_epochs + 1, step):
        metrics, history = train_model(
            hidden_features, num_layers, activation_name, lr,
            num_points, opt_name, epochs, weights, save_img=False
        )
        if float(metrics['mape']) < target_mape:
            return epochs
    return max_epochs

# %%
def try_experiments(eph, lr, csv_path='csv_results/1D_cylinder_robin_results.csv'):
    num_hidden = [32, 64, 128]
    num_layers = [1, 2, 3]
    activation = ['tanh', 'Swish', 'sin', 'GELU', 'ReLU', 'Sigmoid']
    num_interior = [10, 20, 50, 100]
    optimizer = ['adam']
    epochs = [eph]
    weights = [1, 1, 1]
    
    results = []
    exp = 0

    for h in num_hidden:
        for l in num_layers:
            for a in activation:
                for col in num_interior:
                    for opt in optimizer:
                        for epoch in epochs:
                            exp += 1
                            print(f'Experiment {exp}/{len(num_hidden)*len(num_layers)*len(activation)*len(num_interior)}')
                            res, history = train_model(h, l, a, lr, col, opt, epoch, weights)
                            results.append(res)

    df_results = pd.DataFrame(results)
    os.makedirs(os.path.dirname(csv_path), exist_ok=True)
    df_results.to_csv(csv_path, mode='a', header=not os.path.exists(csv_path), index=False)
    print(f'Experiments finished. Results saved to {csv_path}')
    return df_results

# %%
# Оптимальные эпохи
learning_rate = 0.01
weights=[1, 1, 1]

optimal_epochs = find_optimal_epochs(
    target_mape=0.001, max_epochs=3000, step=50,
    hidden_features=64, num_layers=2,
    activation_name='GELU', lr=learning_rate,
    num_points=100, opt_name='adam',
    weights=weights
)
optimal_epochs
# Out:
# Эпохи: 50, Время: 1.3276c, MSE: 7.4632e+02
# Эпохи: 100, Время: 1.3103c, MSE: 7.3670e+01
# Эпохи: 150, Время: 1.1305c, MSE: 1.4340e+02
# Эпохи: 200, Время: 1.4196c, MSE: 1.4059e+02
# Эпохи: 250, Время: 1.2916c, MSE: 1.2820e+02
# Эпохи: 300, Время: 1.3665c, MSE: 1.1618e+02
# Эпохи: 350, Время: 1.5080c, MSE: 1.0454e+02
# Эпохи: 400, Время: 1.7077c, MSE: 9.3430e+01
# Эпохи: 450, Время: 1.6341c, MSE: 8.3001e+01
# Эпохи: 500, Время: 1.9063c, MSE: 6.9689e+01
# Эпохи: 550, Время: 1.8390c, MSE: 6.3222e+01
# Эпохи: 600, Время: 1.6285c, MSE: 5.5439e+01
# Эпохи: 650, Время: 1.7434c, MSE: 4.5365e+01
# Эпохи: 700, Время: 1.8223c, MSE: 4.0778e+01
# Эпохи: 750, Время: 1.9099c, MSE: 3.5169e+01
# Эпохи: 800, Время: 1.8574c, MSE: 3.0034e+01
# Эпохи: 850, Время: 2.0169c, MSE: 2.4534e+01
# Эпохи: 900, Время: 2.4733c, MSE: 2.1132e+01
# Эпохи: 950, Время: 2.4677c, MSE: 1.7461e+01
# Эпохи: 1000, Время: 2.3041c, MSE: 1.4892e+01
# Эпохи: 1050, Время: 2.3282c, MSE: 1.2231e+01
# Эпохи: 1100, Время: 2.5267c, MSE: 8.0884e+00
# Эпохи: 1150, Время: 2.3180c, MSE: 5.0886e+00
# Эпохи: 1200, Время: 2.7358c, MSE: 6.2720e+00
# Эпохи: 1250, Время: 2.8086c, MSE: 4.8749e+00
# Эпохи: 1300, Время: 2.7366c, MSE: 3.8387e+00
# Эпохи: 1350, Время: 3.0495c, MSE: 3.0849e+00
# Эпохи: 1400, Время: 2.9638c, MSE: 2.5124e+00
# Эпохи: 1450, Время: 2.6628c, MSE: 2.0627e+00
# Эпохи: 1500, Время: 2.7431c, MSE: 1.6988e+00
# Эпохи: 1550, Время: 2.7781c, MSE: 2.1532e+01
# Эпохи: 1600, Время: 3.2577c, MSE: 1.7873e+00
# Эпохи: 1650, Время: 3.2692c, MSE: 4.4257e-01
# Эпохи: 1700, Время: 2.8109c, MSE: 1.8964e-01
# Эпохи: 1750, Время: 2.5509c, MSE: 1.0811e-01
# 1750

# %%
metrics, history = train_model(
    hidden_features=64, num_layers=2, 
    activation_name='GELU', lr=learning_rate, 
    num_points=100, opt_name='adam', 
    epochs=optimal_epochs, show_plot=True, save_img=True,
    weights=weights
)
metrics
# Out:
# Эпохи: 1750, Время: 2.4628c, MSE: 1.0811e-01
# {'bc_left': 'dirichlet',
#  'bc_right': 'robin',
#  'training_time': '2.4628',
#  'epoches': 1750,
#  'lr': 0.01,
#  'activation_func': 'GELU',
#  'layers': 2,
#  'neurons': 64,
#  'optimizer': 'adam',
#  'collocation_points': 102,
#  'mape': '8.2738e-04',
#  'mae': '3.0133e-01',
#  'mse': '1.0811e-01',
#  'rmse': '3.2880e-01',
#  'max_error': '5.5676e-01',
#  'weights': '[1, 1, 1]'}

# %%
history.keys()
# Out:
# dict_keys(['steps', 'total_loss', 'pde', 'bc_0', 'bc_1'])

# %%
plt.figure(figsize=(12, 7))
steps = history['steps']

plt.semilogy(steps, history['pde'], 'b', label='PDE Потери', linewidth=2) # PDE
plt.semilogy(steps, history['bc_0'], 'r--', label='ГУ слева', linewidth=2, alpha=0.7) # Boundary Conditions
plt.semilogy(steps, history['bc_1'], 'r--', label='ГУ справа', linewidth=2, alpha=0.7)
plt.semilogy(steps, history['total_loss'], 'g--', label='Общая ошибка', linewidth=2, alpha=0.7)

plt.title('История Обучения')
plt.xlabel('Эпохи')
plt.ylabel('Потери')
plt.legend(loc='upper right')
plt.grid(True, alpha=0.3, which="both")
plt.tight_layout()
plt.savefig('images/history_cylinder_robin', dpi=72, bbox_inches='tight')
plt.show()

# %%
df_results = try_experiments(optimal_epochs, lr=learning_rate)
df_results.head()
# Out:
# Experiment 1/216
# Эпохи: 1750, Время: 0.7755c, MSE: 2.9047e+03
# Experiment 2/216
# Эпохи: 1750, Время: 1.0293c, MSE: 2.9039e+03
# Experiment 3/216
# Эпохи: 1750, Время: 0.7779c, MSE: 2.9035e+03
# Experiment 4/216
# Эпохи: 1750, Время: 1.0374c, MSE: 2.9035e+03
# Experiment 5/216
# Эпохи: 1750, Время: 0.8099c, MSE: 4.3955e+02
# Experiment 6/216
# Эпохи: 1750, Время: 0.7566c, MSE: 5.1109e+02
# Experiment 7/216
# Эпохи: 1750, Время: 0.9243c, MSE: 4.9269e+02
# Experiment 8/216
# Эпохи: 1750, Время: 0.7531c, MSE: 4.7184e+02
# Experiment 9/216
# Эпохи: 1750, Время: 0.7365c, MSE: 1.9669e+03
# Experiment 10/216
# Эпохи: 1750, Время: 0.7919c, MSE: 1.9739e+03
# Experiment 11/216
# Эпохи: 1750, Время: 0.6231c, MSE: 2.0110e+03
# Experiment 12/216
# Эпохи: 1750, Время: 0.7268c, MSE: 2.0186e+03
# Experiment 13/216
# Эпохи: 1750, Время: 1.1022c, MSE: 3.8151e+02
# Experiment 14/216
# Эпохи: 1750, Время: 0.8539c, MSE: 3.0218e+02
# Experiment 15/216
# Эпохи: 1750, Время: 1.4360c, MSE: 2.7964e+02
# Experiment 16/216
# Эпохи: 1750, Время: 1.3403c, MSE: 2.6767e+02
# Experiment 17/216
# Эпохи: 1750, Время: 0.7005c, MSE: 6.0975e+03
# Experiment 18/216
# Эпохи: 1750, Время: 0.5179c, MSE: 5.5580e+03
# Experiment 19/216
# Эпохи: 1750, Время: 0.6315c, MSE: 5.2679e+03
# Experiment 20/216
# Эпохи: 1750, Время: 0.7197c, MSE: 5.2393e+03
# Experiment 21/216
# Эпохи: 1750, Время: 0.7315c, MSE: 3.3343e+03
# Experiment 22/216
# Эпохи: 1750, Время: 0.7472c, MSE: 3.3343e+03
# Experiment 23/216
# Эпохи: 1750, Время: 0.8630c, MSE: 3.3343e+03
# Experiment 24/216
# Эпохи: 1750, Время: 0.6918c, MSE: 3.3343e+03
# Experiment 25/216
# Эпохи: 1750, Время: 1.2531c, MSE: 2.6048e+03
# Experiment 26/216
# Эпохи: 1750, Время: 1.2100c, MSE: 2.6047e+03
# Experiment 27/216
# Эпохи: 1750, Время: 1.5484c, MSE: 2.6047e+03
# Experiment 28/216
# Эпохи: 1750, Время: 1.3276c, MSE: 2.6047e+03
# Experiment 29/216
# Эпохи: 1750, Время: 1.6640c, MSE: 3.5998e-02
# Experiment 30/216
# Эпохи: 1750, Время: 1.1414c, MSE: 3.7450e-02
# Experiment 31/216
# Эпохи: 1750, Время: 1.3899c, MSE: 3.6303e-02
# Experiment 32/216
# Эпохи: 1750, Время: 1.4083c, MSE: 3.7240e-02
# Experiment 33/216
# Эпохи: 1750, Время: 1.2237c, MSE: 1.0920e+05
# Experiment 34/216
# Эпохи: 1750, Время: 1.1813c, MSE: 7.8815e+04
# Experiment 35/216
# Эпохи: 1750, Время: 1.5359c, MSE: 1.0055e+05
# Experiment 36/216
# Эпохи: 1750, Время: 1.9015c, MSE: 6.5990e+04
# Experiment 37/216
# Эпохи: 1750, Время: 1.5330c, MSE: 4.0455e-02
# Experiment 38/216
# Эпохи: 1750, Время: 1.8249c, MSE: 1.0560e-01
# Experiment 39/216
# Эпохи: 1750, Время: 1.6016c, MSE: 9.2849e-02
# Experiment 40/216
# Эпохи: 1750, Время: 1.9429c, MSE: 6.6813e-02
# Experiment 41/216
# Эпохи: 1750, Время: 0.8237c, MSE: 1.3162e+04
# Experiment 42/216
# Эпохи: 1750, Время: 1.1017c, MSE: 1.3088e+04
# Experiment 43/216
# Эпохи: 1750, Время: 0.9091c, MSE: 1.3042e+04
# Experiment 44/216
# Эпохи: 1750, Время: 1.1095c, MSE: 1.3037e+04
# Experiment 45/216
# Эпохи: 1750, Время: 1.2084c, MSE: 2.5811e+03
# Experiment 46/216
# Эпохи: 1750, Время: 0.8633c, MSE: 2.5811e+03
# Experiment 47/216
# Эпохи: 1750, Время: 1.2812c, MSE: 2.5811e+03
# Experiment 48/216
# Эпохи: 1750, Время: 1.1191c, MSE: 2.5811e+03
# Experiment 49/216
# Эпохи: 1750, Время: 1.5331c, MSE: 2.6170e+03
# Experiment 50/216
# Эпохи: 1750, Время: 1.5547c, MSE: 2.6170e+03
# Experiment 51/216
# Эпохи: 1750, Время: 1.7695c, MSE: 2.6170e+03
# Experiment 52/216
# Эпохи: 1750, Время: 1.8915c, MSE: 2.6170e+03
# Experiment 53/216
# Эпохи: 1750, Время: 1.7594c, MSE: 2.8962e-02
# Experiment 54/216
# Эпохи: 1750, Время: 1.5677c, MSE: 3.8529e-02
# Experiment 55/216
# Эпохи: 1750, Время: 1.7584c, MSE: 1.3808e-02
# Experiment 56/216
# Эпохи: 1750, Время: 1.8748c, MSE: 1.1847e-02
# Experiment 57/216
# Эпохи: 1750, Время: 1.7190c, MSE: 1.8797e+05
# Experiment 58/216
# Эпохи: 1750, Время: 1.9748c, MSE: 7.3192e+04
# Experiment 59/216
# Эпохи: 1750, Время: 2.2477c, MSE: 2.1800e+04
# Experiment 60/216
# Эпохи: 1750, Время: 3.5177c, MSE: 1.0077e+05
# Experiment 61/216
# Эпохи: 1750, Время: 2.2768c, MSE: 1.8173e+00
# Experiment 62/216
# Эпохи: 1750, Время: 2.5596c, MSE: 3.6281e-01
# Experiment 63/216
# Эпохи: 1750, Время: 2.5081c, MSE: 9.8823e-02
# Experiment 64/216
# Эпохи: 1750, Время: 3.0769c, MSE: 2.5054e+01
# Experiment 65/216
# Эпохи: 1750, Время: 1.2858c, MSE: 1.3162e+04
# Experiment 66/216
# Эпохи: 1750, Время: 1.1355c, MSE: 1.3088e+04
# Experiment 67/216
# Эпохи: 1750, Время: 1.4081c, MSE: 1.3042e+04
# Experiment 68/216
# Эпохи: 1750, Время: 1.5221c, MSE: 1.3037e+04
# Experiment 69/216
# Эпохи: 1750, Время: 1.1337c, MSE: 2.1821e+03
# Experiment 70/216
# Эпохи: 1750, Время: 1.1740c, MSE: 2.1821e+03
# Experiment 71/216
# Эпохи: 1750, Время: 1.3381c, MSE: 2.1821e+03
# Experiment 72/216
# Эпохи: 1750, Время: 1.5671c, MSE: 2.1821e+03
# Experiment 73/216
# Эпохи: 1750, Время: 0.7034c, MSE: 1.3113e+04
# Experiment 74/216
# Эпохи: 1750, Время: 0.6370c, MSE: 1.3107e+04
# Experiment 75/216
# Эпохи: 1750, Время: 0.8778c, MSE: 1.3103e+04
# Experiment 76/216
# Эпохи: 1750, Время: 0.7217c, MSE: 1.3103e+04
# Experiment 77/216
# Эпохи: 1750, Время: 0.7699c, MSE: 3.6850e+02
# Experiment 78/216
# Эпохи: 1750, Время: 0.7258c, MSE: 4.1570e+02
# Experiment 79/216
# Эпохи: 1750, Время: 0.6944c, MSE: 3.9713e+02
# Experiment 80/216
# Эпохи: 1750, Время: 0.7094c, MSE: 3.7491e+02
# Experiment 81/216
# Эпохи: 1750, Время: 0.6937c, MSE: 1.1569e+04
# Experiment 82/216
# Эпохи: 1750, Время: 0.6237c, MSE: 1.1274e+04
# Experiment 83/216
# Эпохи: 1750, Время: 0.7137c, MSE: 1.1151e+04
# Experiment 84/216
# Эпохи: 1750, Время: 0.9202c, MSE: 1.1150e+04
# Experiment 85/216
# Эпохи: 1750, Время: 0.7803c, MSE: 2.0209e+02
# Experiment 86/216
# Эпохи: 1750, Время: 0.9270c, MSE: 2.5938e+02
# Experiment 87/216
# Эпохи: 1750, Время: 1.0586c, MSE: 2.4955e+02
# Experiment 88/216
# Эпохи: 1750, Время: 0.9770c, MSE: 2.4100e+02
# Experiment 89/216
# Эпохи: 1750, Время: 0.6000c, MSE: 1.0112e+04
# Experiment 90/216
# Эпохи: 1750, Время: 0.6211c, MSE: 9.3884e+03
# Experiment 91/216
# Эпохи: 1750, Время: 0.5416c, MSE: 8.9616e+03
# Experiment 92/216
# Эпохи: 1750, Время: 0.5290c, MSE: 8.9181e+03
# Experiment 93/216
# Эпохи: 1750, Время: 0.7058c, MSE: 1.3058e+04
# Experiment 94/216
# Эпохи: 1750, Время: 0.6652c, MSE: 1.3059e+04
# Experiment 95/216
# Эпохи: 1750, Время: 0.6697c, MSE: 1.3060e+04
# Experiment 96/216
# Эпохи: 1750, Время: 0.6535c, MSE: 1.3060e+04
# Experiment 97/216
# Эпохи: 1750, Время: 1.0512c, MSE: 1.3012e+04
# Experiment 98/216
# Эпохи: 1750, Время: 1.0628c, MSE: 1.3012e+04
# Experiment 99/216
# Эпохи: 1750, Время: 1.1637c, MSE: 1.3011e+04
# Experiment 100/216
# Эпохи: 1750, Время: 1.4403c, MSE: 1.3011e+04
# Experiment 101/216
# Эпохи: 1750, Время: 1.0690c, MSE: 2.9895e-01
# Experiment 102/216
# Эпохи: 1750, Время: 1.1762c, MSE: 1.7545e-01
# Experiment 103/216
# Эпохи: 1750, Время: 1.1531c, MSE: 4.0826e-01
# Experiment 104/216
# Эпохи: 1750, Время: 1.7303c, MSE: 3.8526e-01
# Experiment 105/216
# Эпохи: 1750, Время: 1.3298c, MSE: 5.3816e+03
# Experiment 106/216
# Эпохи: 1750, Время: 1.5022c, MSE: 2.7293e+04
# Experiment 107/216
# Эпохи: 1750, Время: 1.8643c, MSE: 2.4429e+04
# Experiment 108/216
# Эпохи: 1750, Время: 2.9300c, MSE: 1.9043e+04
# Experiment 109/216
# Эпохи: 1750, Время: 1.3245c, MSE: 2.8820e+00
# Experiment 110/216
# Эпохи: 1750, Время: 1.4942c, MSE: 9.3524e-05
# Experiment 111/216
# Эпохи: 1750, Время: 1.6365c, MSE: 1.0462e-01
# Experiment 112/216
# Эпохи: 1750, Время: 2.1218c, MSE: 1.0811e-01
# Experiment 113/216
# Эпохи: 1750, Время: 0.6869c, MSE: 1.3162e+04
# Experiment 114/216
# Эпохи: 1750, Время: 0.7037c, MSE: 1.3088e+04
# Experiment 115/216
# Эпохи: 1750, Время: 0.6549c, MSE: 1.3042e+04
# Experiment 116/216
# Эпохи: 1750, Время: 0.6693c, MSE: 1.3037e+04
# Experiment 117/216
# Эпохи: 1750, Время: 0.8345c, MSE: 1.3017e+04
# Experiment 118/216
# Эпохи: 1750, Время: 0.8586c, MSE: 1.3017e+04
# Experiment 119/216
# Эпохи: 1750, Время: 0.9520c, MSE: 1.3017e+04
# Experiment 120/216
# Эпохи: 1750, Время: 1.2854c, MSE: 1.3017e+04
# Experiment 121/216
# Эпохи: 1750, Время: 1.2013c, MSE: 1.3025e+04
# Experiment 122/216
# Эпохи: 1750, Время: 1.3494c, MSE: 1.3025e+04
# Experiment 123/216
# Эпохи: 1750, Время: 1.4978c, MSE: 1.3025e+04
# Experiment 124/216
# Эпохи: 1750, Время: 2.0850c, MSE: 1.3025e+04
# Experiment 125/216
# Эпохи: 1750, Время: 1.3937c, MSE: 1.1435e-02
# Experiment 126/216
# Эпохи: 1750, Время: 1.6454c, MSE: 5.8602e-05
# Experiment 127/216
# Эпохи: 1750, Время: 1.8020c, MSE: 2.5690e-02
# Experiment 128/216
# Эпохи: 1750, Время: 3.3701c, MSE: 2.5917e-02
# Experiment 129/216
# Эпохи: 1750, Время: 1.8533c, MSE: 4.7059e+03
# Experiment 130/216
# Эпохи: 1750, Время: 2.3670c, MSE: 9.2631e+03
# Experiment 131/216
# Эпохи: 1750, Время: 3.1494c, MSE: 1.5173e+04
# Experiment 132/216
# Эпохи: 1750, Время: 4.9764c, MSE: 6.6405e+03
# Experiment 133/216
# Эпохи: 1750, Время: 2.4272c, MSE: 5.0570e-01
# Experiment 134/216
# Эпохи: 1750, Время: 2.4732c, MSE: 1.4970e-03
# Experiment 135/216
# Эпохи: 1750, Время: 2.9384c, MSE: 8.5196e-03
# Experiment 136/216
# Эпохи: 1750, Время: 4.5397c, MSE: 5.0166e-03
# Experiment 137/216
# Эпохи: 1750, Время: 1.0745c, MSE: 1.3162e+04
# Experiment 138/216
# Эпохи: 1750, Время: 1.0873c, MSE: 1.3088e+04
# Experiment 139/216
# Эпохи: 1750, Время: 1.2967c, MSE: 1.3042e+04
# Experiment 140/216
# Эпохи: 1750, Время: 1.1014c, MSE: 1.3037e+04
# Experiment 141/216
# Эпохи: 1750, Время: 1.4242c, MSE: 1.1651e+04
# Experiment 142/216
# Эпохи: 1750, Время: 1.6334c, MSE: 1.1651e+04
# Experiment 143/216
# Эпохи: 1750, Время: 1.7422c, MSE: 1.1651e+04
# Experiment 144/216
# Эпохи: 1750, Время: 2.5596c, MSE: 1.1651e+04
# Experiment 145/216
# Эпохи: 1750, Время: 0.8875c, MSE: 1.3184e+04
# Experiment 146/216
# Эпохи: 1750, Время: 0.7033c, MSE: 1.3191e+04
# Experiment 147/216
# Эпохи: 1750, Время: 0.7890c, MSE: 1.3190e+04
# Experiment 148/216
# Эпохи: 1750, Время: 0.9959c, MSE: 1.3190e+04
# Experiment 149/216
# Эпохи: 1750, Время: 0.9258c, MSE: 3.8378e+02
# Experiment 150/216
# Эпохи: 1750, Время: 0.9461c, MSE: 3.6113e+02
# Experiment 151/216
# Эпохи: 1750, Время: 0.7312c, MSE: 3.2862e+02
# Experiment 152/216
# Эпохи: 1750, Время: 1.0972c, MSE: 3.0315e+02
# Experiment 153/216
# Эпохи: 1750, Время: 0.6858c, MSE: 1.2003e+04
# Experiment 154/216
# Эпохи: 1750, Время: 0.8760c, MSE: 1.1501e+04
# Experiment 155/216
# Эпохи: 1750, Время: 1.1463c, MSE: 1.1194e+04
# Experiment 156/216
# Эпохи: 1750, Время: 1.4511c, MSE: 1.1173e+04
# Experiment 157/216
# Эпохи: 1750, Время: 1.0403c, MSE: 6.8361e+01
# Experiment 158/216
# Эпохи: 1750, Время: 1.0966c, MSE: 1.1129e+02
# Experiment 159/216
# Эпохи: 1750, Время: 1.2085c, MSE: 1.0740e+02
# Experiment 160/216
# Эпохи: 1750, Время: 1.2009c, MSE: 1.0056e+02
# Experiment 161/216
# Эпохи: 1750, Время: 0.7447c, MSE: 1.2602e+04
# Experiment 162/216
# Эпохи: 1750, Время: 0.6253c, MSE: 1.2223e+04
# Experiment 163/216
# Эпохи: 1750, Время: 0.5016c, MSE: 1.1958e+04
# Experiment 164/216
# Эпохи: 1750, Время: 0.7565c, MSE: 1.1929e+04
# Experiment 165/216
# Эпохи: 1750, Время: 0.8259c, MSE: 1.2517e+04
# Experiment 166/216
# Эпохи: 1750, Время: 0.6273c, MSE: 1.2520e+04
# Experiment 167/216
# Эпохи: 1750, Время: 0.7500c, MSE: 1.2523e+04
# Experiment 168/216
# Эпохи: 1750, Время: 0.8100c, MSE: 1.2522e+04
# Experiment 169/216
# Эпохи: 1750, Время: 1.4109c, MSE: 1.3879e+04
# Experiment 170/216
# Эпохи: 1750, Время: 2.0052c, MSE: 1.3879e+04
# Experiment 171/216
# Эпохи: 1750, Время: 2.1812c, MSE: 1.3879e+04
# Experiment 172/216
# Эпохи: 1750, Время: 3.6636c, MSE: 1.3879e+04
# Experiment 173/216
# Эпохи: 1750, Время: 1.7592c, MSE: 1.3862e-01
# Experiment 174/216
# Эпохи: 1750, Время: 2.0709c, MSE: 1.9286e+01
# Experiment 175/216
# Эпохи: 1750, Время: 2.6738c, MSE: 3.0845e+00
# Experiment 176/216
# Эпохи: 1750, Время: 4.3899c, MSE: 3.9898e-01
# Experiment 177/216
# Эпохи: 1750, Время: 2.4479c, MSE: 1.8855e+01
# Experiment 178/216
# Эпохи: 1750, Время: 3.2021c, MSE: 1.6827e+01
# Experiment 179/216
# Эпохи: 1750, Время: 4.4289c, MSE: 9.0690e+00
# Experiment 180/216
# Эпохи: 1750, Время: 6.4326c, MSE: 1.2154e+01
# Experiment 181/216
# Эпохи: 1750, Время: 2.1778c, MSE: 4.0635e-02
# Experiment 182/216
# Эпохи: 1750, Время: 2.5444c, MSE: 2.1237e-03
# Experiment 183/216
# Эпохи: 1750, Время: 3.0153c, MSE: 3.7062e-04
# Experiment 184/216
# Эпохи: 1750, Время: 4.9373c, MSE: 2.6051e-01
# Experiment 185/216
# Эпохи: 1750, Время: 0.9510c, MSE: 1.3162e+04
# Experiment 186/216
# Эпохи: 1750, Время: 0.7216c, MSE: 1.3088e+04
# Experiment 187/216
# Эпохи: 1750, Время: 1.0652c, MSE: 1.3042e+04
# Experiment 188/216
# Эпохи: 1750, Время: 1.1792c, MSE: 1.3037e+04
# Experiment 189/216
# Эпохи: 1750, Время: 1.4090c, MSE: 1.3879e+04
# Experiment 190/216
# Эпохи: 1750, Время: 1.7194c, MSE: 1.3879e+04
# Experiment 191/216
# Эпохи: 1750, Время: 2.0523c, MSE: 1.3879e+04
# Experiment 192/216
# Эпохи: 1750, Время: 3.6205c, MSE: 1.3879e+04
# Experiment 193/216
# Эпохи: 1750, Время: 2.3821c, MSE: 1.3880e+04
# Experiment 194/216
# Эпохи: 1750, Время: 3.1697c, MSE: 1.3880e+04
# Experiment 195/216
# Эпохи: 1750, Время: 3.9514c, MSE: 1.3880e+04
# Experiment 196/216
# Эпохи: 1750, Время: 7.4476c, MSE: 1.3880e+04
# Experiment 197/216
# Эпохи: 1750, Время: 2.7118c, MSE: 2.7701e-02
# Experiment 198/216
# Эпохи: 1750, Время: 3.5806c, MSE: 1.6741e-01
# Experiment 199/216
# Эпохи: 1750, Время: 5.2229c, MSE: 1.2840e-03
# Experiment 200/216
# Эпохи: 1750, Время: 7.9327c, MSE: 1.5050e-02
# Experiment 201/216
# Эпохи: 1750, Время: 3.9665c, MSE: 2.2099e+00
# Experiment 202/216
# Эпохи: 1750, Время: 5.0770c, MSE: 4.8685e+00
# Experiment 203/216
# Эпохи: 1750, Время: 7.0224c, MSE: 8.0608e+00
# Experiment 204/216
# Эпохи: 1750, Время: 12.3035c, MSE: 5.4057e+01
# Experiment 205/216
# Эпохи: 1750, Время: 3.8279c, MSE: 4.0845e-03
# Experiment 206/216
# Эпохи: 1750, Время: 4.2385c, MSE: 5.6223e-03
# Experiment 207/216
# Эпохи: 1750, Время: 5.6254c, MSE: 6.7332e-03
# Experiment 208/216
# Эпохи: 1750, Время: 7.0617c, MSE: 4.2027e-03
# Experiment 209/216
# Эпохи: 1750, Время: 0.8840c, MSE: 1.3162e+04
# Experiment 210/216
# Эпохи: 1750, Время: 0.9443c, MSE: 1.3088e+04
# Experiment 211/216
# Эпохи: 1750, Время: 1.2129c, MSE: 1.3042e+04
# Experiment 212/216
# Эпохи: 1750, Время: 1.7496c, MSE: 1.3037e+04
# Experiment 213/216
# Эпохи: 1750, Время: 1.8272c, MSE: 1.3860e+04
# Experiment 214/216
# Эпохи: 1750, Время: 2.3084c, MSE: 1.3860e+04
# Experiment 215/216
# Эпохи: 1750, Время: 3.4735c, MSE: 1.3860e+04
# Experiment 216/216
# Эпохи: 1750, Время: 7.8106c, MSE: 1.3860e+04
# Experiments finished. Results saved to csv_results/1D_cylinder_robin_results.csv
#      bc_left bc_right training_time  epoches    lr activation_func  layers  \
# 0  dirichlet    robin        0.7755     1750  0.01            tanh       1
# 1  dirichlet    robin        1.0293     1750  0.01            tanh       1
# 2  dirichlet    robin        0.7779     1750  0.01            tanh       1
# 3  dirichlet    robin        1.0374     1750  0.01            tanh       1
# 4  dirichlet    robin        0.8099     1750  0.01           Swish       1
#
#    neurons optimizer  collocation_points        mape         mae         mse  \
# 0       32      adam                  12  1.2199e-01  4.3313e+01  2.9047e+03
# 1       32      adam                  22  1.2198e-01  4.3309e+01  2.9039e+03
# 2       32      adam                  52  1.2197e-01  4.3306e+01  2.9035e+03
# 3       32      adam                 102  1.2197e-01  4.3305e+01  2.9035e+03
# 4       32      adam                  12  5.2577e-02  1.9114e+01  4.3955e+02
#
#          rmse   max_error          weights
# 0  5.3895e+01  1.1693e+02  [1.0, 1.0, 1.0]
# 1  5.3888e+01  1.1692e+02  [1.0, 1.0, 1.0]
# 2  5.3884e+01  1.1691e+02  [1.0, 1.0, 1.0]
# 3  5.3884e+01  1.1691e+02  [1.0, 1.0, 1.0]
# 4  2.0965e+01  3.6275e+01  [1.0, 1.0, 1.0]
