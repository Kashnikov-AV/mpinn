# %%
import jax
import jax.numpy as jnp
import flax.nnx as nnx
import optax
import matplotlib.pyplot as plt
import pandas as pd
import os
from dataclasses import dataclass
from functools import partial

# %%
from geom import Interval
from pinn_core import PINN, FCNet
from pde import sphere_1d
from bc import dirichlet_bc
from analytic import sphere_1d_dirichlet_exact

# %%
plt.rcParams.update({
    'font.size': 14,
    'axes.titlesize': 14,
    'axes.labelsize': 14,
    'xtick.labelsize': 14,
    'ytick.labelsize': 14,
    'legend.fontsize': 14,
    'figure.titlesize': 16,
})

# %%
@dataclass(frozen=True)
class PhysicsParams:
    L: float = 1.0
    x_left: float = 0.3
    x_right: float = 0.6
    T_left: float = 300.0
    T_right: float = 500.0

# %%
def get_activation(name):
    mapping = {
        'tanh': nnx.tanh,
        'Swish': nnx.silu,
        'sin': jnp.sin,
        'GELU': nnx.gelu,
        'ReLU': nnx.relu,
        'Sigmoid': nnx.sigmoid,
    }
    return mapping.get(name, nnx.relu)

def get_optimizer(name, lr):
    mapping = {'adam': optax.adam(lr)}
    return mapping.get(name, optax.adam(lr))

# %%
def train_model(
    hidden_features, num_layers, activation_name, lr,
    num_points, opt_name, epochs, weights, save_img=False, show_plot=False
):
    phys = PhysicsParams()
    
    geom = Interval(phys.x_left, phys.x_right)
    x_collocation = geom.generate_collocation(n_interior=num_points, method='random')
    total_points = x_collocation.shape[0]

    act_fn = get_activation(activation_name)
    net = FCNet(din=1, dmid=hidden_features, dout=1, num_layers=num_layers, activation=act_fn, rngs=nnx.Rngs(0))
    
    optimizer = get_optimizer(opt_name, lr=lr)
    pinn = PINN(net, opt=optimizer, weights=weights)

    bc_fns = [
        partial(dirichlet_bc, x=phys.x_left, T=phys.T_left),
        partial(dirichlet_bc, x=phys.x_right, T=phys.T_right)
    ]

    history, training_time = pinn.fit(
        x_collocation=x_collocation,
        pde_fn=sphere_1d,
        bc_fns=bc_fns,
        phys=phys,
        epochs=epochs
    )

    x_test = jnp.linspace(phys.x_left, phys.x_right, 100).reshape(-1, 1)
    metrics, T_pred, T_exact = pinn.evaluate(
        x_test, sphere_1d_dirichlet_exact, phys, bc_names=['dirichlet', 'dirichlet']
    )

    print(f'Эпохи: {epochs}, Время: {training_time:.4f}c, MSE: {metrics['mse']}')

    if save_img:
        pinn.save_plot(x_test, T_pred, T_exact, phys, save_path=f'images/pinn/1D_sphere_Dirichlet_{epochs}.png')

    if show_plot:
        pinn.show_plot(x_test, T_pred, T_exact, phys)

    result = {
        'bc_left': metrics['bc_left'],
        'bc_right': metrics['bc_right'],
        'training_time': f'{training_time:.4f}',
        'epoches': epochs,
        'lr': lr,
        'activation_func': activation_name,
        'layers': num_layers,
        'neurons': hidden_features,
        'optimizer': opt_name,
        'collocation_points': total_points,
        'mape': metrics['mape'],
        'mae': metrics['mae'],
        'mse': metrics['mse'],
        'rmse': metrics['rmse'],
        'max_error': metrics['max_error'],
        'weights': f'{weights}',
    }

    return result, history

# %%
def find_optimal_epochs(
    target_mape, max_epochs, step,
    hidden_features, num_layers,
    activation_name, lr,
    num_points, opt_name,
    weights
):
    for epochs in range(step, max_epochs + 1, step):
        metrics, history = train_model(
            hidden_features, num_layers, activation_name, lr,
            num_points, opt_name, epochs, weights, save_img=False
        )
        if float(metrics['mape']) < target_mape:
            return epochs
    return max_epochs

# %%
def try_experiments(eph, lr, csv_path='csv_results/1D_sphere_dirichlet_results.csv'):
    num_hidden = [32, 64, 128]
    num_layers = [1, 2, 3]
    activation = ['tanh', 'Swish', 'sin', 'GELU', 'ReLU', 'Sigmoid']
    num_col = [10, 20, 50, 100]
    optimizer = ['adam']
    epochs = [eph // 2, eph*4, eph*8]
    weights = [1, 5, 5]
    
    results = []
    exp = 0

    for h in num_hidden:
        for l in num_layers:
            for a in activation:
                for col in num_col:
                    for opt in optimizer:
                        for epoch in epochs:
                            exp += 1
                            print(f'Experiment {exp}/{len(num_hidden)*len(num_layers)*len(activation)*len(num_col)}')
                            res, history = train_model(h, l, a, lr, col, opt, epoch, weights)
                            results.append(res)

    df_results = pd.DataFrame(results)
    os.makedirs(os.path.dirname(csv_path), exist_ok=True)
    df_results.to_csv(csv_path, mode='a', header=not os.path.exists(csv_path), index=False)
    print(f'Experiments finished. Results saved to {csv_path}')
    return df_results

# %%
# Оптимальные эпохи
learning_rate = 0.01
weights=[1., 2., 2.]

optimal_epochs = find_optimal_epochs(
    target_mape=0.001, max_epochs=3000, step=50,
    hidden_features=64, num_layers=2,
    activation_name='GELU', lr=learning_rate,
    num_points=100, opt_name='adam',
    weights=weights
)
optimal_epochs
# Out:
# Эпохи: 50, Время: 0.9776c, MSE: 5.4643e+04
# Эпохи: 100, Время: 0.9017c, MSE: 1.8612e+03
# Эпохи: 150, Время: 0.9305c, MSE: 1.5355e+03
# Эпохи: 200, Время: 0.9649c, MSE: 1.0229e+03
# Эпохи: 250, Время: 1.0123c, MSE: 6.6465e+02
# Эпохи: 300, Время: 1.0256c, MSE: 5.0581e+02
# Эпохи: 350, Время: 1.1217c, MSE: 3.0879e+02
# Эпохи: 400, Время: 1.0925c, MSE: 2.0539e+02
# Эпохи: 450, Время: 1.1115c, MSE: 1.5585e+02
# Эпохи: 500, Время: 1.2312c, MSE: 1.0290e+02
# Эпохи: 550, Время: 1.1887c, MSE: 5.2180e+01
# Эпохи: 600, Время: 1.2257c, MSE: 1.2528e+02
# Эпохи: 650, Время: 1.2651c, MSE: 2.4211e+01
# Эпохи: 700, Время: 1.2929c, MSE: 1.2857e+01
# Эпохи: 750, Время: 1.3325c, MSE: 1.1362e+01
# Эпохи: 800, Время: 1.3635c, MSE: 5.4939e+00
# Эпохи: 850, Время: 1.3956c, MSE: 2.6544e+00
# Эпохи: 900, Время: 1.4336c, MSE: 6.8024e+00
# Эпохи: 950, Время: 1.4413c, MSE: 4.2951e+00
# Эпохи: 1000, Время: 1.4790c, MSE: 2.0701e+00
# Эпохи: 1050, Время: 1.5219c, MSE: 1.3319e+00
# Эпохи: 1100, Время: 1.5318c, MSE: 1.3700e+00
# Эпохи: 1150, Время: 1.6478c, MSE: 2.5107e+00
# Эпохи: 1200, Время: 1.7138c, MSE: 3.2411e-01
# Эпохи: 1250, Время: 1.7546c, MSE: 2.0577e+00
# Эпохи: 1300, Время: 1.6571c, MSE: 4.0382e-01
# Эпохи: 1350, Время: 1.6735c, MSE: 3.9315e-01
# Эпохи: 1400, Время: 1.7927c, MSE: 4.6400e-01
# Эпохи: 1450, Время: 1.8143c, MSE: 5.6864e+00
# Эпохи: 1500, Время: 1.8641c, MSE: 8.9262e-01
# Эпохи: 1550, Время: 1.9056c, MSE: 4.0355e-01
# Эпохи: 1600, Время: 1.9436c, MSE: 6.5015e+00
# Эпохи: 1650, Время: 1.9780c, MSE: 8.9601e-01
# Эпохи: 1700, Время: 1.9998c, MSE: 3.2524e-01
# Эпохи: 1750, Время: 2.0362c, MSE: 1.7273e+00
# Эпохи: 1800, Время: 2.0835c, MSE: 9.6833e-02
# 1800

# %%
metrics, history = train_model(
    hidden_features=64, num_layers=2, 
    activation_name='GELU', lr=learning_rate, 
    num_points=100, opt_name='adam', 
    epochs=optimal_epochs, show_plot=True,save_img=True,
    weights=weights
)
metrics
# Out:
# Эпохи: 1800, Время: 2.0593c, MSE: 9.6833e-02
# {'bc_left': 'dirichlet',
#  'bc_right': 'dirichlet',
#  'training_time': '2.0593',
#  'epoches': 1800,
#  'lr': 0.01,
#  'activation_func': 'GELU',
#  'layers': 2,
#  'neurons': 64,
#  'optimizer': 'adam',
#  'collocation_points': 102,
#  'mape': '6.5657e-04',
#  'mae': '2.7223e-01',
#  'mse': '9.6833e-02',
#  'rmse': '3.1118e-01',
#  'max_error': '5.6021e-01',
#  'weights': '[1.0, 2.0, 2.0]'}

# %%
history.keys()
# Out:
# dict_keys(['steps', 'total_loss', 'pde', 'bc_0', 'bc_1'])

# %%
plt.figure(figsize=(12, 7))
steps = history['steps']

plt.semilogy(steps, history['pde'], 'b', label='PDE Потери', linewidth=2) # PDE
plt.semilogy(steps, history['bc_0'], 'r--', label='ГУ слева', linewidth=2, alpha=0.7) # Boundary Conditions
plt.semilogy(steps, history['bc_1'], 'r--', label='ГУ справа', linewidth=2, alpha=0.7)
plt.semilogy(steps, history['total_loss'], 'g--', label='Общая ошибка', linewidth=2, alpha=0.7)

plt.title('История Обучения')
plt.xlabel('Эпохи')
plt.ylabel('Потери')
plt.legend(loc='upper right')
plt.grid(True, alpha=0.3, which="both")
plt.tight_layout()
plt.savefig('history_sphere_dirichlet', dpi=72, bbox_inches='tight')
plt.show()

# %%
df_results = try_experiments(optimal_epochs, lr=learning_rate)
df_results.head()
# Out:
# Experiment 1/216
# Эпохи: 900, Время: 0.5358c, MSE: 2.9506e+04
# Experiment 2/216
# Эпохи: 7200, Время: 1.2652c, MSE: 1.4023e-01
# Experiment 3/216
# Эпохи: 14400, Время: 2.1670c, MSE: 4.2376e-02
# Experiment 4/216
# Эпохи: 900, Время: 0.6105c, MSE: 2.9550e+04
# Experiment 5/216
# Эпохи: 7200, Время: 1.3321c, MSE: 5.6243e-03
# Experiment 6/216
# Эпохи: 14400, Время: 2.2112c, MSE: 3.1157e-03
# Experiment 7/216
# Эпохи: 900, Время: 0.6249c, MSE: 2.9571e+04
# Experiment 8/216
# Эпохи: 7200, Время: 1.3869c, MSE: 1.5260e-03
# Experiment 9/216
# Эпохи: 14400, Время: 2.3507c, MSE: 7.4663e-05
# Experiment 10/216
# Эпохи: 900, Время: 0.7131c, MSE: 2.9573e+04
# Experiment 11/216
# Эпохи: 7200, Время: 1.4143c, MSE: 2.9185e-03
# Experiment 12/216
# Эпохи: 14400, Время: 2.3994c, MSE: 1.9820e-06
# Experiment 13/216
# Эпохи: 900, Время: 0.5360c, MSE: 2.4271e+03
# Experiment 14/216
# Эпохи: 7200, Время: 1.2771c, MSE: 2.5439e-01
# Experiment 15/216
# Эпохи: 14400, Время: 2.1884c, MSE: 1.3156e-01
# Experiment 16/216
# Эпохи: 900, Время: 0.5024c, MSE: 2.3097e+03
# Experiment 17/216
# Эпохи: 7200, Время: 1.2523c, MSE: 4.9626e-03
# Experiment 18/216
# Эпохи: 14400, Время: 2.1663c, MSE: 4.0792e-03
# Experiment 19/216
# Эпохи: 900, Время: 0.5227c, MSE: 2.3271e+03
# Experiment 20/216
# Эпохи: 7200, Время: 1.2930c, MSE: 3.6960e-03
# Experiment 21/216
# Эпохи: 14400, Время: 2.2343c, MSE: 1.2032e-03
# Experiment 22/216
# Эпохи: 900, Время: 0.5317c, MSE: 2.2803e+03
# Experiment 23/216
# Эпохи: 7200, Время: 1.3978c, MSE: 9.6860e-03
# Experiment 24/216
# Эпохи: 14400, Время: 2.4347c, MSE: 2.2288e-04
# Experiment 25/216
# Эпохи: 900, Время: 0.4628c, MSE: 3.0148e+04
# Experiment 26/216
# Эпохи: 7200, Время: 1.2663c, MSE: 2.2154e+03
# Experiment 27/216
# Эпохи: 14400, Время: 2.1445c, MSE: 1.6686e+01
# Experiment 28/216
# Эпохи: 900, Время: 0.4471c, MSE: 3.0188e+04
# Experiment 29/216
# Эпохи: 7200, Время: 1.2124c, MSE: 1.9134e+03
# Experiment 30/216
# Эпохи: 14400, Время: 2.1000c, MSE: 6.8654e+01
# Experiment 31/216
# Эпохи: 900, Время: 0.4194c, MSE: 3.0215e+04
# Experiment 32/216
# Эпохи: 7200, Время: 1.2028c, MSE: 1.9249e+03
# Experiment 33/216
# Эпохи: 14400, Время: 2.1487c, MSE: 7.3999e+01
# Experiment 34/216
# Эпохи: 900, Время: 0.4585c, MSE: 3.0216e+04
# Experiment 35/216
# Эпохи: 7200, Время: 1.5422c, MSE: 1.8591e+03
# Experiment 36/216
# Эпохи: 14400, Время: 2.7615c, MSE: 6.2134e+01
# Experiment 37/216
# Эпохи: 900, Время: 0.6137c, MSE: 1.5981e+03
# Experiment 38/216
# Эпохи: 7200, Время: 1.3668c, MSE: 8.0898e-02
# Experiment 39/216
# Эпохи: 14400, Время: 2.2993c, MSE: 2.5510e-02
# Experiment 40/216
# Эпохи: 900, Время: 0.6079c, MSE: 1.6308e+03
# Experiment 41/216
# Эпохи: 7200, Время: 1.3931c, MSE: 8.0999e-03
# Experiment 42/216
# Эпохи: 14400, Время: 2.3257c, MSE: 2.0126e-03
# Experiment 43/216
# Эпохи: 900, Время: 0.6258c, MSE: 1.7348e+03
# Experiment 44/216
# Эпохи: 7200, Время: 1.5081c, MSE: 4.2319e-03
# Experiment 45/216
# Эпохи: 14400, Время: 2.4992c, MSE: 7.9040e-03
# Experiment 46/216
# Эпохи: 900, Время: 0.6416c, MSE: 1.6855e+03
# Experiment 47/216
# Эпохи: 7200, Время: 1.7542c, MSE: 2.3624e-02
# Experiment 48/216
# Эпохи: 14400, Время: 3.1104c, MSE: 2.7565e-03
# Experiment 49/216
# Эпохи: 900, Время: 0.3933c, MSE: 3.6538e+03
# Experiment 50/216
# Эпохи: 7200, Время: 1.2012c, MSE: 3.6538e+03
# Experiment 51/216
# Эпохи: 14400, Время: 2.0478c, MSE: 3.6590e+03
# Experiment 52/216
# Эпохи: 900, Время: 0.3835c, MSE: 3.6480e+03
# Experiment 53/216
# Эпохи: 7200, Время: 1.1491c, MSE: 3.6480e+03
# Experiment 54/216
# Эпохи: 14400, Время: 2.0671c, MSE: 3.6480e+03
# Experiment 55/216
# Эпохи: 900, Время: 0.4111c, MSE: 3.6443e+03
# Experiment 56/216
# Эпохи: 7200, Время: 1.2177c, MSE: 3.6443e+03
# Experiment 57/216
# Эпохи: 14400, Время: 2.0994c, MSE: 3.6440e+03
# Experiment 58/216
# Эпохи: 900, Время: 0.4175c, MSE: 3.6440e+03
# Experiment 59/216
# Эпохи: 7200, Время: 1.1795c, MSE: 3.6439e+03
# Experiment 60/216
# Эпохи: 14400, Время: 2.1205c, MSE: 3.6439e+03
# Experiment 61/216
# Эпохи: 900, Время: 0.4641c, MSE: 2.8423e+04
# Experiment 62/216
# Эпохи: 7200, Время: 1.2543c, MSE: 1.0800e+00
# Experiment 63/216
# Эпохи: 14400, Время: 2.1606c, MSE: 6.6328e-02
# Experiment 64/216
# Эпохи: 900, Время: 0.4626c, MSE: 2.8429e+04
# Experiment 65/216
# Эпохи: 7200, Время: 1.2598c, MSE: 3.4617e-01
# Experiment 66/216
# Эпохи: 14400, Время: 2.2132c, MSE: 6.4912e-03
# Experiment 67/216
# Эпохи: 900, Время: 0.5045c, MSE: 2.8431e+04
# Experiment 68/216
# Эпохи: 7200, Время: 1.3064c, MSE: 2.3815e-01
# Experiment 69/216
# Эпохи: 14400, Время: 2.1951c, MSE: 4.2175e-03
# Experiment 70/216
# Эпохи: 900, Время: 0.4914c, MSE: 2.8432e+04
# Experiment 71/216
# Эпохи: 7200, Время: 1.3007c, MSE: 2.1070e-01
# Experiment 72/216
# Эпохи: 14400, Время: 2.3298c, MSE: 3.0546e-03
# Experiment 73/216
# Эпохи: 900, Время: 0.7064c, MSE: 3.3798e+04
# Experiment 74/216
# Эпохи: 7200, Время: 1.7311c, MSE: 7.4286e-02
# Experiment 75/216
# Эпохи: 14400, Время: 2.8927c, MSE: 5.1912e-02
# Experiment 76/216
# Эпохи: 900, Время: 0.8395c, MSE: 3.3799e+04
# Experiment 77/216
# Эпохи: 7200, Время: 1.9005c, MSE: 1.4281e-02
# Experiment 78/216
# Эпохи: 14400, Время: 3.0166c, MSE: 3.2554e-02
# Experiment 79/216
# Эпохи: 900, Время: 0.9143c, MSE: 3.3800e+04
# Experiment 80/216
# Эпохи: 7200, Время: 1.9780c, MSE: 4.3499e-02
# Experiment 81/216
# Эпохи: 14400, Время: 3.1208c, MSE: 3.4851e-02
# Experiment 82/216
# Эпохи: 900, Время: 0.9535c, MSE: 3.3800e+04
# Experiment 83/216
# Эпохи: 7200, Время: 2.3011c, MSE: 4.8126e-02
# Experiment 84/216
# Эпохи: 14400, Время: 3.5533c, MSE: 1.4477e-01
# Experiment 85/216
# Эпохи: 900, Время: 0.8018c, MSE: 8.4039e+01
# Experiment 86/216
# Эпохи: 7200, Время: 1.9321c, MSE: 8.9908e+01
# Experiment 87/216
# Эпохи: 14400, Время: 3.1571c, MSE: 9.1609e+01
# Experiment 88/216
# Эпохи: 900, Время: 0.7925c, MSE: 7.1008e-01
# Experiment 89/216
# Эпохи: 7200, Время: 1.8329c, MSE: 2.4784e-02
# Experiment 90/216
# Эпохи: 14400, Время: 2.9478c, MSE: 6.8589e-02
# Experiment 91/216
# Эпохи: 900, Время: 0.7572c, MSE: 3.3280e-01
# Experiment 92/216
# Эпохи: 7200, Время: 1.8251c, MSE: 1.6552e-02
# Experiment 93/216
# Эпохи: 14400, Время: 3.0315c, MSE: 7.4694e-02
# Experiment 94/216
# Эпохи: 900, Время: 0.9163c, MSE: 2.1857e-01
# Experiment 95/216
# Эпохи: 7200, Время: 2.6305c, MSE: 7.2688e-02
# Experiment 96/216
# Эпохи: 14400, Время: 4.6816c, MSE: 2.2161e-02
# Experiment 97/216
# Эпохи: 900, Время: 0.6741c, MSE: 3.3486e+04
# Experiment 98/216
# Эпохи: 7200, Время: 1.8328c, MSE: 5.3609e+00
# Experiment 99/216
# Эпохи: 14400, Время: 3.1821c, MSE: 5.0908e-01
# Experiment 100/216
# Эпохи: 900, Время: 0.7865c, MSE: 3.3479e+04
# Experiment 101/216
# Эпохи: 7200, Время: 2.3442c, MSE: 1.1383e+00
# Experiment 102/216
# Эпохи: 14400, Время: 4.2499c, MSE: 1.3961e-01
# Experiment 103/216
# Эпохи: 900, Время: 0.8052c, MSE: 3.3476e+04
# Experiment 104/216
# Эпохи: 7200, Время: 3.1006c, MSE: 1.9073e-01
# Experiment 105/216
# Эпохи: 14400, Время: 5.6759c, MSE: 2.1366e-03
# Experiment 106/216
# Эпохи: 900, Время: 1.0386c, MSE: 3.3476e+04
# Experiment 107/216
# Эпохи: 7200, Время: 4.9202c, MSE: 3.4802e-01
# Experiment 108/216
# Эпохи: 14400, Время: 9.5082c, MSE: 1.1073e-01
# Experiment 109/216
# Эпохи: 900, Время: 0.9270c, MSE: 1.8194e+01
# Experiment 110/216
# Эпохи: 7200, Время: 1.9747c, MSE: 1.1931e+00
# Experiment 111/216
# Эпохи: 14400, Время: 3.1926c, MSE: 2.9455e-01
# Experiment 112/216
# Эпохи: 900, Время: 1.0324c, MSE: 1.1632e+00
# Experiment 113/216
# Эпохи: 7200, Время: 2.1755c, MSE: 1.6696e-03
# Experiment 114/216
# Эпохи: 14400, Время: 3.3307c, MSE: 6.8592e-04
# Experiment 115/216
# Эпохи: 900, Время: 1.0464c, MSE: 7.9063e-02
# Experiment 116/216
# Эпохи: 7200, Время: 2.5511c, MSE: 1.7951e-04
# Experiment 117/216
# Эпохи: 14400, Время: 4.2246c, MSE: 2.1372e-02
# Experiment 118/216
# Эпохи: 900, Время: 1.1585c, MSE: 1.2281e-01
# Experiment 119/216
# Эпохи: 7200, Время: 3.4073c, MSE: 6.2333e-05
# Experiment 120/216
# Эпохи: 14400, Время: 6.0433c, MSE: 2.0432e-05
# Experiment 121/216
# Эпохи: 900, Время: 0.5038c, MSE: 3.6538e+03
# Experiment 122/216
# Эпохи: 7200, Время: 1.5208c, MSE: 3.6538e+03
# Experiment 123/216
# Эпохи: 14400, Время: 2.6875c, MSE: 3.6498e+03
# Experiment 124/216
# Эпохи: 900, Время: 0.6099c, MSE: 3.6480e+03
# Experiment 125/216
# Эпохи: 7200, Время: 1.6422c, MSE: 3.6480e+03
# Experiment 126/216
# Эпохи: 14400, Время: 2.7953c, MSE: 3.6479e+03
# Experiment 127/216
# Эпохи: 900, Время: 0.6101c, MSE: 3.6443e+03
# Experiment 128/216
# Эпохи: 7200, Время: 1.6297c, MSE: 3.6443e+03
# Experiment 129/216
# Эпохи: 14400, Время: 2.7886c, MSE: 3.6741e+03
# Experiment 130/216
# Эпохи: 900, Время: 0.6273c, MSE: 3.6439e+03
# Experiment 131/216
# Эпохи: 7200, Время: 1.6518c, MSE: 3.6439e+03
# Experiment 132/216
# Эпохи: 14400, Время: 3.0151c, MSE: 3.6440e+03
# Experiment 133/216
# Эпохи: 900, Время: 0.6771c, MSE: 3.4189e+04
# Experiment 134/216
# Эпохи: 7200, Время: 1.7126c, MSE: 1.7087e-01
# Experiment 135/216
# Эпохи: 14400, Время: 2.8987c, MSE: 3.6567e-01
# Experiment 136/216
# Эпохи: 900, Время: 0.6594c, MSE: 3.4189e+04
# Experiment 137/216
# Эпохи: 7200, Время: 1.7180c, MSE: 4.6476e-01
# Experiment 138/216
# Эпохи: 14400, Время: 2.8905c, MSE: 1.6112e-01
# Experiment 139/216
# Эпохи: 900, Время: 0.6882c, MSE: 3.4189e+04
# Experiment 140/216
# Эпохи: 7200, Время: 1.8034c, MSE: 1.1047e-01
# Experiment 141/216
# Эпохи: 14400, Время: 3.0295c, MSE: 1.4923e-01
# Experiment 142/216
# Эпохи: 900, Время: 0.7293c, MSE: 3.4189e+04
# Experiment 143/216
# Эпохи: 7200, Время: 2.0353c, MSE: 1.4777e-01
# Experiment 144/216
# Эпохи: 14400, Время: 3.6859c, MSE: 4.0283e-01
# Experiment 145/216
# Эпохи: 900, Время: 0.8998c, MSE: 3.3860e+04
# Experiment 146/216
# Эпохи: 7200, Время: 2.2693c, MSE: 3.7091e+03
# Experiment 147/216
# Эпохи: 14400, Время: 3.6553c, MSE: 3.7091e+03
# Experiment 148/216
# Эпохи: 900, Время: 1.0279c, MSE: 3.3860e+04
# Experiment 149/216
# Эпохи: 7200, Время: 2.2466c, MSE: 3.7091e+03
# Experiment 150/216
# Эпохи: 14400, Время: 3.5652c, MSE: 3.7091e+03
# Experiment 151/216
# Эпохи: 900, Время: 1.1723c, MSE: 3.3860e+04
# Experiment 152/216
# Эпохи: 7200, Время: 2.4691c, MSE: 3.7091e+03
# Experiment 153/216
# Эпохи: 14400, Время: 4.0358c, MSE: 3.7150e+03
# Experiment 154/216
# Эпохи: 900, Время: 1.2592c, MSE: 3.3860e+04
# Experiment 155/216
# Эпохи: 7200, Время: 3.3454c, MSE: 3.7091e+03
# Experiment 156/216
# Эпохи: 14400, Время: 5.7519c, MSE: 3.7091e+03
# Experiment 157/216
# Эпохи: 900, Время: 0.9264c, MSE: 2.0277e+00
# Experiment 158/216
# Эпохи: 7200, Время: 2.1831c, MSE: 3.1922e-02
# Experiment 159/216
# Эпохи: 14400, Время: 3.6169c, MSE: 7.4113e-01
# Experiment 160/216
# Эпохи: 900, Время: 0.9227c, MSE: 5.2057e-02
# Experiment 161/216
# Эпохи: 7200, Время: 2.2905c, MSE: 1.2246e-01
# Experiment 162/216
# Эпохи: 14400, Время: 3.7992c, MSE: 6.0680e-04
# Experiment 163/216
# Эпохи: 900, Время: 0.9800c, MSE: 2.5791e-02
# Experiment 164/216
# Эпохи: 7200, Время: 2.6459c, MSE: 2.3801e-04
# Experiment 165/216
# Эпохи: 14400, Время: 4.6758c, MSE: 5.1855e-04
# Experiment 166/216
# Эпохи: 900, Время: 1.1567c, MSE: 2.0564e-02
# Experiment 167/216
# Эпохи: 7200, Время: 3.9508c, MSE: 3.1685e-01
# Experiment 168/216
# Эпохи: 14400, Время: 7.1381c, MSE: 6.0356e-05
# Experiment 169/216
# Эпохи: 900, Время: 0.9249c, MSE: 3.3807e+04
# Experiment 170/216
# Эпохи: 7200, Время: 2.8097c, MSE: 6.0863e-01
# Experiment 171/216
# Эпохи: 14400, Время: 4.9919c, MSE: 2.3312e+03
# Experiment 172/216
# Эпохи: 900, Время: 1.0249c, MSE: 3.3817e+04
# Experiment 173/216
# Эпохи: 7200, Время: 3.6297c, MSE: 7.4437e-01
# Experiment 174/216
# Эпохи: 14400, Время: 6.4577c, MSE: 9.3203e-02
# Experiment 175/216
# Эпохи: 900, Время: 1.0954c, MSE: 3.3815e+04
# Experiment 176/216
# Эпохи: 7200, Время: 4.7699c, MSE: 2.2744e+00
# Experiment 177/216
# Эпохи: 14400, Время: 8.8784c, MSE: 4.8313e-01
# Experiment 178/216
# Эпохи: 900, Время: 1.5166c, MSE: 3.3815e+04
# Experiment 179/216
# Эпохи: 7200, Время: 8.2782c, MSE: 4.9696e+01
# Experiment 180/216
# Эпохи: 14400, Время: 15.7793c, MSE: 2.7482e+03
# Experiment 181/216
# Эпохи: 900, Время: 1.2862c, MSE: 2.6398e+00
# Experiment 182/216
# Эпохи: 7200, Время: 2.6485c, MSE: 4.1902e+00
# Experiment 183/216
# Эпохи: 14400, Время: 4.2140c, MSE: 2.5189e-01
# Experiment 184/216
# Эпохи: 900, Время: 1.4154c, MSE: 3.4356e+00
# Experiment 185/216
# Эпохи: 7200, Время: 3.1774c, MSE: 1.0484e-01
# Experiment 186/216
# Эпохи: 14400, Время: 5.3327c, MSE: 1.3558e-01
# Experiment 187/216
# Эпохи: 900, Время: 1.4366c, MSE: 6.9797e-02
# Experiment 188/216
# Эпохи: 7200, Время: 3.8168c, MSE: 4.7587e-03
# Experiment 189/216
# Эпохи: 14400, Время: 6.5560c, MSE: 5.9897e-01
# Experiment 190/216
# Эпохи: 900, Время: 1.8346c, MSE: 8.7971e-02
# Experiment 191/216
# Эпохи: 7200, Время: 5.1871c, MSE: 2.5731e-02
# Experiment 192/216
# Эпохи: 14400, Время: 9.3285c, MSE: 2.1329e-02
# Experiment 193/216
# Эпохи: 900, Время: 0.6016c, MSE: 3.6538e+03
# Experiment 194/216
# Эпохи: 7200, Время: 1.7987c, MSE: 3.6533e+03
# Experiment 195/216
# Эпохи: 14400, Время: 3.1587c, MSE: 3.6529e+03
# Experiment 196/216
# Эпохи: 900, Время: 0.6906c, MSE: 3.6480e+03
# Experiment 197/216
# Эпохи: 7200, Время: 1.9502c, MSE: 3.6552e+03
# Experiment 198/216
# Эпохи: 14400, Время: 3.2876c, MSE: 3.6480e+03
# Experiment 199/216
# Эпохи: 900, Время: 0.7246c, MSE: 3.6443e+03
# Experiment 200/216
# Эпохи: 7200, Время: 2.1774c, MSE: 3.6447e+03
# Experiment 201/216
# Эпохи: 14400, Время: 3.2896c, MSE: 3.6443e+03
# Experiment 202/216
# Эпохи: 900, Время: 0.7137c, MSE: 3.6439e+03
# Experiment 203/216
# Эпохи: 7200, Время: 1.9249c, MSE: 3.6434e+03
# Experiment 204/216
# Эпохи: 14400, Время: 3.3185c, MSE: 3.6402e+03
# Experiment 205/216
# Эпохи: 900, Время: 0.8415c, MSE: 3.8888e+04
# Experiment 206/216
# Эпохи: 7200, Время: 2.0380c, MSE: 2.1967e+03
# Experiment 207/216
# Эпохи: 14400, Время: 3.3856c, MSE: 2.6074e-02
# Experiment 208/216
# Эпохи: 900, Время: 0.8332c, MSE: 3.8888e+04
# Experiment 209/216
# Эпохи: 7200, Время: 2.0146c, MSE: 2.1651e+03
# Experiment 210/216
# Эпохи: 14400, Время: 3.4341c, MSE: 1.2100e+00
# Experiment 211/216
# Эпохи: 900, Время: 0.8502c, MSE: 3.8888e+04
# Experiment 212/216
# Эпохи: 7200, Время: 2.1892c, MSE: 1.5342e+03
# Experiment 213/216
# Эпохи: 14400, Время: 3.6334c, MSE: 1.5163e-02
# Experiment 214/216
# Эпохи: 900, Время: 0.9306c, MSE: 3.8888e+04
# Experiment 215/216
# Эпохи: 7200, Время: 2.8752c, MSE: 1.5498e+03
# Experiment 216/216
# Эпохи: 14400, Время: 5.0999c, MSE: 1.9204e-02
# Experiment 217/216
# Эпохи: 900, Время: 0.4776c, MSE: 5.4765e+03
# Experiment 218/216
# Эпохи: 7200, Время: 1.2419c, MSE: 1.9361e-02
# Experiment 219/216
# Эпохи: 14400, Время: 2.1652c, MSE: 9.4177e-03
# Experiment 220/216
# Эпохи: 900, Время: 0.4659c, MSE: 5.4935e+03
# Experiment 221/216
# Эпохи: 7200, Время: 1.2606c, MSE: 1.2635e-02
# Experiment 222/216
# Эпохи: 14400, Время: 2.2039c, MSE: 1.1063e-04
# Experiment 223/216
# Эпохи: 900, Время: 0.4813c, MSE: 5.5017e+03
# Experiment 224/216
# Эпохи: 7200, Время: 1.3210c, MSE: 1.9968e-03
# Experiment 225/216
# Эпохи: 14400, Время: 2.2899c, MSE: 7.3656e-05
# Experiment 226/216
# Эпохи: 900, Время: 0.4898c, MSE: 5.5025e+03
# Experiment 227/216
# Эпохи: 7200, Время: 1.4136c, MSE: 8.1085e-04
# Experiment 228/216
# Эпохи: 14400, Время: 2.4571c, MSE: 2.1367e-05
# Experiment 229/216
# Эпохи: 900, Время: 0.5547c, MSE: 2.3974e+03
# Experiment 230/216
# Эпохи: 7200, Время: 1.2813c, MSE: 1.0892e-02
# Experiment 231/216
# Эпохи: 14400, Время: 2.2548c, MSE: 8.0671e-03
# Experiment 232/216
# Эпохи: 900, Время: 0.5084c, MSE: 2.1594e+03
# Experiment 233/216
# Эпохи: 7200, Время: 1.2539c, MSE: 2.4946e-03
# Experiment 234/216
# Эпохи: 14400, Время: 2.1450c, MSE: 3.7930e-04
# Experiment 235/216
# Эпохи: 900, Время: 0.5341c, MSE: 2.2310e+03
# Experiment 236/216
# Эпохи: 7200, Время: 1.3534c, MSE: 1.1040e-03
# Experiment 237/216
# Эпохи: 14400, Время: 2.3101c, MSE: 1.0582e-04
# Experiment 238/216
# Эпохи: 900, Время: 0.5512c, MSE: 2.1747e+03
# Experiment 239/216
# Эпохи: 7200, Время: 1.5701c, MSE: 9.9743e-04
# Experiment 240/216
# Эпохи: 14400, Время: 2.8146c, MSE: 1.3748e-03
# Experiment 241/216
# Эпохи: 900, Время: 0.5077c, MSE: 5.6221e+03
# Experiment 242/216
# Эпохи: 7200, Время: 1.2993c, MSE: 7.4437e+01
# Experiment 243/216
# Эпохи: 14400, Время: 2.2174c, MSE: 8.8941e+00
# Experiment 244/216
# Эпохи: 900, Время: 0.4329c, MSE: 5.6491e+03
# Experiment 245/216
# Эпохи: 7200, Время: 1.2083c, MSE: 2.5057e+02
# Experiment 246/216
# Эпохи: 14400, Время: 2.1131c, MSE: 8.7938e+00
# Experiment 247/216
# Эпохи: 900, Время: 0.4644c, MSE: 5.6638e+03
# Experiment 248/216
# Эпохи: 7200, Время: 1.5648c, MSE: 2.3431e+02
# Experiment 249/216
# Эпохи: 14400, Время: 2.8233c, MSE: 1.0767e+01
# Experiment 250/216
# Эпохи: 900, Время: 0.5788c, MSE: 5.6650e+03
# Experiment 251/216
# Эпохи: 7200, Время: 2.4838c, MSE: 2.0750e+02
# Experiment 252/216
# Эпохи: 14400, Время: 4.6410c, MSE: 8.8372e+00
# Experiment 253/216
# Эпохи: 900, Время: 0.6270c, MSE: 1.4548e+03
# Experiment 254/216
# Эпохи: 7200, Время: 1.4237c, MSE: 6.5210e-02
# Experiment 255/216
# Эпохи: 14400, Время: 2.2953c, MSE: 5.4723e-02
# Experiment 256/216
# Эпохи: 900, Время: 0.6411c, MSE: 1.4914e+03
# Experiment 257/216
# Эпохи: 7200, Время: 1.7634c, MSE: 1.8642e-03
# Experiment 258/216
# Эпохи: 14400, Время: 2.5273c, MSE: 2.0464e-02
# Experiment 259/216
# Эпохи: 900, Время: 0.6894c, MSE: 1.5011e+03
# Experiment 260/216
# Эпохи: 7200, Время: 1.7669c, MSE: 1.6901e-03
# Experiment 261/216
# Эпохи: 14400, Время: 3.0337c, MSE: 9.8004e-05
# Experiment 262/216
# Эпохи: 900, Время: 0.6902c, MSE: 1.4302e+03
# Experiment 263/216
# Эпохи: 7200, Время: 2.1219c, MSE: 4.2481e-03
# Experiment 264/216
# Эпохи: 14400, Время: 3.7012c, MSE: 6.7073e-04
# Experiment 265/216
# Эпохи: 900, Время: 0.3846c, MSE: 3.6538e+03
# Experiment 266/216
# Эпохи: 7200, Время: 1.1595c, MSE: 3.6538e+03
# Experiment 267/216
# Эпохи: 14400, Время: 2.3299c, MSE: 3.6538e+03
# Experiment 268/216
# Эпохи: 900, Время: 0.3991c, MSE: 3.6479e+03
# Experiment 269/216
# Эпохи: 7200, Время: 1.1532c, MSE: 3.6480e+03
# Experiment 270/216
# Эпохи: 14400, Время: 2.0902c, MSE: 3.6347e+03
# Experiment 271/216
# Эпохи: 900, Время: 0.4177c, MSE: 3.6443e+03
# Experiment 272/216
# Эпохи: 7200, Время: 1.2115c, MSE: 3.6443e+03
# Experiment 273/216
# Эпохи: 14400, Время: 2.1099c, MSE: 3.6443e+03
# Experiment 274/216
# Эпохи: 900, Время: 0.3769c, MSE: 3.6439e+03
# Experiment 275/216
# Эпохи: 7200, Время: 1.2295c, MSE: 3.6439e+03
# Experiment 276/216
# Эпохи: 14400, Время: 2.1239c, MSE: 3.6437e+03
# Experiment 277/216
# Эпохи: 900, Время: 0.4666c, MSE: 5.3528e+03
# Experiment 278/216
# Эпохи: 7200, Время: 1.2450c, MSE: 3.7093e-01
# Experiment 279/216
# Эпохи: 14400, Время: 2.1806c, MSE: 1.2228e-01
# Experiment 280/216
# Эпохи: 900, Время: 0.4574c, MSE: 5.3539e+03
# Experiment 281/216
# Эпохи: 7200, Время: 1.2440c, MSE: 1.2456e-01
# Experiment 282/216
# Эпохи: 14400, Время: 2.1547c, MSE: 4.7503e-03
# Experiment 283/216
# Эпохи: 900, Время: 0.4443c, MSE: 5.3546e+03
# Experiment 284/216
# Эпохи: 7200, Время: 1.2335c, MSE: 7.4978e-02
# Experiment 285/216
# Эпохи: 14400, Время: 2.1258c, MSE: 3.7486e-03
# Experiment 286/216
# Эпохи: 900, Время: 0.4756c, MSE: 5.3546e+03
# Experiment 287/216
# Эпохи: 7200, Время: 1.2346c, MSE: 7.2491e-02
# Experiment 288/216
# Эпохи: 14400, Время: 2.1618c, MSE: 3.3409e-03
# Experiment 289/216
# Эпохи: 900, Время: 0.7155c, MSE: 6.8014e+03
# Experiment 290/216
# Эпохи: 7200, Время: 1.9480c, MSE: 1.6170e-01
# Experiment 291/216
# Эпохи: 14400, Время: 3.3353c, MSE: 6.3641e-03
# Experiment 292/216
# Эпохи: 900, Время: 0.7374c, MSE: 6.8018e+03
# Experiment 293/216
# Эпохи: 7200, Время: 1.9299c, MSE: 2.1881e-02
# Experiment 294/216
# Эпохи: 14400, Время: 3.3495c, MSE: 1.2227e-01
# Experiment 295/216
# Эпохи: 900, Время: 0.7813c, MSE: 6.8019e+03
# Experiment 296/216
# Эпохи: 7200, Время: 2.3484c, MSE: 4.8288e-02
# Experiment 297/216
# Эпохи: 14400, Время: 4.1425c, MSE: 2.5149e-01
# Experiment 298/216
# Эпохи: 900, Время: 0.9206c, MSE: 6.8019e+03
# Experiment 299/216
# Эпохи: 7200, Время: 3.4081c, MSE: 3.5746e-01
# Experiment 300/216
# Эпохи: 14400, Время: 6.3242c, MSE: 4.6321e-03
# Experiment 301/216
# Эпохи: 900, Время: 0.7959c, MSE: 7.3737e+01
# Experiment 302/216
# Эпохи: 7200, Время: 2.0160c, MSE: 6.5316e+01
# Experiment 303/216
# Эпохи: 14400, Время: 3.5273c, MSE: 6.2016e+01
# Experiment 304/216
# Эпохи: 900, Время: 0.8090c, MSE: 3.8781e+00
# Experiment 305/216
# Эпохи: 7200, Время: 2.2030c, MSE: 1.7343e-01
# Experiment 306/216
# Эпохи: 14400, Время: 3.7705c, MSE: 8.2360e-02
# Experiment 307/216
# Эпохи: 900, Время: 0.8473c, MSE: 2.2119e+00
# Experiment 308/216
# Эпохи: 7200, Время: 2.6149c, MSE: 1.4639e-02
# Experiment 309/216
# Эпохи: 14400, Время: 4.7250c, MSE: 3.6630e-01
# Experiment 310/216
# Эпохи: 900, Время: 1.0726c, MSE: 2.1115e+00
# Experiment 311/216
# Эпохи: 7200, Время: 4.1580c, MSE: 1.5430e-01
# Experiment 312/216
# Эпохи: 14400, Время: 7.9998c, MSE: 4.7140e-01
# Experiment 313/216
# Эпохи: 900, Время: 0.9531c, MSE: 7.0849e+03
# Experiment 314/216
# Эпохи: 7200, Время: 3.2507c, MSE: 1.8318e+03
# Experiment 315/216
# Эпохи: 14400, Время: 6.0397c, MSE: 2.8499e-01
# Experiment 316/216
# Эпохи: 900, Время: 1.0138c, MSE: 6.7902e+03
# Experiment 317/216
# Эпохи: 7200, Время: 4.0775c, MSE: 3.3732e-02
# Experiment 318/216
# Эпохи: 14400, Время: 7.6989c, MSE: 9.1592e-03
# Experiment 319/216
# Эпохи: 900, Время: 1.2058c, MSE: 7.3215e+03
# Experiment 320/216
# Эпохи: 7200, Время: 6.0508c, MSE: 3.0887e+01
# Experiment 321/216
# Эпохи: 14400, Время: 11.5734c, MSE: 9.7072e-02
# Experiment 322/216
# Эпохи: 900, Время: 1.6444c, MSE: 7.5919e+03
# Experiment 323/216
# Эпохи: 7200, Время: 10.2232c, MSE: 1.3701e+00
# Experiment 324/216
# Эпохи: 14400, Время: 19.1567c, MSE: 1.9427e-02
# Experiment 325/216
# Эпохи: 900, Время: 1.0341c, MSE: 8.4017e+01
# Experiment 326/216
# Эпохи: 7200, Время: 2.5980c, MSE: 1.7040e+01
# Experiment 327/216
# Эпохи: 14400, Время: 4.3373c, MSE: 3.8350e+00
# Experiment 328/216
# Эпохи: 900, Время: 1.1599c, MSE: 1.6226e+00
# Experiment 329/216
# Эпохи: 7200, Время: 3.1900c, MSE: 1.4035e-02
# Experiment 330/216
# Эпохи: 14400, Время: 5.5647c, MSE: 1.5262e-02
# Experiment 331/216
# Эпохи: 900, Время: 1.2037c, MSE: 2.9523e-01
# Experiment 332/216
# Эпохи: 7200, Время: 3.9185c, MSE: 4.5262e-04
# Experiment 333/216
# Эпохи: 14400, Время: 6.8365c, MSE: 3.9266e-02
# Experiment 334/216
# Эпохи: 900, Время: 1.7730c, MSE: 1.3302e+00
# Experiment 335/216
# Эпохи: 7200, Время: 5.3659c, MSE: 5.4061e-02
# Experiment 336/216
# Эпохи: 14400, Время: 9.9293c, MSE: 1.6957e-01
# Experiment 337/216
# Эпохи: 900, Время: 0.5307c, MSE: 3.6538e+03
# Experiment 338/216
# Эпохи: 7200, Время: 1.5317c, MSE: 3.7261e+03
# Experiment 339/216
# Эпохи: 14400, Время: 2.7440c, MSE: 3.6539e+03
# Experiment 340/216
# Эпохи: 900, Время: 0.5480c, MSE: 3.6480e+03
# Experiment 341/216
# Эпохи: 7200, Время: 1.5832c, MSE: 3.6627e+03
# Experiment 342/216
# Эпохи: 14400, Время: 2.7229c, MSE: 3.6479e+03
# Experiment 343/216
# Эпохи: 900, Время: 0.5081c, MSE: 3.6443e+03
# Experiment 344/216
# Эпохи: 7200, Время: 1.5821c, MSE: 3.6442e+03
# Experiment 345/216
# Эпохи: 14400, Время: 2.7827c, MSE: 3.6472e+03
# Experiment 346/216
# Эпохи: 900, Время: 0.5066c, MSE: 3.6439e+03
# Experiment 347/216
# Эпохи: 7200, Время: 1.5109c, MSE: 3.6434e+03
# Experiment 348/216
# Эпохи: 14400, Время: 2.6277c, MSE: 3.6437e+03
# Experiment 349/216
# Эпохи: 900, Время: 0.6496c, MSE: 8.1278e+03
# Experiment 350/216
# Эпохи: 7200, Время: 1.6152c, MSE: 3.9985e+00
# Experiment 351/216
# Эпохи: 14400, Время: 2.8210c, MSE: 9.2851e+00
# Experiment 352/216
# Эпохи: 900, Время: 0.6969c, MSE: 8.1278e+03
# Experiment 353/216
# Эпохи: 7200, Время: 1.7800c, MSE: 2.9164e-01
# Experiment 354/216
# Эпохи: 14400, Время: 2.9229c, MSE: 4.4865e-01
# Experiment 355/216
# Эпохи: 900, Время: 0.7086c, MSE: 8.1278e+03
# Experiment 356/216
# Эпохи: 7200, Время: 2.1866c, MSE: 5.5358e-01
# Experiment 357/216
# Эпохи: 14400, Время: 3.8505c, MSE: 4.0439e-01
# Experiment 358/216
# Эпохи: 900, Время: 0.8425c, MSE: 8.1278e+03
# Experiment 359/216
# Эпохи: 7200, Время: 3.2785c, MSE: 6.6590e-01
# Experiment 360/216
# Эпохи: 14400, Время: 6.0701c, MSE: 2.8562e-01
# Experiment 361/216
# Эпохи: 900, Время: 0.9013c, MSE: 6.8018e+03
# Experiment 362/216
# Эпохи: 7200, Время: 2.4884c, MSE: 3.7091e+03
# Experiment 363/216
# Эпохи: 14400, Время: 4.3403c, MSE: 3.7091e+03
# Experiment 364/216
# Эпохи: 900, Время: 1.0170c, MSE: 6.8019e+03
# Experiment 365/216
# Эпохи: 7200, Время: 3.0045c, MSE: 3.7093e+03
# Experiment 366/216
# Эпохи: 14400, Время: 5.3050c, MSE: 3.7091e+03
# Experiment 367/216
# Эпохи: 900, Время: 1.0898c, MSE: 6.8019e+03
# Experiment 368/216
# Эпохи: 7200, Время: 4.0426c, MSE: 3.7091e+03
# Experiment 369/216
# Эпохи: 14400, Время: 7.4812c, MSE: 3.7091e+03
# Experiment 370/216
# Эпохи: 900, Время: 1.3497c, MSE: 6.8019e+03
# Experiment 371/216
# Эпохи: 7200, Время: 6.2158c, MSE: 3.7091e+03
# Experiment 372/216
# Эпохи: 14400, Время: 11.6821c, MSE: 3.7091e+03
# Experiment 373/216
# Эпохи: 900, Время: 1.0006c, MSE: 1.0286e+00
# Experiment 374/216
# Эпохи: 7200, Время: 2.7057c, MSE: 1.4876e+00
# Experiment 375/216
# Эпохи: 14400, Время: 4.5232c, MSE: 2.7055e+00
# Experiment 376/216
# Эпохи: 900, Время: 1.0613c, MSE: 1.6103e+00
# Experiment 377/216
# Эпохи: 7200, Время: 3.4186c, MSE: 2.9472e+00
# Experiment 378/216
# Эпохи: 14400, Время: 6.0712c, MSE: 1.6816e-05
# Experiment 379/216
# Эпохи: 900, Время: 1.1535c, MSE: 1.1167e+00
# Experiment 380/216
# Эпохи: 7200, Время: 4.4151c, MSE: 3.1181e-02
# Experiment 381/216
# Эпохи: 14400, Время: 8.0729c, MSE: 4.3633e-01
# Experiment 382/216
# Эпохи: 900, Время: 1.9110c, MSE: 2.6135e+00
# Experiment 383/216
# Эпохи: 7200, Время: 10.4311c, MSE: 1.4816e-01
# Experiment 384/216
# Эпохи: 14400, Время: 20.6666c, MSE: 3.7506e+00
# Experiment 385/216
# Эпохи: 900, Время: 1.2005c, MSE: 8.4250e+03
# Experiment 386/216
# Эпохи: 7200, Время: 4.7451c, MSE: 1.9689e+03
# Experiment 387/216
# Эпохи: 14400, Время: 8.9966c, MSE: 3.7208e+03
# Experiment 388/216
# Эпохи: 900, Время: 1.3798c, MSE: 7.9196e+03
# Experiment 389/216
# Эпохи: 7200, Время: 6.4111c, MSE: 8.2284e+02
# Experiment 390/216
# Эпохи: 14400, Время: 12.4600c, MSE: 9.4343e+02
# Experiment 391/216
# Эпохи: 900, Время: 1.7306c, MSE: 7.0924e+03
# Experiment 392/216
# Эпохи: 7200, Время: 10.0503c, MSE: 2.8637e+01
# Experiment 393/216
# Эпохи: 14400, Время: 19.6725c, MSE: 1.7798e+03
# Experiment 394/216
# Эпохи: 900, Время: 2.5901c, MSE: 6.5034e+03
# Experiment 395/216
# Эпохи: 7200, Время: 16.9536c, MSE: 3.0083e+01
# Experiment 396/216
# Эпохи: 14400, Время: 33.8905c, MSE: 1.3436e+02
# Experiment 397/216
# Эпохи: 900, Время: 1.4755c, MSE: 9.7542e+00
# Experiment 398/216
# Эпохи: 7200, Время: 4.1021c, MSE: 3.8553e+00
# Experiment 399/216
# Эпохи: 14400, Время: 7.0592c, MSE: 8.3720e-02
# Experiment 400/216
# Эпохи: 900, Время: 1.6217c, MSE: 1.5365e-01
# Experiment 401/216
# Эпохи: 7200, Время: 4.9518c, MSE: 7.3442e-02
# Experiment 402/216
# Эпохи: 14400, Время: 8.8359c, MSE: 2.7641e+00
# Experiment 403/216
# Эпохи: 900, Время: 1.7064c, MSE: 7.0749e-02
# Experiment 404/216
# Эпохи: 7200, Время: 6.1221c, MSE: 1.2031e+01
# Experiment 405/216
# Эпохи: 14400, Время: 11.3061c, MSE: 4.9828e+00
# Experiment 406/216
# Эпохи: 900, Время: 2.3581c, MSE: 3.3996e-02
# Experiment 407/216
# Эпохи: 7200, Время: 11.2694c, MSE: 1.0662e-02
# Experiment 408/216
# Эпохи: 14400, Время: 21.2474c, MSE: 6.4107e-01
# Experiment 409/216
# Эпохи: 900, Время: 0.6298c, MSE: 3.6538e+03
# Experiment 410/216
# Эпохи: 7200, Время: 1.8627c, MSE: 3.6545e+03
# Experiment 411/216
# Эпохи: 14400, Время: 3.2830c, MSE: 3.6538e+03
# Experiment 412/216
# Эпохи: 900, Время: 0.6675c, MSE: 3.6480e+03
# Experiment 413/216
# Эпохи: 7200, Время: 1.9890c, MSE: 3.6497e+03
# Experiment 414/216
# Эпохи: 14400, Время: 3.4923c, MSE: 3.6481e+03
# Experiment 415/216
# Эпохи: 900, Время: 0.5970c, MSE: 3.6443e+03
# Experiment 416/216
# Эпохи: 7200, Время: 1.7841c, MSE: 3.6443e+03
# Experiment 417/216
# Эпохи: 14400, Время: 3.1540c, MSE: 3.6443e+03
# Experiment 418/216
# Эпохи: 900, Время: 0.6365c, MSE: 3.6439e+03
# Experiment 419/216
# Эпохи: 7200, Время: 2.0313c, MSE: 3.6439e+03
# Experiment 420/216
# Эпохи: 14400, Время: 3.6367c, MSE: 3.6437e+03
# Experiment 421/216
# Эпохи: 900, Время: 0.8681c, MSE: 1.3201e+04
# Experiment 422/216
# Эпохи: 7200, Время: 2.2697c, MSE: 8.5784e-02
# Experiment 423/216
# Эпохи: 14400, Время: 3.8848c, MSE: 8.2930e+00
# Experiment 424/216
# Эпохи: 900, Время: 0.9400c, MSE: 1.3201e+04
# Experiment 425/216
# Эпохи: 7200, Время: 2.8771c, MSE: 2.3485e+00
# Experiment 426/216
# Эпохи: 14400, Время: 5.0489c, MSE: 2.1559e-03
# Experiment 427/216
# Эпохи: 900, Время: 1.0119c, MSE: 1.3201e+04
# Experiment 428/216
# Эпохи: 7200, Время: 3.7700c, MSE: 6.2101e-01
# Experiment 429/216
# Эпохи: 14400, Время: 6.7837c, MSE: 5.0474e-01
# Experiment 430/216
# Эпохи: 900, Время: 1.3452c, MSE: 1.3201e+04
# Experiment 431/216
# Эпохи: 7200, Время: 6.1318c, MSE: 6.0400e-01
# Experiment 432/216
# Эпохи: 14400, Время: 11.6432c, MSE: 1.6628e-04
# Experiment 433/216
# Эпохи: 900, Время: 0.5400c, MSE: 2.8225e+03
# Experiment 434/216
# Эпохи: 7200, Время: 1.3304c, MSE: 1.8432e-02
# Experiment 435/216
# Эпохи: 14400, Время: 2.2071c, MSE: 2.8203e-02
# Experiment 436/216
# Эпохи: 900, Время: 0.4814c, MSE: 2.7302e+03
# Experiment 437/216
# Эпохи: 7200, Время: 1.6385c, MSE: 6.2728e-04
# Experiment 438/216
# Эпохи: 14400, Время: 2.2311c, MSE: 5.5800e-05
# Experiment 439/216
# Эпохи: 900, Время: 0.5338c, MSE: 2.8225e+03
# Experiment 440/216
# Эпохи: 7200, Время: 1.4411c, MSE: 1.4668e-02
# Experiment 441/216
# Эпохи: 14400, Время: 2.4800c, MSE: 9.0946e-05
# Experiment 442/216
# Эпохи: 900, Время: 0.5515c, MSE: 2.7891e+03
# Experiment 443/216
# Эпохи: 7200, Время: 1.7340c, MSE: 3.1645e-04
# Experiment 444/216
# Эпохи: 14400, Время: 2.9523c, MSE: 2.3026e-05
# Experiment 445/216
# Эпохи: 900, Время: 0.6477c, MSE: 1.9554e+03
# Experiment 446/216
# Эпохи: 7200, Время: 1.3959c, MSE: 6.0437e-03
# Experiment 447/216
# Эпохи: 14400, Время: 2.2967c, MSE: 1.3823e-03
# Experiment 448/216
# Эпохи: 900, Время: 0.5143c, MSE: 1.6600e+03
# Experiment 449/216
# Эпохи: 7200, Время: 1.3175c, MSE: 1.9359e-03
# Experiment 450/216
# Эпохи: 14400, Время: 2.2374c, MSE: 3.5213e-04
# Experiment 451/216
# Эпохи: 900, Время: 0.5834c, MSE: 1.7374e+03
# Experiment 452/216
# Эпохи: 7200, Время: 1.7170c, MSE: 1.8404e-02
# Experiment 453/216
# Эпохи: 14400, Время: 3.0864c, MSE: 1.1528e-04
# Experiment 454/216
# Эпохи: 900, Время: 0.6648c, MSE: 1.6564e+03
# Experiment 455/216
# Эпохи: 7200, Время: 2.1091c, MSE: 3.0198e-02
# Experiment 456/216
# Эпохи: 14400, Время: 3.7253c, MSE: 8.8174e-05
# Experiment 457/216
# Эпохи: 900, Время: 0.5411c, MSE: 3.6026e+03
# Experiment 458/216
# Эпохи: 7200, Время: 1.3987c, MSE: 2.1876e+01
# Experiment 459/216
# Эпохи: 14400, Время: 2.3926c, MSE: 1.0006e+01
# Experiment 460/216
# Эпохи: 900, Время: 0.5103c, MSE: 3.5645e+03
# Experiment 461/216
# Эпохи: 7200, Время: 1.6738c, MSE: 2.0467e+01
# Experiment 462/216
# Эпохи: 14400, Время: 2.9049c, MSE: 8.4571e+00
# Experiment 463/216
# Эпохи: 900, Время: 0.6055c, MSE: 3.5389e+03
# Experiment 464/216
# Эпохи: 7200, Время: 2.5762c, MSE: 2.4062e+01
# Experiment 465/216
# Эпохи: 14400, Время: 4.8053c, MSE: 9.6331e+00
# Experiment 466/216
# Эпохи: 900, Время: 0.8146c, MSE: 3.5367e+03
# Experiment 467/216
# Эпохи: 7200, Время: 4.2609c, MSE: 1.9370e+01
# Experiment 468/216
# Эпохи: 14400, Время: 8.1972c, MSE: 8.3253e+00
# Experiment 469/216
# Эпохи: 900, Время: 0.6814c, MSE: 7.2460e+02
# Experiment 470/216
# Эпохи: 7200, Время: 1.5689c, MSE: 1.2533e-02
# Experiment 471/216
# Эпохи: 14400, Время: 2.5866c, MSE: 7.6740e-03
# Experiment 472/216
# Эпохи: 900, Время: 0.7435c, MSE: 8.1127e+02
# Experiment 473/216
# Эпохи: 7200, Время: 2.4328c, MSE: 1.0970e-03
# Experiment 474/216
# Эпохи: 14400, Время: 3.3398c, MSE: 3.6293e-03
# Experiment 475/216
# Эпохи: 900, Время: 0.7907c, MSE: 8.2651e+02
# Experiment 476/216
# Эпохи: 7200, Время: 2.2610c, MSE: 3.6086e-04
# Experiment 477/216
# Эпохи: 14400, Время: 3.9652c, MSE: 3.1436e-03
# Experiment 478/216
# Эпохи: 900, Время: 0.7834c, MSE: 7.6896e+02
# Experiment 479/216
# Эпохи: 7200, Время: 2.4675c, MSE: 2.5880e-04
# Experiment 480/216
# Эпохи: 14400, Время: 4.3577c, MSE: 3.8674e-05
# Experiment 481/216
# Эпохи: 900, Время: 0.4818c, MSE: 3.6538e+03
# Experiment 482/216
# Эпохи: 7200, Время: 1.2520c, MSE: 3.6538e+03
# Experiment 483/216
# Эпохи: 14400, Время: 2.2075c, MSE: 3.6538e+03
# Experiment 484/216
# Эпохи: 900, Время: 0.3963c, MSE: 3.6480e+03
# Experiment 485/216
# Эпохи: 7200, Время: 1.2057c, MSE: 3.6480e+03
# Experiment 486/216
# Эпохи: 14400, Время: 2.1267c, MSE: 3.6481e+03
# Experiment 487/216
# Эпохи: 900, Время: 0.3930c, MSE: 3.6443e+03
# Experiment 488/216
# Эпохи: 7200, Время: 1.2469c, MSE: 3.6443e+03
# Experiment 489/216
# Эпохи: 14400, Время: 2.1719c, MSE: 3.6441e+03
# Experiment 490/216
# Эпохи: 900, Время: 0.4033c, MSE: 3.6439e+03
# Experiment 491/216
# Эпохи: 7200, Время: 1.2561c, MSE: 3.6439e+03
# Experiment 492/216
# Эпохи: 14400, Время: 2.2086c, MSE: 3.6483e+03
# Experiment 493/216
# Эпохи: 900, Время: 0.5192c, MSE: 3.5282e+03
# Experiment 494/216
# Эпохи: 7200, Время: 1.3648c, MSE: 1.2387e-01
# Experiment 495/216
# Эпохи: 14400, Время: 2.2716c, MSE: 1.7552e-02
# Experiment 496/216
# Эпохи: 900, Время: 0.4815c, MSE: 3.4926e+03
# Experiment 497/216
# Эпохи: 7200, Время: 1.3371c, MSE: 5.3473e-02
# Experiment 498/216
# Эпохи: 14400, Время: 2.3248c, MSE: 2.4533e-03
# Experiment 499/216
# Эпохи: 900, Время: 0.4996c, MSE: 3.4708e+03
# Experiment 500/216
# Эпохи: 7200, Время: 1.3190c, MSE: 2.7981e-02
# Experiment 501/216
# Эпохи: 14400, Время: 2.2491c, MSE: 4.8558e-04
# Experiment 502/216
# Эпохи: 900, Время: 0.5125c, MSE: 3.4674e+03
# Experiment 503/216
# Эпохи: 7200, Время: 1.5287c, MSE: 2.0302e-02
# Experiment 504/216
# Эпохи: 14400, Время: 2.7077c, MSE: 4.5625e-04
# Experiment 505/216
# Эпохи: 900, Время: 0.9678c, MSE: 3.7963e+03
# Experiment 506/216
# Эпохи: 7200, Время: 3.4810c, MSE: 3.7092e+03
# Experiment 507/216
# Эпохи: 14400, Время: 6.3350c, MSE: 3.5301e+03
# Experiment 508/216
# Эпохи: 900, Время: 1.1557c, MSE: 4.0621e+03
# Experiment 509/216
# Эпохи: 7200, Время: 4.6255c, MSE: 1.1953e-01
# Experiment 510/216
# Эпохи: 14400, Время: 8.6362c, MSE: 2.5511e-02
# Experiment 511/216
# Эпохи: 900, Время: 1.2406c, MSE: 3.8183e+03
# Experiment 512/216
# Эпохи: 7200, Время: 5.7669c, MSE: 8.0658e-01
# Experiment 513/216
# Эпохи: 14400, Время: 10.8419c, MSE: 2.1325e-03
# Experiment 514/216
# Эпохи: 900, Время: 1.9503c, MSE: 2.2998e+03
# Experiment 515/216
# Эпохи: 7200, Время: 11.2637c, MSE: 1.0818e-03
# Experiment 516/216
# Эпохи: 14400, Время: 21.7703c, MSE: 1.2699e-02
# Experiment 517/216
# Эпохи: 900, Время: 1.1415c, MSE: 6.2493e+01
# Experiment 518/216
# Эпохи: 7200, Время: 3.8857c, MSE: 2.5733e+00
# Experiment 519/216
# Эпохи: 14400, Время: 7.1421c, MSE: 1.5745e-01
# Experiment 520/216
# Эпохи: 900, Время: 1.1451c, MSE: 3.0847e+01
# Experiment 521/216
# Эпохи: 7200, Время: 4.7249c, MSE: 2.4266e-02
# Experiment 522/216
# Эпохи: 14400, Время: 9.0137c, MSE: 2.7366e-02
# Experiment 523/216
# Эпохи: 900, Время: 1.4851c, MSE: 3.1517e+00
# Experiment 524/216
# Эпохи: 7200, Время: 7.0590c, MSE: 4.6136e-02
# Experiment 525/216
# Эпохи: 14400, Время: 13.4689c, MSE: 2.9771e+00
# Experiment 526/216
# Эпохи: 900, Время: 2.6050c, MSE: 1.7221e+00
# Experiment 527/216
# Эпохи: 7200, Время: 16.1491c, MSE: 4.9236e-02
# Experiment 528/216
# Эпохи: 14400, Время: 33.0650c, MSE: 2.2924e-01
# Experiment 529/216
# Эпохи: 900, Время: 1.2878c, MSE: 2.6252e+03
# Experiment 530/216
# Эпохи: 7200, Время: 6.7116c, MSE: 6.2160e+01
# Experiment 531/216
# Эпохи: 14400, Время: 12.6658c, MSE: 1.9439e-01
# Experiment 532/216
# Эпохи: 900, Время: 1.6163c, MSE: 1.6306e+03
# Experiment 533/216
# Эпохи: 7200, Время: 8.9564c, MSE: 1.6238e-01
# Experiment 534/216
# Эпохи: 14400, Время: 17.3461c, MSE: 5.4825e+02
# Experiment 535/216
# Эпохи: 900, Время: 2.0731c, MSE: 1.2279e+03
# Experiment 536/216
# Эпохи: 7200, Время: 13.0812c, MSE: 1.7471e+02
# Experiment 537/216
# Эпохи: 14400, Время: 25.5659c, MSE: 8.8088e-01
# Experiment 538/216
# Эпохи: 900, Время: 3.2477c, MSE: 1.1826e+03
# Experiment 539/216
# Эпохи: 7200, Время: 23.4242c, MSE: 9.7291e-01
# Experiment 540/216
# Эпохи: 14400, Время: 46.2349c, MSE: 4.5936e-01
# Experiment 541/216
# Эпохи: 900, Время: 1.3484c, MSE: 8.5045e+00
# Experiment 542/216
# Эпохи: 7200, Время: 4.5142c, MSE: 1.7636e+00
# Experiment 543/216
# Эпохи: 14400, Время: 8.5770c, MSE: 1.6232e-01
# Experiment 544/216
# Эпохи: 900, Время: 1.5593c, MSE: 2.0016e+00
# Experiment 545/216
# Эпохи: 7200, Время: 6.0049c, MSE: 1.0261e+01
# Experiment 546/216
# Эпохи: 14400, Время: 10.5573c, MSE: 5.0932e-02
# Experiment 547/216
# Эпохи: 900, Время: 1.7150c, MSE: 3.2777e-01
# Experiment 548/216
# Эпохи: 7200, Время: 8.0839c, MSE: 6.7426e-02
# Experiment 549/216
# Эпохи: 14400, Время: 14.7442c, MSE: 7.7914e-02
# Experiment 550/216
# Эпохи: 900, Время: 2.6127c, MSE: 1.4585e+00
# Experiment 551/216
# Эпохи: 7200, Время: 15.2432c, MSE: 6.3095e-04
# Experiment 552/216
# Эпохи: 14400, Время: 29.7873c, MSE: 5.4411e-02
# Experiment 553/216
# Эпохи: 900, Время: 0.5760c, MSE: 3.6538e+03
# Experiment 554/216
# Эпохи: 7200, Время: 1.5540c, MSE: 3.6537e+03
# Experiment 555/216
# Эпохи: 14400, Время: 2.7332c, MSE: 3.6538e+03
# Experiment 556/216
# Эпохи: 900, Время: 0.5795c, MSE: 3.6480e+03
# Experiment 557/216
# Эпохи: 7200, Время: 1.5584c, MSE: 3.6477e+03
# Experiment 558/216
# Эпохи: 14400, Время: 2.7266c, MSE: 3.7711e+03
# Experiment 559/216
# Эпохи: 900, Время: 0.5862c, MSE: 3.6443e+03
# Experiment 560/216
# Эпохи: 7200, Время: 2.0515c, MSE: 3.6442e+03
# Experiment 561/216
# Эпохи: 14400, Время: 3.7235c, MSE: 3.6446e+03
# Experiment 562/216
# Эпохи: 900, Время: 0.6988c, MSE: 3.6439e+03
# Experiment 563/216
# Эпохи: 7200, Время: 2.9547c, MSE: 3.6444e+03
# Experiment 564/216
# Эпохи: 14400, Время: 5.3835c, MSE: 3.6389e+03
# Experiment 565/216
# Эпохи: 900, Время: 0.8272c, MSE: 3.8393e+03
# Experiment 566/216
# Эпохи: 7200, Время: 3.0108c, MSE: 1.2021e+00
# Experiment 567/216
# Эпохи: 14400, Время: 5.5873c, MSE: 9.9646e-01
# Experiment 568/216
# Эпохи: 900, Время: 1.0177c, MSE: 3.8393e+03
# Experiment 569/216
# Эпохи: 7200, Время: 4.2091c, MSE: 1.8523e+01
# Experiment 570/216
# Эпохи: 14400, Время: 7.8507c, MSE: 5.4238e-03
# Experiment 571/216
# Эпохи: 900, Время: 1.1668c, MSE: 3.8393e+03
# Experiment 572/216
# Эпохи: 7200, Время: 5.6200c, MSE: 3.7108e-01
# Experiment 573/216
# Эпохи: 14400, Время: 10.7137c, MSE: 2.2721e-01
# Experiment 574/216
# Эпохи: 900, Время: 1.8717c, MSE: 3.8393e+03
# Experiment 575/216
# Эпохи: 7200, Время: 11.1048c, MSE: 1.0092e-01
# Experiment 576/216
# Эпохи: 14400, Время: 21.8984c, MSE: 4.3413e-04
# Experiment 577/216
# Эпохи: 900, Время: 1.3799c, MSE: 3.7302e+03
# Experiment 578/216
# Эпохи: 7200, Время: 5.9127c, MSE: 3.7091e+03
# Experiment 579/216
# Эпохи: 14400, Время: 11.0964c, MSE: 3.7091e+03
# Experiment 580/216
# Эпохи: 900, Время: 1.6174c, MSE: 3.7302e+03
# Experiment 581/216
# Эпохи: 7200, Время: 7.7376c, MSE: 3.7091e+03
# Experiment 582/216
# Эпохи: 14400, Время: 15.3687c, MSE: 3.7091e+03
# Experiment 583/216
# Эпохи: 900, Время: 1.9845c, MSE: 3.7302e+03
# Experiment 584/216
# Эпохи: 7200, Время: 11.1467c, MSE: 3.7091e+03
# Experiment 585/216
# Эпохи: 14400, Время: 21.5232c, MSE: 3.7091e+03
# Experiment 586/216
# Эпохи: 900, Время: 3.6765c, MSE: 3.7302e+03
# Experiment 587/216
# Эпохи: 7200, Время: 24.2352c, MSE: 3.6238e+03
# Experiment 588/216
# Эпохи: 14400, Время: 47.9854c, MSE: 3.7091e+03
# Experiment 589/216
# Эпохи: 900, Время: 1.5661c, MSE: 1.6950e-01
# Experiment 590/216
# Эпохи: 7200, Время: 6.4769c, MSE: 1.9058e+00
# Experiment 591/216
# Эпохи: 14400, Время: 12.8986c, MSE: 5.2770e-05
# Experiment 592/216
# Эпохи: 900, Время: 1.9248c, MSE: 1.4411e+00
# Experiment 593/216
# Эпохи: 7200, Время: 8.9297c, MSE: 2.0842e+00
# Experiment 594/216
# Эпохи: 14400, Время: 18.9024c, MSE: 7.4706e-03
# Experiment 595/216
# Эпохи: 900, Время: 2.8776c, MSE: 8.2891e-02
# Experiment 596/216
# Эпохи: 7200, Время: 17.0729c, MSE: 6.4636e+00
# Experiment 597/216
# Эпохи: 14400, Время: 33.6666c, MSE: 5.6624e-03
# Experiment 598/216
# Эпохи: 900, Время: 4.6509c, MSE: 1.2144e+00
# Experiment 599/216
# Эпохи: 7200, Время: 31.8584c, MSE: 6.8608e-02
# Experiment 600/216
# Эпохи: 14400, Время: 64.3878c, MSE: 2.9906e-01
# Experiment 601/216
# Эпохи: 900, Время: 2.1348c, MSE: 2.9851e+04
# Experiment 602/216
# Эпохи: 7200, Время: 13.1272c, MSE: 1.2483e+05
# Experiment 603/216
# Эпохи: 14400, Время: 26.2223c, MSE: 8.0653e+04
# Experiment 604/216
# Эпохи: 900, Время: 2.6709c, MSE: 1.4105e+04
# Experiment 605/216
# Эпохи: 7200, Время: 16.7983c, MSE: 6.7138e+04
# Experiment 606/216
# Эпохи: 14400, Время: 33.2378c, MSE: 2.1844e+04
# Experiment 607/216
# Эпохи: 900, Время: 3.5185c, MSE: 1.4587e+04
# Experiment 608/216
# Эпохи: 7200, Время: 24.5270c, MSE: 1.3194e+04
# Experiment 609/216
# Эпохи: 14400, Время: 49.4391c, MSE: 3.7319e+04
# Experiment 610/216
# Эпохи: 900, Время: 6.3686c, MSE: 1.3611e+04
# Experiment 611/216
# Эпохи: 7200, Время: 45.7219c, MSE: 4.2733e+03
# Experiment 612/216
# Эпохи: 14400, Время: 90.3163c, MSE: 9.2261e+02
# Experiment 613/216
# Эпохи: 900, Время: 2.1936c, MSE: 3.2862e-01
# Experiment 614/216
# Эпохи: 7200, Время: 8.7169c, MSE: 5.6102e-02
# Experiment 615/216
# Эпохи: 14400, Время: 16.1198c, MSE: 1.0012e-01
# Experiment 616/216
# Эпохи: 900, Время: 2.5232c, MSE: 1.9101e-01
# Experiment 617/216
# Эпохи: 7200, Время: 10.8138c, MSE: 1.6619e-01
# Experiment 618/216
# Эпохи: 14400, Время: 19.8963c, MSE: 2.8860e-02
# Experiment 619/216
# Эпохи: 900, Время: 3.3692c, MSE: 2.9039e+00
# Experiment 620/216
# Эпохи: 7200, Время: 18.2484c, MSE: 6.0991e+00
# Experiment 621/216
# Эпохи: 14400, Время: 36.3920c, MSE: 2.6517e-01
# Experiment 622/216
# Эпохи: 900, Время: 4.5894c, MSE: 2.8602e-01
# Experiment 623/216
# Эпохи: 7200, Время: 27.2614c, MSE: 7.5121e+00
# Experiment 624/216
# Эпохи: 14400, Время: 55.7077c, MSE: 1.5371e+00
# Experiment 625/216
# Эпохи: 900, Время: 0.7639c, MSE: 3.5701e+03
# Experiment 626/216
# Эпохи: 7200, Время: 2.2405c, MSE: 3.6326e+03
# Experiment 627/216
# Эпохи: 14400, Время: 3.7850c, MSE: 3.6807e+03
# Experiment 628/216
# Эпохи: 900, Время: 0.7656c, MSE: 3.6436e+03
# Experiment 629/216
# Эпохи: 7200, Время: 2.6237c, MSE: 3.6479e+03
# Experiment 630/216
# Эпохи: 14400, Время: 4.6619c, MSE: 3.6502e+03
# Experiment 631/216
# Эпохи: 900, Время: 0.9234c, MSE: 3.6660e+03
# Experiment 632/216
# Эпохи: 7200, Время: 3.5562c, MSE: 3.6444e+03
# Experiment 633/216
# Эпохи: 14400, Время: 6.6820c, MSE: 3.5157e+03
# Experiment 634/216
# Эпохи: 900, Время: 1.1380c, MSE: 3.6447e+03
# Experiment 635/216
# Эпохи: 7200, Время: 5.5606c, MSE: 3.6431e+03
# Experiment 636/216
# Эпохи: 14400, Время: 10.3244c, MSE: 3.6432e+03
# Experiment 637/216
# Эпохи: 900, Время: 1.3996c, MSE: 4.1163e+03
# Experiment 638/216
# Эпохи: 7200, Время: 5.8028c, MSE: 2.3580e+03
# Experiment 639/216
# Эпохи: 14400, Время: 10.7754c, MSE: 7.2709e+02
# Experiment 640/216
# Эпохи: 900, Время: 1.6245c, MSE: 4.1163e+03
# Experiment 641/216
# Эпохи: 7200, Время: 7.9748c, MSE: 3.7091e+03
# Experiment 642/216
# Эпохи: 14400, Время: 15.2967c, MSE: 2.2527e+00
# Experiment 643/216
# Эпохи: 900, Время: 2.2087c, MSE: 4.1163e+03
# Experiment 644/216
# Эпохи: 7200, Время: 12.6984c, MSE: 2.9716e+03
# Experiment 645/216
# Эпохи: 14400, Время: 24.5700c, MSE: 2.1990e+03
# Experiment 646/216
# Эпохи: 900, Время: 3.9818c, MSE: 4.1163e+03
# Experiment 647/216
# Эпохи: 7200, Время: 26.0446c, MSE: 5.9239e+02
# Experiment 648/216
# Эпохи: 14400, Время: 51.1951c, MSE: 2.0849e+00
# Experiments finished. Results saved to csv_results/1D_sphere_dirichlet_results.csv
#      bc_left   bc_right training_time  epoches    lr activation_func  layers  \
# 0  dirichlet  dirichlet        0.5358      900  0.01            tanh       1
# 1  dirichlet  dirichlet        1.2652     7200  0.01            tanh       1
# 2  dirichlet  dirichlet        2.1670    14400  0.01            tanh       1
# 3  dirichlet  dirichlet        0.6105      900  0.01            tanh       1
# 4  dirichlet  dirichlet        1.3321     7200  0.01            tanh       1
#
#    neurons optimizer  collocation_points        mape         mae         mse  \
# 0       32      adam                  12  3.7171e-01  1.6222e+02  2.9506e+04
# 1       32      adam                  12  7.8561e-04  3.3854e-01  1.4023e-01
# 2       32      adam                  12  4.3906e-04  1.8587e-01  4.2376e-02
# 3       32      adam                  22  3.7203e-01  1.6236e+02  2.9550e+04
# 4       32      adam                  22  1.4817e-04  6.6111e-02  5.6243e-03
#
#          rmse   max_error    weights
# 0  1.7177e+02  2.3958e+02  [1, 5, 5]
# 1  3.7447e-01  5.5316e-01  [1, 5, 5]
# 2  2.0585e-01  3.0499e-01  [1, 5, 5]
# 3  1.7190e+02  2.3971e+02  [1, 5, 5]
# 4  7.4995e-02  1.1905e-01  [1, 5, 5]
